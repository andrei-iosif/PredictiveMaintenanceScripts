# %%
import os
import sys

seed = 0
os.environ['PYTHONHASHSEED'] = str(seed)

# %%
import numpy as np
import pandas as pd
import time
import random

from tensorflow.random import set_seed

# %%
# Add modules path
module_path = os.path.abspath('..')
if module_path not in sys.path:
    sys.path.append(module_path)

# %%
from src.data_reader import DataReader
from src.feature_engineering import add_time_lags
from src.metrics import compute_evaluation_metrics
from src.model_evaluation import evaluate_mlp, evaluate_mlp_multiple_splits
from src.plotting import plot_loss_curves
from src.serialization import load_object
from src.training import train_evaluate_mlp, MLPConfigParams
from src.utils import numbers_list_to_string

# %%
# Set seed
random.seed(seed)
np.random.seed(seed)
set_seed(seed)

# %%
# Set input and output paths
filename = '../data/N-CMAPSS_DS02-006.h5'
output_path = '../results/experiment_set_21_time_window'

if not os.path.exists(output_path):
    os.makedirs(output_path)

# %%
def time_window_processing(train_set, window_size, selected_columns, drop_unit_col=False, 
                           remove_overlapped_windows=False):
    df = train_set[selected_columns].copy()
    
    # Create lagged version for each column
    shifted_cols = {}
    for lag in range(1, window_size):
        cols = df[selected_columns].groupby("unit").shift(lag)
        shifted_cols[lag] = cols
    
    # Add lag columns to initial dataframe
    for lag, cols in shifted_cols.items():
        df = df.join(cols.rename(columns=lambda x: x + "_(t-{})".format(lag)))
    
    # Add output column
    df = df.join(train_set['RUL'])
    
    # Drop rows with NaN and the unit column
    df.dropna(inplace=True)
    if drop_unit_col:
        df.drop(labels=['unit'], axis=1, inplace=True)
        
    # Remove overlapping windows with overlap less than stride
    # Stride fixed to half of window length
    if remove_overlapped_windows:
        df.reset_index(drop=True, inplace=True)
        stride = window_size // 2
        df = df[df.index % (stride + 1) == 0]
    
    return df

def train_validation_split(train_set, val_units=[10, 20]):
    unit_col = train_set['unit'].copy(deep=True)
    train_set.drop(['unit'], axis=1, inplace=True)
    
    train_idx = unit_col[~unit_col.isin(val_units)].index
    val_idx = unit_col[unit_col.isin(val_units)].index
    
    train_split = train_set.loc[train_idx]
    val_split = train_set.loc[val_idx]
    
    return train_split, val_split

# %%
data_reader = DataReader()

start_time = time.process_time()  
data_reader.load_dataset(filename, load_train=True, load_test=True)
print("Operation time (sec): " , (time.process_time() - start_time))

if data_reader.train_set is not None:
    print("Train set shape: " + str(data_reader.train_set.shape))
    
if data_reader.test_set is not None:   
    print("Test set shape: " + str(data_reader.test_set.shape))
# Out:
# Operation time (sec):  3.6875
# Train set shape: (5263447, 47)
# Test set shape: (1253743, 47)

# %%
train_set = data_reader.train_set

selected_columns = ['T24', 'T30', 'P15', 'SmFan', 'SmLPC']
selected_columns_with_unit = selected_columns + ['unit']
train_set = train_set[selected_columns_with_unit + ['RUL']]

train_set = train_set.astype(np.float32)

# %%
train_set_preproc = time_window_processing(train_set, 10, selected_columns_with_unit, 
                                           drop_unit_col=False, remove_overlapped_windows=True)

# %%
train_set_preproc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1754465 entries, 0 to 5263392
# Data columns (total 52 columns):
#  #   Column       Dtype
# ---  ------       -----
#  0   T24          float32
#  1   T30          float32
#  2   P15          float32
#  3   SmFan        float32
#  4   SmLPC        float32
#  5   unit         float32
#  6   T24_(t-1)    float32
#  7   T30_(t-1)    float32
#  8   P15_(t-1)    float32
#  9   SmFan_(t-1)  float32
#  10  SmLPC_(t-1)  float32
#  11  T24_(t-2)    float32
#  12  T30_(t-2)    float32
#  13  P15_(t-2)    float32
#  14  SmFan_(t-2)  float32
#  15  SmLPC_(t-2)  float32
#  16  T24_(t-3)    float32
#  17  T30_(t-3)    float32
#  18  P15_(t-3)    float32
#  19  SmFan_(t-3)  float32
#  20  SmLPC_(t-3)  float32
#  21  T24_(t-4)    float32
#  22  T30_(t-4)    float32
#  23  P15_(t-4)    float32
#  24  SmFan_(t-4)  float32
#  25  SmLPC_(t-4)  float32
#  26  T24_(t-5)    float32
#  27  T30_(t-5)    float32
#  28  P15_(t-5)    float32
#  29  SmFan_(t-5)  float32
#  30  SmLPC_(t-5)  float32
#  31  T24_(t-6)    float32
#  32  T30_(t-6)    float32
#  33  P15_(t-6)    float32
#  34  SmFan_(t-6)  float32
#  35  SmLPC_(t-6)  float32
#  36  T24_(t-7)    float32
#  37  T30_(t-7)    float32
#  38  P15_(t-7)    float32
#  39  SmFan_(t-7)  float32
#  40  SmLPC_(t-7)  float32
#  41  T24_(t-8)    float32
#  42  T30_(t-8)    float32
#  43  P15_(t-8)    float32
#  44  SmFan_(t-8)  float32
#  45  SmLPC_(t-8)  float32
#  46  T24_(t-9)    float32
#  47  T30_(t-9)    float32
#  48  P15_(t-9)    float32
#  49  SmFan_(t-9)  float32
#  50  SmLPC_(t-9)  float32
#  51  RUL          float32
# dtypes: float32(52)
# memory usage: 361.4 MB

# %%
##############################################
# Effect of time windowing (experiment set 20)
##############################################
NUM_TRIALS = 3
EPOCHS = 15
BATCH_SIZE = 512

mlp_params = MLPConfigParams(layer_sizes=[256, 256, 512, 64], activation='tanh', dropout=0.0)
window_sizes = [0, 5, 10, 15, 20]

results_file = os.path.join(output_path, "results_time_window.csv")
with open(results_file, "w") as file:
    file.write("window,mse,rmse,cmapss,mse(mean),mse(std),rmse(mean),rmse(std),cmapss(mean),cmapss(std)\n")

for w in window_sizes:
    results_folder = f"results_window_{w}"
    results_path = os.path.join(output_path, results_folder)
    if not os.path.exists(results_path):
        os.makedirs(results_path)
    
    with open(results_file, "a") as file:
        file.write(f"{w},")
    
    # Add time lags
    if w == 0:
        train_set_preproc = train_set.copy()
    else:
        train_set_preproc = time_window_processing(train_set, w, selected_columns_with_unit, 
                                                   drop_unit_col=False) 
    
    # Validation split after engine number
    train_split, val_split = train_validation_split(train_set_preproc)
    
    x_train_split = train_split[[i for i in list(train_split.columns) if i != 'RUL']]
    x_holdout_split = val_split[[i for i in list(val_split.columns) if i != 'RUL']]
    
    y_train_split = train_split['RUL']
    y_holdout_split = val_split['RUL']
    
    mse_vals, rmse_vals, cmapss_vals = train_evaluate_mlp(
        x_train_split, y_train_split, 
        x_holdout_split, y_holdout_split,
        NUM_TRIALS, 
        mlp_params, 
        results_path, 
        EPOCHS, BATCH_SIZE,
        results_file=results_file)
# Out:
# Saved object to file: ../results/experiment_set_20_time_window\results_window_0\split_0\scaler.pkl
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_5 (Dense)              (None, 256)               1536
# _________________________________________________________________
# dense_6 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dense_7 (Dense)              (None, 512)               131584
# _________________________________________________________________
# dense_8 (Dense)              (None, 64)                32832
# _________________________________________________________________
# dense_9 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 231,809
# Trainable params: 231,809
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/15
# 6228/6228 [==============================] - ETA: 0s - loss: 183.2012
# Epoch 00001: val_loss improved from inf to 71.73375, saving model to ../results/experiment_set_20_time_window\results_window_0\split_0\mlp_model_trained.h5
# 6228/6228 [==============================] - 26s 4ms/step - loss: 183.2012 - val_loss: 71.7337
# Epoch 2/15
# 6219/6228 [============================>.] - ETA: 0s - loss: 65.4033
# Epoch 00002: val_loss improved from 71.73375 to 57.97439, saving model to ../results/experiment_set_20_time_window\results_window_0\split_0\mlp_model_trained.h5
# 6228/6228 [==============================] - 24s 4ms/step - loss: 65.3960 - val_loss: 57.9744
# Epoch 3/15
# 6224/6228 [============================>.] - ETA: 0s - loss: 58.7957
# Epoch 00003: val_loss did not improve from 57.97439
# 6228/6228 [==============================] - 24s 4ms/step - loss: 58.7973 - val_loss: 68.2726
# Epoch 4/15
# 6225/6228 [============================>.] - ETA: 0s - loss: 54.8762
# Epoch 00004: val_loss improved from 57.97439 to 54.25644, saving model to ../results/experiment_set_20_time_window\results_window_0\split_0\mlp_model_trained.h5
# 6228/6228 [==============================] - 24s 4ms/step - loss: 54.8779 - val_loss: 54.2564
# Epoch 5/15
# 6226/6228 [============================>.] - ETA: 0s - loss: 52.0691
# Epoch 00005: val_loss improved from 54.25644 to 50.06058, saving model to ../results/experiment_set_20_time_window\results_window_0\split_0\mlp_model_trained.h5
# 6228/6228 [==============================] - 26s 4ms/step - loss: 52.0687 - val_loss: 50.0606
# Epoch 6/15
# 6220/6228 [============================>.] - ETA: 0s - loss: 49.3538
# Epoch 00006: val_loss improved from 50.06058 to 48.80165, saving model to ../results/experiment_set_20_time_window\results_window_0\split_0\mlp_model_trained.h5
# 6228/6228 [==============================] - 25s 4ms/step - loss: 49.3498 - val_loss: 48.8016
# Epoch 7/15
# 6224/6228 [============================>.] - ETA: 0s - loss: 47.2143
# Epoch 00007: val_loss did not improve from 48.80165
# 6228/6228 [==============================] - 25s 4ms/step - loss: 47.2172 - val_loss: 53.5868
# Epoch 8/15
# 6218/6228 [============================>.] - ETA: 0s - loss: 45.3655
# Epoch 00008: val_loss improved from 48.80165 to 44.07280, saving model to ../results/experiment_set_20_time_window\results_window_0\split_0\mlp_model_trained.h5
# 6228/6228 [==============================] - 26s 4ms/step - loss: 45.3668 - val_loss: 44.0728
# Epoch 9/15
# 6215/6228 [============================>.] - ETA: 0s - loss: 44.1276
# Epoch 00009: val_loss improved from 44.07280 to 42.53933, saving model to ../results/experiment_set_20_time_window\results_window_0\split_0\mlp_model_trained.h5
# 6228/6228 [==============================] - 24s 4ms/step - loss: 44.1246 - val_loss: 42.5393
# Epoch 10/15
# 6227/6228 [============================>.] - ETA: 0s - loss: 42.7154
# Epoch 00010: val_loss did not improve from 42.53933
# 6228/6228 [==============================] - 25s 4ms/step - loss: 42.7150 - val_loss: 42.7785
# Epoch 11/15
# 6217/6228 [============================>.] - ETA: 0s - loss: 41.5923
# Epoch 00011: val_loss did not improve from 42.53933
# 6228/6228 [==============================] - 25s 4ms/step - loss: 41.6039 - val_loss: 45.7941
# Epoch 12/15
# 6224/6228 [============================>.] - ETA: 0s - loss: 40.2495
# Epoch 00012: val_loss improved from 42.53933 to 41.24901, saving model to ../results/experiment_set_20_time_window\results_window_0\split_0\mlp_model_trained.h5
# 6228/6228 [==============================] - 25s 4ms/step - loss: 40.2489 - val_loss: 41.2490
# Epoch 13/15
# 6217/6228 [============================>.] - ETA: 0s - loss: 39.4256
# Epoch 00013: val_loss improved from 41.24901 to 38.47704, saving model to ../results/experiment_set_20_time_window\results_window_0\split_0\mlp_model_trained.h5
# 6228/6228 [==============================] - 25s 4ms/step - loss: 39.4226 - val_loss: 38.4770
# Epoch 14/15
# 6216/6228 [============================>.] - ETA: 0s - loss: 38.4307
# Epoch 00014: val_loss improved from 38.47704 to 38.38922, saving model to ../results/experiment_set_20_time_window\results_window_0\split_0\mlp_model_trained.h5
# 6228/6228 [==============================] - 25s 4ms/step - loss: 38.4288 - val_loss: 38.3892
# Epoch 15/15
# 6219/6228 [============================>.] - ETA: 0s - loss: 37.4018
# Epoch 00015: val_loss improved from 38.38922 to 36.48825, saving model to ../results/experiment_set_20_time_window\results_window_0\split_0\mlp_model_trained.h5
# 6228/6228 [==============================] - 26s 4ms/step - loss: 37.4026 - val_loss: 36.4882
# Saved object to file: ../results/experiment_set_20_time_window\results_window_0\split_0\history_0.pkl
# Test set:
# MSE: 139.93
# RMSE: 11.83
# CMAPSS score: 2.93
#
# Saved object to file: ../results/experiment_set_20_time_window\results_window_0\split_1\scaler.pkl
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_10 (Dense)             (None, 256)               1536
# _________________________________________________________________
# dense_11 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dense_12 (Dense)             (None, 512)               131584
# _________________________________________________________________
# dense_13 (Dense)             (None, 64)                32832
# _________________________________________________________________
# dense_14 (Dense)             (None, 1)                 65
# =================================================================
# Total params: 231,809
# Trainable params: 231,809
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/15
# 6216/6228 [============================>.] - ETA: 0s - loss: 177.6738
# Epoch 00001: val_loss improved from inf to 80.15151, saving model to ../results/experiment_set_20_time_window\results_window_0\split_1\mlp_model_trained.h5
# 6228/6228 [==============================] - 25s 4ms/step - loss: 177.4707 - val_loss: 80.1515
# Epoch 2/15
# 6224/6228 [============================>.] - ETA: 0s - loss: 65.6038
# Epoch 00002: val_loss improved from 80.15151 to 63.87113, saving model to ../results/experiment_set_20_time_window\results_window_0\split_1\mlp_model_trained.h5
# 6228/6228 [==============================] - 24s 4ms/step - loss: 65.6008 - val_loss: 63.8711
# Epoch 3/15
# 6214/6228 [============================>.] - ETA: 0s - loss: 59.1384
# Epoch 00003: val_loss improved from 63.87113 to 60.83920, saving model to ../results/experiment_set_20_time_window\results_window_0\split_1\mlp_model_trained.h5
# 6228/6228 [==============================] - 25s 4ms/step - loss: 59.1418 - val_loss: 60.8392
# Epoch 4/15
# 6228/6228 [==============================] - ETA: 0s - loss: 55.1523
# Epoch 00004: val_loss improved from 60.83920 to 56.30401, saving model to ../results/experiment_set_20_time_window\results_window_0\split_1\mlp_model_trained.h5
# 6228/6228 [==============================] - 25s 4ms/step - loss: 55.1523 - val_loss: 56.3040
# Epoch 5/15
# 6222/6228 [============================>.] - ETA: 0s - loss: 51.9238
# Epoch 00005: val_loss improved from 56.30401 to 54.50821, saving model to ../results/experiment_set_20_time_window\results_window_0\split_1\mlp_model_trained.h5
# 6228/6228 [==============================] - 24s 4ms/step - loss: 51.9185 - val_loss: 54.5082
# Epoch 6/15
# 6228/6228 [==============================] - ETA: 0s - loss: 49.0881
# Epoch 00006: val_loss improved from 54.50821 to 48.34965, saving model to ../results/experiment_set_20_time_window\results_window_0\split_1\mlp_model_trained.h5
# 6228/6228 [==============================] - 24s 4ms/step - loss: 49.0881 - val_loss: 48.3496
# Epoch 7/15
# 6216/6228 [============================>.] - ETA: 0s - loss: 47.2170
# Epoch 00007: val_loss improved from 48.34965 to 47.69789, saving model to ../results/experiment_set_20_time_window\results_window_0\split_1\mlp_model_trained.h5
# 6228/6228 [==============================] - 24s 4ms/step - loss: 47.2126 - val_loss: 47.6979
# Epoch 8/15
# 6217/6228 [============================>.] - ETA: 0s - loss: 45.5527
# Epoch 00008: val_loss improved from 47.69789 to 42.13973, saving model to ../results/experiment_set_20_time_window\results_window_0\split_1\mlp_model_trained.h5
# 6228/6228 [==============================] - 25s 4ms/step - loss: 45.5565 - val_loss: 42.1397
# Epoch 9/15
# 6215/6228 [============================>.] - ETA: 0s - loss: 44.3752
# Epoch 00009: val_loss improved from 42.13973 to 39.77559, saving model to ../results/experiment_set_20_time_window\results_window_0\split_1\mlp_model_trained.h5
# 6228/6228 [==============================] - 24s 4ms/step - loss: 44.3766 - val_loss: 39.7756
# Epoch 10/15
# 6222/6228 [============================>.] - ETA: 0s - loss: 42.8438
# Epoch 00010: val_loss did not improve from 39.77559
# 6228/6228 [==============================] - 24s 4ms/step - loss: 42.8433 - val_loss: 46.1481
# Epoch 11/15
# 6213/6228 [============================>.] - ETA: 0s - loss: 41.7818
# Epoch 00011: val_loss improved from 39.77559 to 38.84490, saving model to ../results/experiment_set_20_time_window\results_window_0\split_1\mlp_model_trained.h5
# 6228/6228 [==============================] - 25s 4ms/step - loss: 41.7797 - val_loss: 38.8449
# Epoch 12/15
# 6215/6228 [============================>.] - ETA: 0s - loss: 40.8790
# Epoch 00012: val_loss improved from 38.84490 to 37.46365, saving model to ../results/experiment_set_20_time_window\results_window_0\split_1\mlp_model_trained.h5
# 6228/6228 [==============================] - 24s 4ms/step - loss: 40.8732 - val_loss: 37.4636
# Epoch 13/15
# 6217/6228 [============================>.] - ETA: 0s - loss: 39.6710
# Epoch 00013: val_loss did not improve from 37.46365
# 6228/6228 [==============================] - 24s 4ms/step - loss: 39.6752 - val_loss: 45.9663
# Epoch 14/15
# 6215/6228 [============================>.] - ETA: 0s - loss: 38.8288
# Epoch 00014: val_loss did not improve from 37.46365
# 6228/6228 [==============================] - 24s 4ms/step - loss: 38.8312 - val_loss: 39.5280
# Epoch 15/15
# 6220/6228 [============================>.] - ETA: 0s - loss: 38.1195
# Epoch 00015: val_loss improved from 37.46365 to 35.43018, saving model to ../results/experiment_set_20_time_window\results_window_0\split_1\mlp_model_trained.h5
# 6228/6228 [==============================] - 24s 4ms/step - loss: 38.1149 - val_loss: 35.4302
# Saved object to file: ../results/experiment_set_20_time_window\results_window_0\split_1\history_1.pkl
# Test set:
# MSE: 138.78
# RMSE: 11.78
# CMAPSS score: 2.89
#
# Saved object to file: ../results/experiment_set_20_time_window\results_window_0\split_2\scaler.pkl
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_15 (Dense)             (None, 256)               1536
# _________________________________________________________________
# dense_16 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dense_17 (Dense)             (None, 512)               131584
# _________________________________________________________________
# dense_18 (Dense)             (None, 64)                32832
# _________________________________________________________________
# dense_19 (Dense)             (None, 1)                 65
# =================================================================
# Total params: 231,809
# Trainable params: 231,809
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/15
# 6212/6228 [============================>.] - ETA: 0s - loss: 172.9342
# Epoch 00001: val_loss improved from inf to 73.85643, saving model to ../results/experiment_set_20_time_window\results_window_0\split_2\mlp_model_trained.h5
# 6228/6228 [==============================] - 25s 4ms/step - loss: 172.6790 - val_loss: 73.8564
# Epoch 2/15
# 6214/6228 [============================>.] - ETA: 0s - loss: 64.2169
# Epoch 00002: val_loss improved from 73.85643 to 62.34588, saving model to ../results/experiment_set_20_time_window\results_window_0\split_2\mlp_model_trained.h5
# 6228/6228 [==============================] - 25s 4ms/step - loss: 64.2095 - val_loss: 62.3459
# Epoch 3/15
# 6225/6228 [============================>.] - ETA: 0s - loss: 58.1202
# Epoch 00003: val_loss improved from 62.34588 to 51.99637, saving model to ../results/experiment_set_20_time_window\results_window_0\split_2\mlp_model_trained.h5
# 6228/6228 [==============================] - 25s 4ms/step - loss: 58.1195 - val_loss: 51.9964
# Epoch 4/15
# 6216/6228 [============================>.] - ETA: 0s - loss: 53.7993
# Epoch 00004: val_loss did not improve from 51.99637
# 6228/6228 [==============================] - 24s 4ms/step - loss: 53.7935 - val_loss: 56.3540
# Epoch 5/15
# 6224/6228 [============================>.] - ETA: 0s - loss: 50.4358
# Epoch 00005: val_loss improved from 51.99637 to 49.35414, saving model to ../results/experiment_set_20_time_window\results_window_0\split_2\mlp_model_trained.h5
# 6228/6228 [==============================] - 25s 4ms/step - loss: 50.4353 - val_loss: 49.3541
# Epoch 6/15
# 6225/6228 [============================>.] - ETA: 0s - loss: 48.2752
# Epoch 00006: val_loss improved from 49.35414 to 46.76404, saving model to ../results/experiment_set_20_time_window\results_window_0\split_2\mlp_model_trained.h5
# 6228/6228 [==============================] - 25s 4ms/step - loss: 48.2749 - val_loss: 46.7640
# Epoch 7/15
# 6223/6228 [============================>.] - ETA: 0s - loss: 46.4419
# Epoch 00007: val_loss improved from 46.76404 to 43.70065, saving model to ../results/experiment_set_20_time_window\results_window_0\split_2\mlp_model_trained.h5
# 6228/6228 [==============================] - 25s 4ms/step - loss: 46.4410 - val_loss: 43.7006
# Epoch 8/15
# 6215/6228 [============================>.] - ETA: 0s - loss: 44.8044
# Epoch 00008: val_loss did not improve from 43.70065
# 6228/6228 [==============================] - 24s 4ms/step - loss: 44.8010 - val_loss: 46.3723
# Epoch 9/15
# 6221/6228 [============================>.] - ETA: 0s - loss: 43.3999
# Epoch 00009: val_loss did not improve from 43.70065
# 6228/6228 [==============================] - 24s 4ms/step - loss: 43.4080 - val_loss: 50.3428
# Epoch 10/15
# 6214/6228 [============================>.] - ETA: 0s - loss: 42.3872
# Epoch 00010: val_loss did not improve from 43.70065
# 6228/6228 [==============================] - 24s 4ms/step - loss: 42.3770 - val_loss: 49.8428
# Epoch 11/15
# 6215/6228 [============================>.] - ETA: 0s - loss: 41.3162
# Epoch 00011: val_loss did not improve from 43.70065
# 6228/6228 [==============================] - 24s 4ms/step - loss: 41.3194 - val_loss: 61.2370
# Epoch 12/15
# 6224/6228 [============================>.] - ETA: 0s - loss: 40.1782
# Epoch 00012: val_loss improved from 43.70065 to 40.03497, saving model to ../results/experiment_set_20_time_window\results_window_0\split_2\mlp_model_trained.h5
# 6228/6228 [==============================] - 24s 4ms/step - loss: 40.1764 - val_loss: 40.0350
# Epoch 13/15
# 6227/6228 [============================>.] - ETA: 0s - loss: 39.4866
# Epoch 00013: val_loss improved from 40.03497 to 39.41905, saving model to ../results/experiment_set_20_time_window\results_window_0\split_2\mlp_model_trained.h5
# 6228/6228 [==============================] - 24s 4ms/step - loss: 39.4862 - val_loss: 39.4191
# Epoch 14/15
# 6217/6228 [============================>.] - ETA: 0s - loss: 38.5152
# Epoch 00014: val_loss improved from 39.41905 to 36.74842, saving model to ../results/experiment_set_20_time_window\results_window_0\split_2\mlp_model_trained.h5
# 6228/6228 [==============================] - 25s 4ms/step - loss: 38.5120 - val_loss: 36.7484
# Epoch 15/15
# 6226/6228 [============================>.] - ETA: 0s - loss: 37.6695
# Epoch 00015: val_loss did not improve from 36.74842
# 6228/6228 [==============================] - 25s 4ms/step - loss: 37.6720 - val_loss: 39.0320
# Saved object to file: ../results/experiment_set_20_time_window\results_window_0\split_2\history_2.pkl
# Test set:
# MSE: 134.78
# RMSE: 11.61
# CMAPSS score: 2.79
#
# MSE: mean = 137.83   stddev = 2.21
# RMSE: mean = 11.74   stddev = 0.09
# CMAPSS: mean = 2.87   stddev = 0.06
# Saved object to file: ../results/experiment_set_20_time_window\results_window_5\split_0\scaler.pkl
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_20 (Dense)             (None, 256)               6656
# _________________________________________________________________
# dense_21 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dense_22 (Dense)             (None, 512)               131584
# _________________________________________________________________
# dense_23 (Dense)             (None, 64)                32832
# _________________________________________________________________
# dense_24 (Dense)             (None, 1)                 65
# =================================================================
# Total params: 236,929
# Trainable params: 236,929
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/15
# 6225/6228 [============================>.] - ETA: 0s - loss: 167.1733
# Epoch 00001: val_loss improved from inf to 56.25515, saving model to ../results/experiment_set_20_time_window\results_window_5\split_0\mlp_model_trained.h5
# 6228/6228 [==============================] - 25s 4ms/step - loss: 167.1354 - val_loss: 56.2551
# Epoch 2/15
# 6226/6228 [============================>.] - ETA: 0s - loss: 55.2733
# Epoch 00002: val_loss did not improve from 56.25515
# 6228/6228 [==============================] - 24s 4ms/step - loss: 55.2713 - val_loss: 83.2039
# Epoch 3/15
# 6223/6228 [============================>.] - ETA: 0s - loss: 47.9329
# Epoch 00003: val_loss improved from 56.25515 to 44.57207, saving model to ../results/experiment_set_20_time_window\results_window_5\split_0\mlp_model_trained.h5
# 6228/6228 [==============================] - 25s 4ms/step - loss: 47.9329 - val_loss: 44.5721
# Epoch 4/15
# 6213/6228 [============================>.] - ETA: 0s - loss: 42.8772
# Epoch 00004: val_loss improved from 44.57207 to 43.58000, saving model to ../results/experiment_set_20_time_window\results_window_5\split_0\mlp_model_trained.h5
# 6228/6228 [==============================] - 25s 4ms/step - loss: 42.8685 - val_loss: 43.5800
# Epoch 5/15
# 6227/6228 [============================>.] - ETA: 0s - loss: 39.5706
# Epoch 00005: val_loss improved from 43.58000 to 35.68818, saving model to ../results/experiment_set_20_time_window\results_window_5\split_0\mlp_model_trained.h5
# 6228/6228 [==============================] - 25s 4ms/step - loss: 39.5703 - val_loss: 35.6882
# Epoch 6/15
# 6219/6228 [============================>.] - ETA: 0s - loss: 36.9936
# Epoch 00006: val_loss did not improve from 35.68818
# 6228/6228 [==============================] - 24s 4ms/step - loss: 36.9912 - val_loss: 40.3624
# Epoch 7/15
# 6217/6228 [============================>.] - ETA: 0s - loss: 34.8552
# Epoch 00007: val_loss improved from 35.68818 to 31.14589, saving model to ../results/experiment_set_20_time_window\results_window_5\split_0\mlp_model_trained.h5
# 6228/6228 [==============================] - 25s 4ms/step - loss: 34.8495 - val_loss: 31.1459
# Epoch 8/15
# 6216/6228 [============================>.] - ETA: 0s - loss: 32.8726
# Epoch 00008: val_loss improved from 31.14589 to 30.58967, saving model to ../results/experiment_set_20_time_window\results_window_5\split_0\mlp_model_trained.h5
# 6228/6228 [==============================] - 25s 4ms/step - loss: 32.8763 - val_loss: 30.5897
# Epoch 9/15
# 6225/6228 [============================>.] - ETA: 0s - loss: 31.2263
# Epoch 00009: val_loss improved from 30.58967 to 29.92464, saving model to ../results/experiment_set_20_time_window\results_window_5\split_0\mlp_model_trained.h5
# 6228/6228 [==============================] - 26s 4ms/step - loss: 31.2254 - val_loss: 29.9246
# Epoch 10/15
# 6216/6228 [============================>.] - ETA: 0s - loss: 30.0361
# Epoch 00010: val_loss improved from 29.92464 to 27.17695, saving model to ../results/experiment_set_20_time_window\results_window_5\split_0\mlp_model_trained.h5
# 6228/6228 [==============================] - 25s 4ms/step - loss: 30.0315 - val_loss: 27.1770
# Epoch 11/15
# 6225/6228 [============================>.] - ETA: 0s - loss: 28.4169
# Epoch 00011: val_loss did not improve from 27.17695
# 6228/6228 [==============================] - 24s 4ms/step - loss: 28.4161 - val_loss: 27.2491
# Epoch 12/15
# 6220/6228 [============================>.] - ETA: 0s - loss: 27.7372
# Epoch 00012: val_loss did not improve from 27.17695
# 6228/6228 [==============================] - 25s 4ms/step - loss: 27.7315 - val_loss: 27.3387
# Epoch 13/15
# 6224/6228 [============================>.] - ETA: 0s - loss: 26.7445
# Epoch 00013: val_loss improved from 27.17695 to 23.36454, saving model to ../results/experiment_set_20_time_window\results_window_5\split_0\mlp_model_trained.h5
# 6228/6228 [==============================] - 25s 4ms/step - loss: 26.7447 - val_loss: 23.3645
# Epoch 14/15
# 6218/6228 [============================>.] - ETA: 0s - loss: 26.0399
# Epoch 00014: val_loss did not improve from 23.36454
# 6228/6228 [==============================] - 26s 4ms/step - loss: 26.0385 - val_loss: 23.6271
# Epoch 15/15
# 6228/6228 [==============================] - ETA: 0s - loss: 25.3022
# Epoch 00015: val_loss did not improve from 23.36454
# 6228/6228 [==============================] - 25s 4ms/step - loss: 25.3022 - val_loss: 25.2193
# Saved object to file: ../results/experiment_set_20_time_window\results_window_5\split_0\history_0.pkl
# Test set:
# MSE: 137.24
# RMSE: 11.72
# CMAPSS score: 2.94
#
# Saved object to file: ../results/experiment_set_20_time_window\results_window_5\split_1\scaler.pkl
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_25 (Dense)             (None, 256)               6656
# _________________________________________________________________
# dense_26 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dense_27 (Dense)             (None, 512)               131584
# _________________________________________________________________
# dense_28 (Dense)             (None, 64)                32832
# _________________________________________________________________
# dense_29 (Dense)             (None, 1)                 65
# =================================================================
# Total params: 236,929
# Trainable params: 236,929
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/15
# 6216/6228 [============================>.] - ETA: 0s - loss: 168.4538
# Epoch 00001: val_loss improved from inf to 64.95164, saving model to ../results/experiment_set_20_time_window\results_window_5\split_1\mlp_model_trained.h5
# 6228/6228 [==============================] - 24s 4ms/step - loss: 168.2560 - val_loss: 64.9516
# Epoch 2/15
# 6213/6228 [============================>.] - ETA: 0s - loss: 54.3089
# Epoch 00002: val_loss improved from 64.95164 to 50.26463, saving model to ../results/experiment_set_20_time_window\results_window_5\split_1\mlp_model_trained.h5
# 6228/6228 [==============================] - 24s 4ms/step - loss: 54.2886 - val_loss: 50.2646
# Epoch 3/15
# 6217/6228 [============================>.] - ETA: 0s - loss: 46.8496
# Epoch 00003: val_loss improved from 50.26463 to 39.94284, saving model to ../results/experiment_set_20_time_window\results_window_5\split_1\mlp_model_trained.h5
# 6228/6228 [==============================] - 24s 4ms/step - loss: 46.8450 - val_loss: 39.9428
# Epoch 4/15
# 6225/6228 [============================>.] - ETA: 0s - loss: 42.3108
# Epoch 00004: val_loss did not improve from 39.94284
# 6228/6228 [==============================] - 24s 4ms/step - loss: 42.3123 - val_loss: 56.4126
# Epoch 5/15
# 6216/6228 [============================>.] - ETA: 0s - loss: 38.9760
# Epoch 00005: val_loss improved from 39.94284 to 38.17572, saving model to ../results/experiment_set_20_time_window\results_window_5\split_1\mlp_model_trained.h5
# 6228/6228 [==============================] - 24s 4ms/step - loss: 38.9746 - val_loss: 38.1757
# Epoch 6/15
# 6221/6228 [============================>.] - ETA: 0s - loss: 36.0070
# Epoch 00006: val_loss did not improve from 38.17572
# 6228/6228 [==============================] - 24s 4ms/step - loss: 36.0063 - val_loss: 44.2283
# Epoch 7/15
# 6215/6228 [============================>.] - ETA: 0s - loss: 33.6375
# Epoch 00007: val_loss improved from 38.17572 to 34.82781, saving model to ../results/experiment_set_20_time_window\results_window_5\split_1\mlp_model_trained.h5
# 6228/6228 [==============================] - 25s 4ms/step - loss: 33.6358 - val_loss: 34.8278
# Epoch 8/15
# 6216/6228 [============================>.] - ETA: 0s - loss: 31.9663
# Epoch 00008: val_loss improved from 34.82781 to 29.21903, saving model to ../results/experiment_set_20_time_window\results_window_5\split_1\mlp_model_trained.h5
# 6228/6228 [==============================] - 25s 4ms/step - loss: 31.9639 - val_loss: 29.2190
# Epoch 9/15
# 6215/6228 [============================>.] - ETA: 0s - loss: 30.4802
# Epoch 00009: val_loss did not improve from 29.21903
# 6228/6228 [==============================] - 24s 4ms/step - loss: 30.4860 - val_loss: 49.2481
# Epoch 10/15
# 6221/6228 [============================>.] - ETA: 0s - loss: 29.2880
# Epoch 00010: val_loss improved from 29.21903 to 23.91743, saving model to ../results/experiment_set_20_time_window\results_window_5\split_1\mlp_model_trained.h5
# 6228/6228 [==============================] - 26s 4ms/step - loss: 29.2821 - val_loss: 23.9174
# Epoch 11/15
# 6217/6228 [============================>.] - ETA: 0s - loss: 27.9865
# Epoch 00011: val_loss did not improve from 23.91743
# 6228/6228 [==============================] - 25s 4ms/step - loss: 27.9863 - val_loss: 25.4762
# Epoch 12/15
# 6224/6228 [============================>.] - ETA: 0s - loss: 27.3090
# Epoch 00012: val_loss did not improve from 23.91743
# 6228/6228 [==============================] - 24s 4ms/step - loss: 27.3111 - val_loss: 33.6035
# Epoch 13/15
# 6214/6228 [============================>.] - ETA: 0s - loss: 26.2785
# Epoch 00013: val_loss did not improve from 23.91743
# 6228/6228 [==============================] - 24s 4ms/step - loss: 26.2801 - val_loss: 35.9311
# Epoch 14/15
# 6216/6228 [============================>.] - ETA: 0s - loss: 25.5153
# Epoch 00014: val_loss improved from 23.91743 to 23.62614, saving model to ../results/experiment_set_20_time_window\results_window_5\split_1\mlp_model_trained.h5
# 6228/6228 [==============================] - 24s 4ms/step - loss: 25.5209 - val_loss: 23.6261
# Epoch 15/15
# 6214/6228 [============================>.] - ETA: 0s - loss: 24.6171
# Epoch 00015: val_loss did not improve from 23.62614
# 6228/6228 [==============================] - 24s 4ms/step - loss: 24.6191 - val_loss: 24.8188
# Saved object to file: ../results/experiment_set_20_time_window\results_window_5\split_1\history_1.pkl
# Test set:
# MSE: 149.07
# RMSE: 12.21
# CMAPSS score: 3.02
#
# Saved object to file: ../results/experiment_set_20_time_window\results_window_5\split_2\scaler.pkl
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_30 (Dense)             (None, 256)               6656
# _________________________________________________________________
# dense_31 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dense_32 (Dense)             (None, 512)               131584
# _________________________________________________________________
# dense_33 (Dense)             (None, 64)                32832
# _________________________________________________________________
# dense_34 (Dense)             (None, 1)                 65
# =================================================================
# Total params: 236,929
# Trainable params: 236,929
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/15
# 6218/6228 [============================>.] - ETA: 0s - loss: 165.8091
# Epoch 00001: val_loss improved from inf to 74.97901, saving model to ../results/experiment_set_20_time_window\results_window_5\split_2\mlp_model_trained.h5
# 6228/6228 [==============================] - 25s 4ms/step - loss: 165.6608 - val_loss: 74.9790
# Epoch 2/15
# 6220/6228 [============================>.] - ETA: 0s - loss: 54.0049
# Epoch 00002: val_loss improved from 74.97901 to 48.46617, saving model to ../results/experiment_set_20_time_window\results_window_5\split_2\mlp_model_trained.h5
# 6228/6228 [==============================] - 24s 4ms/step - loss: 54.0018 - val_loss: 48.4662
# Epoch 3/15
# 6225/6228 [============================>.] - ETA: 0s - loss: 46.9092
# Epoch 00003: val_loss improved from 48.46617 to 43.59621, saving model to ../results/experiment_set_20_time_window\results_window_5\split_2\mlp_model_trained.h5
# 6228/6228 [==============================] - 25s 4ms/step - loss: 46.9073 - val_loss: 43.5962
# Epoch 4/15
# 6224/6228 [============================>.] - ETA: 0s - loss: 42.4385
# Epoch 00004: val_loss did not improve from 43.59621
# 6228/6228 [==============================] - 25s 4ms/step - loss: 42.4386 - val_loss: 44.3045
# Epoch 5/15
# 6227/6228 [============================>.] - ETA: 0s - loss: 39.2090
# Epoch 00005: val_loss improved from 43.59621 to 39.63857, saving model to ../results/experiment_set_20_time_window\results_window_5\split_2\mlp_model_trained.h5
# 6228/6228 [==============================] - 25s 4ms/step - loss: 39.2087 - val_loss: 39.6386
# Epoch 6/15
# 6223/6228 [============================>.] - ETA: 0s - loss: 36.7437
# Epoch 00006: val_loss did not improve from 39.63857
# 6228/6228 [==============================] - 25s 4ms/step - loss: 36.7416 - val_loss: 40.2634
# Epoch 7/15
# 6215/6228 [============================>.] - ETA: 0s - loss: 34.4783
# Epoch 00007: val_loss improved from 39.63857 to 37.85854, saving model to ../results/experiment_set_20_time_window\results_window_5\split_2\mlp_model_trained.h5
# 6228/6228 [==============================] - 25s 4ms/step - loss: 34.4801 - val_loss: 37.8585
# Epoch 8/15
# 6222/6228 [============================>.] - ETA: 0s - loss: 32.5431
# Epoch 00008: val_loss improved from 37.85854 to 35.20229, saving model to ../results/experiment_set_20_time_window\results_window_5\split_2\mlp_model_trained.h5
# 6228/6228 [==============================] - 25s 4ms/step - loss: 32.5405 - val_loss: 35.2023
# Epoch 9/15
# 6220/6228 [============================>.] - ETA: 0s - loss: 31.0969
# Epoch 00009: val_loss did not improve from 35.20229
# 6228/6228 [==============================] - 25s 4ms/step - loss: 31.0989 - val_loss: 36.8622
# Epoch 10/15
# 6228/6228 [==============================] - ETA: 0s - loss: 29.5933
# Epoch 00010: val_loss improved from 35.20229 to 29.11710, saving model to ../results/experiment_set_20_time_window\results_window_5\split_2\mlp_model_trained.h5
# 6228/6228 [==============================] - 25s 4ms/step - loss: 29.5933 - val_loss: 29.1171
# Epoch 11/15
# 6224/6228 [============================>.] - ETA: 0s - loss: 28.1632
# Epoch 00011: val_loss did not improve from 29.11710
# 6228/6228 [==============================] - 25s 4ms/step - loss: 28.1612 - val_loss: 37.8468
# Epoch 12/15
# 6220/6228 [============================>.] - ETA: 0s - loss: 27.0586
# Epoch 00012: val_loss improved from 29.11710 to 23.21140, saving model to ../results/experiment_set_20_time_window\results_window_5\split_2\mlp_model_trained.h5
# 6228/6228 [==============================] - 25s 4ms/step - loss: 27.0541 - val_loss: 23.2114
# Epoch 13/15
# 6227/6228 [============================>.] - ETA: 0s - loss: 26.2510
# Epoch 00013: val_loss did not improve from 23.21140
# 6228/6228 [==============================] - 25s 4ms/step - loss: 26.2511 - val_loss: 35.4924
# Epoch 14/15
# 6221/6228 [============================>.] - ETA: 0s - loss: 25.6467
# Epoch 00014: val_loss improved from 23.21140 to 23.07897, saving model to ../results/experiment_set_20_time_window\results_window_5\split_2\mlp_model_trained.h5
# 6228/6228 [==============================] - 24s 4ms/step - loss: 25.6455 - val_loss: 23.0790
# Epoch 15/15
# 6218/6228 [============================>.] - ETA: 0s - loss: 24.6936
# Epoch 00015: val_loss improved from 23.07897 to 22.21136, saving model to ../results/experiment_set_20_time_window\results_window_5\split_2\mlp_model_trained.h5
# 6228/6228 [==============================] - 24s 4ms/step - loss: 24.6919 - val_loss: 22.2114
# Saved object to file: ../results/experiment_set_20_time_window\results_window_5\split_2\history_2.pkl
# Test set:
# MSE: 148.18
# RMSE: 12.17
# CMAPSS score: 2.96
#
# MSE: mean = 144.83   stddev = 5.38
# RMSE: mean = 12.03   stddev = 0.22
# CMAPSS: mean = 2.97   stddev = 0.03
# Saved object to file: ../results/experiment_set_20_time_window\results_window_10\split_0\scaler.pkl
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_35 (Dense)             (None, 256)               13056
# _________________________________________________________________
# dense_36 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dense_37 (Dense)             (None, 512)               131584
# _________________________________________________________________
# dense_38 (Dense)             (None, 64)                32832
# _________________________________________________________________
# dense_39 (Dense)             (None, 1)                 65
# =================================================================
# Total params: 243,329
# Trainable params: 243,329
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/15
# 6220/6228 [============================>.] - ETA: 0s - loss: 171.9809
# Epoch 00001: val_loss improved from inf to 63.32217, saving model to ../results/experiment_set_20_time_window\results_window_10\split_0\mlp_model_trained.h5
# 6228/6228 [==============================] - 26s 4ms/step - loss: 171.8539 - val_loss: 63.3222
# Epoch 2/15
# 6224/6228 [============================>.] - ETA: 0s - loss: 56.7190
# Epoch 00002: val_loss did not improve from 63.32217
# 6228/6228 [==============================] - 26s 4ms/step - loss: 56.7135 - val_loss: 67.8201
# Epoch 3/15
# 6220/6228 [============================>.] - ETA: 0s - loss: 48.4122
# Epoch 00003: val_loss improved from 63.32217 to 41.87369, saving model to ../results/experiment_set_20_time_window\results_window_10\split_0\mlp_model_trained.h5
# 6228/6228 [==============================] - 27s 4ms/step - loss: 48.4070 - val_loss: 41.8737
# Epoch 4/15
# 6226/6228 [============================>.] - ETA: 0s - loss: 42.7576
# Epoch 00004: val_loss improved from 41.87369 to 35.93774, saving model to ../results/experiment_set_20_time_window\results_window_10\split_0\mlp_model_trained.h5
# 6228/6228 [==============================] - 26s 4ms/step - loss: 42.7571 - val_loss: 35.9377
# Epoch 5/15
# 6219/6228 [============================>.] - ETA: 0s - loss: 38.5962
# Epoch 00005: val_loss did not improve from 35.93774
# 6228/6228 [==============================] - 26s 4ms/step - loss: 38.5913 - val_loss: 41.1191
# Epoch 6/15
# 6221/6228 [============================>.] - ETA: 0s - loss: 35.7591
# Epoch 00006: val_loss improved from 35.93774 to 35.20184, saving model to ../results/experiment_set_20_time_window\results_window_10\split_0\mlp_model_trained.h5
# 6228/6228 [==============================] - 26s 4ms/step - loss: 35.7556 - val_loss: 35.2018
# Epoch 7/15
# 6218/6228 [============================>.] - ETA: 0s - loss: 33.4453
# Epoch 00007: val_loss improved from 35.20184 to 31.84130, saving model to ../results/experiment_set_20_time_window\results_window_10\split_0\mlp_model_trained.h5
# 6228/6228 [==============================] - 26s 4ms/step - loss: 33.4424 - val_loss: 31.8413
# Epoch 8/15
# 6224/6228 [============================>.] - ETA: 0s - loss: 31.7274
# Epoch 00008: val_loss did not improve from 31.84130
# 6228/6228 [==============================] - 25s 4ms/step - loss: 31.7259 - val_loss: 32.4724
# Epoch 9/15
# 6222/6228 [============================>.] - ETA: 0s - loss: 29.9465
# Epoch 00009: val_loss did not improve from 31.84130
# 6228/6228 [==============================] - 26s 4ms/step - loss: 29.9492 - val_loss: 42.5107
# Epoch 10/15
# 6218/6228 [============================>.] - ETA: 0s - loss: 28.6761
# Epoch 00010: val_loss did not improve from 31.84130
# 6228/6228 [==============================] - 25s 4ms/step - loss: 28.6740 - val_loss: 36.0446
# Epoch 11/15
# 6224/6228 [============================>.] - ETA: 0s - loss: 27.7787
# Epoch 00011: val_loss did not improve from 31.84130
# 6228/6228 [==============================] - 26s 4ms/step - loss: 27.7793 - val_loss: 40.0183
# Epoch 12/15
# 6227/6228 [============================>.] - ETA: 0s - loss: 26.5805
# Epoch 00012: val_loss did not improve from 31.84130
# 6228/6228 [==============================] - 26s 4ms/step - loss: 26.5804 - val_loss: 48.8918
# Epoch 00012: early stopping
# Saved object to file: ../results/experiment_set_20_time_window\results_window_10\split_0\history_0.pkl
# Test set:
# MSE: 152.84
# RMSE: 12.36
# CMAPSS score: 3.03
#
# Saved object to file: ../results/experiment_set_20_time_window\results_window_10\split_1\scaler.pkl
# Model: "sequential_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_40 (Dense)             (None, 256)               13056
# _________________________________________________________________
# dense_41 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dense_42 (Dense)             (None, 512)               131584
# _________________________________________________________________
# dense_43 (Dense)             (None, 64)                32832
# _________________________________________________________________
# dense_44 (Dense)             (None, 1)                 65
# =================================================================
# Total params: 243,329
# Trainable params: 243,329
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/15
# 6218/6228 [============================>.] - ETA: 0s - loss: 171.0071
# Epoch 00001: val_loss improved from inf to 57.82916, saving model to ../results/experiment_set_20_time_window\results_window_10\split_1\mlp_model_trained.h5
# 6228/6228 [==============================] - 25s 4ms/step - loss: 170.8462 - val_loss: 57.8292
# Epoch 2/15
# 6222/6228 [============================>.] - ETA: 0s - loss: 55.9367
# Epoch 00002: val_loss improved from 57.82916 to 51.07160, saving model to ../results/experiment_set_20_time_window\results_window_10\split_1\mlp_model_trained.h5
# 6228/6228 [==============================] - 25s 4ms/step - loss: 55.9337 - val_loss: 51.0716
# Epoch 3/15
# 6223/6228 [============================>.] - ETA: 0s - loss: 47.9116
# Epoch 00003: val_loss improved from 51.07160 to 45.41936, saving model to ../results/experiment_set_20_time_window\results_window_10\split_1\mlp_model_trained.h5
# 6228/6228 [==============================] - 25s 4ms/step - loss: 47.9078 - val_loss: 45.4194
# Epoch 4/15
# 6220/6228 [============================>.] - ETA: 0s - loss: 42.6063
# Epoch 00004: val_loss did not improve from 45.41936
# 6228/6228 [==============================] - 25s 4ms/step - loss: 42.6079 - val_loss: 71.9997
# Epoch 5/15
# 6223/6228 [============================>.] - ETA: 0s - loss: 39.1754
# Epoch 00005: val_loss improved from 45.41936 to 40.27008, saving model to ../results/experiment_set_20_time_window\results_window_10\split_1\mlp_model_trained.h5
# 6228/6228 [==============================] - 25s 4ms/step - loss: 39.1756 - val_loss: 40.2701
# Epoch 6/15
# 6217/6228 [============================>.] - ETA: 0s - loss: 36.4089
# Epoch 00006: val_loss did not improve from 40.27008
# 6228/6228 [==============================] - 25s 4ms/step - loss: 36.4017 - val_loss: 51.0645
# Epoch 7/15
# 6225/6228 [============================>.] - ETA: 0s - loss: 34.0794
# Epoch 00007: val_loss improved from 40.27008 to 32.65273, saving model to ../results/experiment_set_20_time_window\results_window_10\split_1\mlp_model_trained.h5
# 6228/6228 [==============================] - 26s 4ms/step - loss: 34.0777 - val_loss: 32.6527
# Epoch 8/15
# 6221/6228 [============================>.] - ETA: 0s - loss: 31.9467
# Epoch 00008: val_loss did not improve from 32.65273
# 6228/6228 [==============================] - 26s 4ms/step - loss: 31.9525 - val_loss: 38.4326
# Epoch 9/15
# 6227/6228 [============================>.] - ETA: 0s - loss: 30.3985
# Epoch 00009: val_loss improved from 32.65273 to 26.80365, saving model to ../results/experiment_set_20_time_window\results_window_10\split_1\mlp_model_trained.h5
# 6228/6228 [==============================] - 26s 4ms/step - loss: 30.3982 - val_loss: 26.8036
# Epoch 10/15
# 6217/6228 [============================>.] - ETA: 0s - loss: 29.0290
# Epoch 00010: val_loss did not improve from 26.80365
# 6228/6228 [==============================] - 26s 4ms/step - loss: 29.0290 - val_loss: 28.6029
# Epoch 11/15
# 6224/6228 [============================>.] - ETA: 0s - loss: 27.8903
# Epoch 00011: val_loss did not improve from 26.80365
# 6228/6228 [==============================] - 25s 4ms/step - loss: 27.8909 - val_loss: 34.0608
# Epoch 12/15
# 6225/6228 [============================>.] - ETA: 0s - loss: 26.8277
# Epoch 00012: val_loss improved from 26.80365 to 26.49386, saving model to ../results/experiment_set_20_time_window\results_window_10\split_1\mlp_model_trained.h5
# 6228/6228 [==============================] - 26s 4ms/step - loss: 26.8256 - val_loss: 26.4939
# Epoch 13/15
# 6217/6228 [============================>.] - ETA: 0s - loss: 25.9067
# Epoch 00013: val_loss did not improve from 26.49386
# 6228/6228 [==============================] - 26s 4ms/step - loss: 25.9209 - val_loss: 33.0291
# Epoch 14/15
# 6215/6228 [============================>.] - ETA: 0s - loss: 25.1355
# Epoch 00014: val_loss improved from 26.49386 to 22.14764, saving model to ../results/experiment_set_20_time_window\results_window_10\split_1\mlp_model_trained.h5
# 6228/6228 [==============================] - 25s 4ms/step - loss: 25.1293 - val_loss: 22.1476
# Epoch 15/15
# 6222/6228 [============================>.] - ETA: 0s - loss: 24.3814
# Epoch 00015: val_loss did not improve from 22.14764
# 6228/6228 [==============================] - 26s 4ms/step - loss: 24.3825 - val_loss: 31.9497
# Saved object to file: ../results/experiment_set_20_time_window\results_window_10\split_1\history_1.pkl
# Test set:
# MSE: 151.88
# RMSE: 12.32
# CMAPSS score: 2.97
#
# Saved object to file: ../results/experiment_set_20_time_window\results_window_10\split_2\scaler.pkl
# Model: "sequential_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_45 (Dense)             (None, 256)               13056
# _________________________________________________________________
# dense_46 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dense_47 (Dense)             (None, 512)               131584
# _________________________________________________________________
# dense_48 (Dense)             (None, 64)                32832
# _________________________________________________________________
# dense_49 (Dense)             (None, 1)                 65
# =================================================================
# Total params: 243,329
# Trainable params: 243,329
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/15
# 6227/6228 [============================>.] - ETA: 0s - loss: 182.2173
# Epoch 00001: val_loss improved from inf to 67.50665, saving model to ../results/experiment_set_20_time_window\results_window_10\split_2\mlp_model_trained.h5
# 6228/6228 [==============================] - 25s 4ms/step - loss: 182.2149 - val_loss: 67.5066
# Epoch 2/15
# 6217/6228 [============================>.] - ETA: 0s - loss: 54.1890
# Epoch 00002: val_loss improved from 67.50665 to 58.20761, saving model to ../results/experiment_set_20_time_window\results_window_10\split_2\mlp_model_trained.h5
# 6228/6228 [==============================] - 26s 4ms/step - loss: 54.1758 - val_loss: 58.2076
# Epoch 3/15
# 6227/6228 [============================>.] - ETA: 0s - loss: 45.7382
# Epoch 00003: val_loss improved from 58.20761 to 52.93613, saving model to ../results/experiment_set_20_time_window\results_window_10\split_2\mlp_model_trained.h5
# 6228/6228 [==============================] - 26s 4ms/step - loss: 45.7381 - val_loss: 52.9361
# Epoch 4/15
# 6219/6228 [============================>.] - ETA: 0s - loss: 40.6983
# Epoch 00004: val_loss improved from 52.93613 to 43.15315, saving model to ../results/experiment_set_20_time_window\results_window_10\split_2\mlp_model_trained.h5
# 6228/6228 [==============================] - 26s 4ms/step - loss: 40.6894 - val_loss: 43.1531
# Epoch 5/15
# 6225/6228 [============================>.] - ETA: 0s - loss: 37.0139
# Epoch 00005: val_loss improved from 43.15315 to 35.39185, saving model to ../results/experiment_set_20_time_window\results_window_10\split_2\mlp_model_trained.h5
# 6228/6228 [==============================] - 25s 4ms/step - loss: 37.0127 - val_loss: 35.3919
# Epoch 6/15
# 6227/6228 [============================>.] - ETA: 0s - loss: 34.3220
# Epoch 00006: val_loss did not improve from 35.39185
# 6228/6228 [==============================] - 25s 4ms/step - loss: 34.3226 - val_loss: 39.5537
# Epoch 7/15
# 6224/6228 [============================>.] - ETA: 0s - loss: 32.3581
# ...
# Total params: 256,129
# Trainable params: 256,129
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/15
# 6228/6228 [==============================] - ETA: 0s - loss: 171.4983WARNING:tensorflow:Callbacks method `on_test_batch_end` is slow compared to the batch time (batch time: 0.0000s vs `on_test_batch_end` time: 0.0040s). Check your callbacks.
#
# Epoch 00001: val_loss improved from inf to 73.65319, saving model to ../results/experiment_set_20_time_window\results_window_20\split_0\mlp_model_trained.h5
# 6228/6228 [==============================] - 27s 4ms/step - loss: 171.4983 - val_loss: 73.6532
# Epoch 2/15
# 6222/6228 [============================>.] - ETA: 0s - loss: 53.1234
# Epoch 00002: val_loss improved from 73.65319 to 60.44469, saving model to ../results/experiment_set_20_time_window\results_window_20\split_0\mlp_model_trained.h5
# 6228/6228 [==============================] - 26s 4ms/step - loss: 53.1173 - val_loss: 60.4447
# Epoch 3/15
# 6227/6228 [============================>.] - ETA: 0s - loss: 45.1344
# Epoch 00003: val_loss improved from 60.44469 to 47.34208, saving model to ../results/experiment_set_20_time_window\results_window_20\split_0\mlp_model_trained.h5
# 6228/6228 [==============================] - 26s 4ms/step - loss: 45.1342 - val_loss: 47.3421
# Epoch 4/15
# 6217/6228 [============================>.] - ETA: 0s - loss: 39.7617
# Epoch 00004: val_loss improved from 47.34208 to 39.02502, saving model to ../results/experiment_set_20_time_window\results_window_20\split_0\mlp_model_trained.h5
# 6228/6228 [==============================] - 26s 4ms/step - loss: 39.7539 - val_loss: 39.0250
# Epoch 5/15
# 6217/6228 [============================>.] - ETA: 0s - loss: 36.4629
# Epoch 00005: val_loss did not improve from 39.02502
# 6228/6228 [==============================] - 26s 4ms/step - loss: 36.4631 - val_loss: 56.8279
# Epoch 6/15
# 6224/6228 [============================>.] - ETA: 0s - loss: 33.5119
# Epoch 00006: val_loss improved from 39.02502 to 37.20206, saving model to ../results/experiment_set_20_time_window\results_window_20\split_0\mlp_model_trained.h5
# 6228/6228 [==============================] - 26s 4ms/step - loss: 33.5118 - val_loss: 37.2021
# Epoch 7/15
# 6227/6228 [============================>.] - ETA: 0s - loss: 32.0659
# Epoch 00007: val_loss improved from 37.20206 to 30.95571, saving model to ../results/experiment_set_20_time_window\results_window_20\split_0\mlp_model_trained.h5
# 6228/6228 [==============================] - 26s 4ms/step - loss: 32.0658 - val_loss: 30.9557
# Epoch 8/15
# 6216/6228 [============================>.] - ETA: 0s - loss: 30.1742
# Epoch 00008: val_loss did not improve from 30.95571
# 6228/6228 [==============================] - 25s 4ms/step - loss: 30.1746 - val_loss: 37.8755
# Epoch 9/15
# 6228/6228 [==============================] - ETA: 0s - loss: 28.6961
# Epoch 00009: val_loss did not improve from 30.95571
# 6228/6228 [==============================] - 25s 4ms/step - loss: 28.6961 - val_loss: 37.1839
# Epoch 10/15
# 6226/6228 [============================>.] - ETA: 0s - loss: 27.4250
# Epoch 00010: val_loss did not improve from 30.95571
# 6228/6228 [==============================] - 25s 4ms/step - loss: 27.4252 - val_loss: 39.4330
# Epoch 11/15
# 6228/6228 [==============================] - ETA: 0s - loss: 26.6723
# Epoch 00011: val_loss improved from 30.95571 to 26.36423, saving model to ../results/experiment_set_20_time_window\results_window_20\split_0\mlp_model_trained.h5
# 6228/6228 [==============================] - 27s 4ms/step - loss: 26.6723 - val_loss: 26.3642
# Epoch 12/15
# 6215/6228 [============================>.] - ETA: 0s - loss: 25.6316
# Epoch 00012: val_loss did not improve from 26.36423
# 6228/6228 [==============================] - 26s 4ms/step - loss: 25.6351 - val_loss: 43.2849
# Epoch 13/15
# 6223/6228 [============================>.] - ETA: 0s - loss: 25.1349
# Epoch 00013: val_loss improved from 26.36423 to 22.61353, saving model to ../results/experiment_set_20_time_window\results_window_20\split_0\mlp_model_trained.h5
# 6228/6228 [==============================] - 26s 4ms/step - loss: 25.1332 - val_loss: 22.6135
# Epoch 14/15
# 6226/6228 [============================>.] - ETA: 0s - loss: 24.2519
# Epoch 00014: val_loss did not improve from 22.61353
# 6228/6228 [==============================] - 26s 4ms/step - loss: 24.2508 - val_loss: 36.4753
# Epoch 15/15
# 6217/6228 [============================>.] - ETA: 0s - loss: 23.7254
# Epoch 00015: val_loss did not improve from 22.61353
# 6228/6228 [==============================] - 26s 4ms/step - loss: 23.7248 - val_loss: 25.0706
# Saved object to file: ../results/experiment_set_20_time_window\results_window_20\split_0\history_0.pkl
# Test set:
# MSE: 170.06
# RMSE: 13.04
# CMAPSS score: 3.26
#
# Saved object to file: ../results/experiment_set_20_time_window\results_window_20\split_1\scaler.pkl
# Model: "sequential_14"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_70 (Dense)             (None, 256)               25856
# _________________________________________________________________
# dense_71 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dense_72 (Dense)             (None, 512)               131584
# _________________________________________________________________
# dense_73 (Dense)             (None, 64)                32832
# _________________________________________________________________
# dense_74 (Dense)             (None, 1)                 65
# =================================================================
# Total params: 256,129
# Trainable params: 256,129
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/15
# 6221/6228 [============================>.] - ETA: 0s - loss: 167.6957
# Epoch 00001: val_loss improved from inf to 73.49590, saving model to ../results/experiment_set_20_time_window\results_window_20\split_1\mlp_model_trained.h5
# 6228/6228 [==============================] - 26s 4ms/step - loss: 167.5882 - val_loss: 73.4959
# Epoch 2/15
# 6217/6228 [============================>.] - ETA: 0s - loss: 53.2053
# Epoch 00002: val_loss improved from 73.49590 to 60.66945, saving model to ../results/experiment_set_20_time_window\results_window_20\split_1\mlp_model_trained.h5
# 6228/6228 [==============================] - 27s 4ms/step - loss: 53.1916 - val_loss: 60.6695
# Epoch 3/15
# 6222/6228 [============================>.] - ETA: 0s - loss: 45.2812
# Epoch 00003: val_loss improved from 60.66945 to 59.20030, saving model to ../results/experiment_set_20_time_window\results_window_20\split_1\mlp_model_trained.h5
# 6228/6228 [==============================] - 27s 4ms/step - loss: 45.2816 - val_loss: 59.2003
# Epoch 4/15
# 6226/6228 [============================>.] - ETA: 0s - loss: 40.3771
# Epoch 00004: val_loss improved from 59.20030 to 37.28741, saving model to ../results/experiment_set_20_time_window\results_window_20\split_1\mlp_model_trained.h5
# 6228/6228 [==============================] - 26s 4ms/step - loss: 40.3768 - val_loss: 37.2874
# Epoch 5/15
# 6224/6228 [============================>.] - ETA: 0s - loss: 36.8174
# Epoch 00005: val_loss did not improve from 37.28741
# 6228/6228 [==============================] - 26s 4ms/step - loss: 36.8153 - val_loss: 39.9835
# Epoch 6/15
# 6226/6228 [============================>.] - ETA: 0s - loss: 34.3517
# Epoch 00006: val_loss did not improve from 37.28741
# 6228/6228 [==============================] - 26s 4ms/step - loss: 34.3507 - val_loss: 68.9028
# Epoch 7/15
# 6226/6228 [============================>.] - ETA: 0s - loss: 32.4503
# Epoch 00007: val_loss did not improve from 37.28741
# 6228/6228 [==============================] - 26s 4ms/step - loss: 32.4516 - val_loss: 45.8004
# Epoch 8/15
# 6216/6228 [============================>.] - ETA: 0s - loss: 30.9204
# Epoch 00008: val_loss improved from 37.28741 to 33.93471, saving model to ../results/experiment_set_20_time_window\results_window_20\split_1\mlp_model_trained.h5
# 6228/6228 [==============================] - 26s 4ms/step - loss: 30.9141 - val_loss: 33.9347
# Epoch 9/15
# 6226/6228 [============================>.] - ETA: 0s - loss: 29.0593
# Epoch 00009: val_loss improved from 33.93471 to 30.70922, saving model to ../results/experiment_set_20_time_window\results_window_20\split_1\mlp_model_trained.h5
# 6228/6228 [==============================] - 26s 4ms/step - loss: 29.0587 - val_loss: 30.7092
# Epoch 10/15
# 6219/6228 [============================>.] - ETA: 0s - loss: 27.9012
# Epoch 00010: val_loss improved from 30.70922 to 26.40379, saving model to ../results/experiment_set_20_time_window\results_window_20\split_1\mlp_model_trained.h5
# 6228/6228 [==============================] - 26s 4ms/step - loss: 27.8983 - val_loss: 26.4038
# Epoch 11/15
# 6224/6228 [============================>.] - ETA: 0s - loss: 27.1187
# Epoch 00011: val_loss did not improve from 26.40379
# 6228/6228 [==============================] - 25s 4ms/step - loss: 27.1181 - val_loss: 27.9724
# Epoch 12/15
# 6228/6228 [==============================] - ETA: 0s - loss: 26.0854
# Epoch 00012: val_loss did not improve from 26.40379
# 6228/6228 [==============================] - 25s 4ms/step - loss: 26.0854 - val_loss: 36.3631
# Epoch 13/15
# 6218/6228 [============================>.] - ETA: 0s - loss: 25.2233
# Epoch 00013: val_loss did not improve from 26.40379
# 6228/6228 [==============================] - 26s 4ms/step - loss: 25.2249 - val_loss: 79.6211
# Epoch 14/15
# 6226/6228 [============================>.] - ETA: 0s - loss: 24.7864
# Epoch 00014: val_loss did not improve from 26.40379
# 6228/6228 [==============================] - 26s 4ms/step - loss: 24.7862 - val_loss: 33.1384
# Epoch 15/15
# 6224/6228 [============================>.] - ETA: 0s - loss: 24.2805
# Epoch 00015: val_loss did not improve from 26.40379
# 6228/6228 [==============================] - 25s 4ms/step - loss: 24.2831 - val_loss: 33.9962
# Epoch 00015: early stopping
# Saved object to file: ../results/experiment_set_20_time_window\results_window_20\split_1\history_1.pkl
# Test set:
# MSE: 166.19
# RMSE: 12.89
# CMAPSS score: 3.18
#
# Saved object to file: ../results/experiment_set_20_time_window\results_window_20\split_2\scaler.pkl
# Model: "sequential_15"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_75 (Dense)             (None, 256)               25856
# _________________________________________________________________
# dense_76 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dense_77 (Dense)             (None, 512)               131584
# _________________________________________________________________
# dense_78 (Dense)             (None, 64)                32832
# _________________________________________________________________
# dense_79 (Dense)             (None, 1)                 65
# =================================================================
# Total params: 256,129
# Trainable params: 256,129
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/15
# 6218/6228 [============================>.] - ETA: 0s - loss: 171.4936
# Epoch 00001: val_loss improved from inf to 62.41745, saving model to ../results/experiment_set_20_time_window\results_window_20\split_2\mlp_model_trained.h5
# 6228/6228 [==============================] - 25s 4ms/step - loss: 171.3210 - val_loss: 62.4174
# Epoch 2/15
# 6221/6228 [============================>.] - ETA: 0s - loss: 54.9581
# Epoch 00002: val_loss improved from 62.41745 to 51.67692, saving model to ../results/experiment_set_20_time_window\results_window_20\split_2\mlp_model_trained.h5
# 6228/6228 [==============================] - 26s 4ms/step - loss: 54.9455 - val_loss: 51.6769
# Epoch 3/15
# 6222/6228 [============================>.] - ETA: 0s - loss: 45.7878
# Epoch 00003: val_loss improved from 51.67692 to 50.64684, saving model to ../results/experiment_set_20_time_window\results_window_20\split_2\mlp_model_trained.h5
# 6228/6228 [==============================] - 26s 4ms/step - loss: 45.7833 - val_loss: 50.6468
# Epoch 4/15
# 6220/6228 [============================>.] - ETA: 0s - loss: 40.9071
# Epoch 00004: val_loss improved from 50.64684 to 42.35412, saving model to ../results/experiment_set_20_time_window\results_window_20\split_2\mlp_model_trained.h5
# 6228/6228 [==============================] - 26s 4ms/step - loss: 40.9134 - val_loss: 42.3541
# Epoch 5/15
# 6222/6228 [============================>.] - ETA: 0s - loss: 37.4279
# Epoch 00005: val_loss did not improve from 42.35412
# 6228/6228 [==============================] - 26s 4ms/step - loss: 37.4260 - val_loss: 49.7621
# Epoch 6/15
# 6226/6228 [============================>.] - ETA: 0s - loss: 34.8843
# Epoch 00006: val_loss improved from 42.35412 to 41.69927, saving model to ../results/experiment_set_20_time_window\results_window_20\split_2\mlp_model_trained.h5
# 6228/6228 [==============================] - 26s 4ms/step - loss: 34.8850 - val_loss: 41.6993
# Epoch 7/15
# 6219/6228 [============================>.] - ETA: 0s - loss: 33.2246
# Epoch 00007: val_loss improved from 41.69927 to 41.22489, saving model to ../results/experiment_set_20_time_window\results_window_20\split_2\mlp_model_trained.h5
# 6228/6228 [==============================] - 26s 4ms/step - loss: 33.2226 - val_loss: 41.2249
# Epoch 8/15
# 6228/6228 [==============================] - ETA: 0s - loss: 31.2789
# Epoch 00008: val_loss improved from 41.22489 to 30.79712, saving model to ../results/experiment_set_20_time_window\results_window_20\split_2\mlp_model_trained.h5
# 6228/6228 [==============================] - 26s 4ms/step - loss: 31.2789 - val_loss: 30.7971
# Epoch 9/15
# 6224/6228 [============================>.] - ETA: 0s - loss: 29.6645
# Epoch 00009: val_loss did not improve from 30.79712
# 6228/6228 [==============================] - 26s 4ms/step - loss: 29.6637 - val_loss: 31.5885
# Epoch 10/15
# 6220/6228 [============================>.] - ETA: 0s - loss: 28.4605
# Epoch 00010: val_loss did not improve from 30.79712
# 6228/6228 [==============================] - 26s 4ms/step - loss: 28.4573 - val_loss: 53.0970
# Epoch 11/15
# 6226/6228 [============================>.] - ETA: 0s - loss: 27.6511
# Epoch 00011: val_loss improved from 30.79712 to 27.15764, saving model to ../results/experiment_set_20_time_window\results_window_20\split_2\mlp_model_trained.h5
# 6228/6228 [==============================] - 26s 4ms/step - loss: 27.6504 - val_loss: 27.1576
# Epoch 12/15
# 6226/6228 [============================>.] - ETA: 0s - loss: 26.5063
# Epoch 00012: val_loss did not improve from 27.15764
# 6228/6228 [==============================] - 26s 4ms/step - loss: 26.5069 - val_loss: 45.6261
# Epoch 13/15
# 6219/6228 [============================>.] - ETA: 0s - loss: 25.8435
# Epoch 00013: val_loss did not improve from 27.15764
# 6228/6228 [==============================] - 26s 4ms/step - loss: 25.8468 - val_loss: 38.3075
# Epoch 14/15
# 6226/6228 [============================>.] - ETA: 0s - loss: 25.1482
# Epoch 00014: val_loss improved from 27.15764 to 26.34542, saving model to ../results/experiment_set_20_time_window\results_window_20\split_2\mlp_model_trained.h5
# 6228/6228 [==============================] - 27s 4ms/step - loss: 25.1482 - val_loss: 26.3454
# Epoch 15/15
# 6222/6228 [============================>.] - ETA: 0s - loss: 24.3639
# Epoch 00015: val_loss did not improve from 26.34542
# 6228/6228 [==============================] - 26s 4ms/step - loss: 24.3625 - val_loss: 31.6939
# Saved object to file: ../results/experiment_set_20_time_window\results_window_20\split_2\history_2.pkl
# Test set:
# MSE: 158.80
# RMSE: 12.60
# CMAPSS score: 3.13
#
# MSE: mean = 165.02   stddev = 4.67
# RMSE: mean = 12.84   stddev = 0.18
# CMAPSS: mean = 3.19   stddev = 0.05

# %%
################################################
# Effect of time windowing (experiment set 21)
################################################
NUM_TRIALS = 3
EPOCHS = 15
BATCH_SIZE = 512

mlp_params = MLPConfigParams(layer_sizes=[256, 256, 512, 64], activation='tanh', dropout=0.0)
window_sizes = [5, 10, 15, 20]

results_file = os.path.join(output_path, "results_time_window.csv")
with open(results_file, "w") as file:
    file.write("window,mse,rmse,cmapss,mse(mean),mse(std),rmse(mean),rmse(std),cmapss(mean),cmapss(std)\n")

for w in window_sizes:
    results_folder = f"results_window_{w}"
    results_path = os.path.join(output_path, results_folder)
    if not os.path.exists(results_path):
        os.makedirs(results_path)
    
    with open(results_file, "a") as file:
        file.write(f"{w},")
    
    # Add time lags
    train_set_preproc = time_window_processing(train_set, w, selected_columns_with_unit, 
                                               drop_unit_col=False, remove_overlapped_windows=True) 
    
    # Validation split after engine number
    train_split, val_split = train_validation_split(train_set_preproc)
    
    x_train_split = train_split[[i for i in list(train_split.columns) if i != 'RUL']]
    x_holdout_split = val_split[[i for i in list(val_split.columns) if i != 'RUL']]
    
    y_train_split = train_split['RUL']
    y_holdout_split = val_split['RUL']
    
    mse_vals, rmse_vals, cmapss_vals = train_evaluate_mlp(
        x_train_split, y_train_split, 
        x_holdout_split, y_holdout_split,
        NUM_TRIALS, 
        mlp_params, 
        results_path, 
        EPOCHS, BATCH_SIZE,
        results_file=results_file)
# Out:
# Saved object to file: ../results/experiment_set_21_time_window\results_window_5\split_0\scaler.pkl
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 256)               6656
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               131584
# _________________________________________________________________
# dense_3 (Dense)              (None, 64)                32832
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 236,929
# Trainable params: 236,929
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/15
# 2076/2076 [==============================] - ETA: 0s - loss: 397.7574
# Epoch 00001: val_loss improved from inf to 89.96282, saving model to ../results/experiment_set_21_time_window\results_window_5\split_0\mlp_model_trained.h5
# 2076/2076 [==============================] - 9s 4ms/step - loss: 397.7574 - val_loss: 89.9628
# Epoch 2/15
# 2065/2076 [============================>.] - ETA: 0s - loss: 84.4429
# Epoch 00002: val_loss improved from 89.96282 to 71.99000, saving model to ../results/experiment_set_21_time_window\results_window_5\split_0\mlp_model_trained.h5
# 2076/2076 [==============================] - 9s 4ms/step - loss: 84.3770 - val_loss: 71.9900
# Epoch 3/15
# 2068/2076 [============================>.] - ETA: 0s - loss: 70.4799
# Epoch 00003: val_loss improved from 71.99000 to 64.62897, saving model to ../results/experiment_set_21_time_window\results_window_5\split_0\mlp_model_trained.h5
# 2076/2076 [==============================] - 9s 5ms/step - loss: 70.4630 - val_loss: 64.6290
# Epoch 4/15
# 2067/2076 [============================>.] - ETA: 0s - loss: 63.2964
# Epoch 00004: val_loss did not improve from 64.62897
# 2076/2076 [==============================] - 9s 4ms/step - loss: 63.3033 - val_loss: 64.7203
# Epoch 5/15
# 2071/2076 [============================>.] - ETA: 0s - loss: 57.9654
# Epoch 00005: val_loss improved from 64.62897 to 53.02818, saving model to ../results/experiment_set_21_time_window\results_window_5\split_0\mlp_model_trained.h5
# 2076/2076 [==============================] - 9s 4ms/step - loss: 57.9557 - val_loss: 53.0282
# Epoch 6/15
# 2067/2076 [============================>.] - ETA: 0s - loss: 54.9532
# Epoch 00006: val_loss did not improve from 53.02818
# 2076/2076 [==============================] - 9s 4ms/step - loss: 54.9480 - val_loss: 55.7051
# Epoch 7/15
# 2071/2076 [============================>.] - ETA: 0s - loss: 52.1838
# Epoch 00007: val_loss improved from 53.02818 to 45.47505, saving model to ../results/experiment_set_21_time_window\results_window_5\split_0\mlp_model_trained.h5
# 2076/2076 [==============================] - 9s 4ms/step - loss: 52.1778 - val_loss: 45.4751
# Epoch 8/15
# 2068/2076 [============================>.] - ETA: 0s - loss: 50.2312
# Epoch 00008: val_loss did not improve from 45.47505
# 2076/2076 [==============================] - 9s 4ms/step - loss: 50.2359 - val_loss: 50.8175
# Epoch 9/15
# 2063/2076 [============================>.] - ETA: 0s - loss: 48.0257
# Epoch 00009: val_loss improved from 45.47505 to 45.06034, saving model to ../results/experiment_set_21_time_window\results_window_5\split_0\mlp_model_trained.h5
# 2076/2076 [==============================] - 9s 5ms/step - loss: 47.9967 - val_loss: 45.0603
# Epoch 10/15
# 2064/2076 [============================>.] - ETA: 0s - loss: 46.3535
# Epoch 00010: val_loss improved from 45.06034 to 44.18168, saving model to ../results/experiment_set_21_time_window\results_window_5\split_0\mlp_model_trained.h5
# 2076/2076 [==============================] - 9s 4ms/step - loss: 46.3567 - val_loss: 44.1817
# Epoch 11/15
# 2070/2076 [============================>.] - ETA: 0s - loss: 44.1574
# Epoch 00011: val_loss improved from 44.18168 to 41.89262, saving model to ../results/experiment_set_21_time_window\results_window_5\split_0\mlp_model_trained.h5
# 2076/2076 [==============================] - 9s 4ms/step - loss: 44.1499 - val_loss: 41.8926
# Epoch 12/15
# 2063/2076 [============================>.] - ETA: 0s - loss: 43.6184
# Epoch 00012: val_loss did not improve from 41.89262
# 2076/2076 [==============================] - 9s 4ms/step - loss: 43.6409 - val_loss: 44.4684
# Epoch 13/15
# 2075/2076 [============================>.] - ETA: 0s - loss: 41.9991
# Epoch 00013: val_loss improved from 41.89262 to 38.14103, saving model to ../results/experiment_set_21_time_window\results_window_5\split_0\mlp_model_trained.h5
# 2076/2076 [==============================] - 9s 4ms/step - loss: 42.0020 - val_loss: 38.1410
# Epoch 14/15
# 2065/2076 [============================>.] - ETA: 0s - loss: 41.0587
# Epoch 00014: val_loss did not improve from 38.14103
# 2076/2076 [==============================] - 8s 4ms/step - loss: 41.0688 - val_loss: 51.0987
# Epoch 15/15
# 2071/2076 [============================>.] - ETA: 0s - loss: 39.5390
# Epoch 00015: val_loss did not improve from 38.14103
# 2076/2076 [==============================] - 8s 4ms/step - loss: 39.5501 - val_loss: 46.2799
# Saved object to file: ../results/experiment_set_21_time_window\results_window_5\split_0\history_0.pkl
# Test set:
# MSE: 150.08
# RMSE: 12.25
# CMAPSS score: 3.00
#
# Saved object to file: ../results/experiment_set_21_time_window\results_window_5\split_1\scaler.pkl
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_5 (Dense)              (None, 256)               6656
# _________________________________________________________________
# dense_6 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dense_7 (Dense)              (None, 512)               131584
# _________________________________________________________________
# dense_8 (Dense)              (None, 64)                32832
# _________________________________________________________________
# dense_9 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 236,929
# Trainable params: 236,929
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/15
# 2069/2076 [============================>.] - ETA: 0s - loss: 361.1265
# Epoch 00001: val_loss improved from inf to 102.67056, saving model to ../results/experiment_set_21_time_window\results_window_5\split_1\mlp_model_trained.h5
# 2076/2076 [==============================] - 9s 4ms/step - loss: 360.2617 - val_loss: 102.6706
# Epoch 2/15
# 2072/2076 [============================>.] - ETA: 0s - loss: 75.6878
# Epoch 00002: val_loss improved from 102.67056 to 69.96310, saving model to ../results/experiment_set_21_time_window\results_window_5\split_1\mlp_model_trained.h5
# 2076/2076 [==============================] - 9s 4ms/step - loss: 75.6766 - val_loss: 69.9631
# Epoch 3/15
# 2063/2076 [============================>.] - ETA: 0s - loss: 62.7575
# Epoch 00003: val_loss improved from 69.96310 to 64.64970, saving model to ../results/experiment_set_21_time_window\results_window_5\split_1\mlp_model_trained.h5
# 2076/2076 [==============================] - 9s 4ms/step - loss: 62.7204 - val_loss: 64.6497
# Epoch 4/15
# 2075/2076 [============================>.] - ETA: 0s - loss: 57.8187
# Epoch 00004: val_loss improved from 64.64970 to 54.39499, saving model to ../results/experiment_set_21_time_window\results_window_5\split_1\mlp_model_trained.h5
# 2076/2076 [==============================] - 9s 4ms/step - loss: 57.8196 - val_loss: 54.3950
# Epoch 5/15
# 2070/2076 [============================>.] - ETA: 0s - loss: 54.1126
# Epoch 00005: val_loss did not improve from 54.39499
# 2076/2076 [==============================] - 9s 4ms/step - loss: 54.1198 - val_loss: 57.0048
# Epoch 6/15
# 2069/2076 [============================>.] - ETA: 0s - loss: 51.1373
# Epoch 00006: val_loss improved from 54.39499 to 51.55354, saving model to ../results/experiment_set_21_time_window\results_window_5\split_1\mlp_model_trained.h5
# 2076/2076 [==============================] - 9s 4ms/step - loss: 51.1364 - val_loss: 51.5535
# Epoch 7/15
# 2076/2076 [==============================] - ETA: 0s - loss: 49.4405
# Epoch 00007: val_loss did not improve from 51.55354
# 2076/2076 [==============================] - 9s 4ms/step - loss: 49.4405 - val_loss: 52.9616
# Epoch 8/15
# 2066/2076 [============================>.] - ETA: 0s - loss: 46.7554
# Epoch 00008: val_loss improved from 51.55354 to 47.50620, saving model to ../results/experiment_set_21_time_window\results_window_5\split_1\mlp_model_trained.h5
# 2076/2076 [==============================] - 9s 4ms/step - loss: 46.7653 - val_loss: 47.5062
# Epoch 9/15
# 2071/2076 [============================>.] - ETA: 0s - loss: 45.0150
# Epoch 00009: val_loss improved from 47.50620 to 41.96069, saving model to ../results/experiment_set_21_time_window\results_window_5\split_1\mlp_model_trained.h5
# 2076/2076 [==============================] - 9s 4ms/step - loss: 45.0136 - val_loss: 41.9607
# Epoch 10/15
# 2066/2076 [============================>.] - ETA: 0s - loss: 43.8671
# Epoch 00010: val_loss did not improve from 41.96069
# 2076/2076 [==============================] - 9s 4ms/step - loss: 43.8510 - val_loss: 44.5583
# Epoch 11/15
# 2070/2076 [============================>.] - ETA: 0s - loss: 42.9751
# Epoch 00011: val_loss improved from 41.96069 to 40.42061, saving model to ../results/experiment_set_21_time_window\results_window_5\split_1\mlp_model_trained.h5
# 2076/2076 [==============================] - 9s 4ms/step - loss: 42.9718 - val_loss: 40.4206
# Epoch 12/15
# 2067/2076 [============================>.] - ETA: 0s - loss: 41.2621
# Epoch 00012: val_loss improved from 40.42061 to 37.83631, saving model to ../results/experiment_set_21_time_window\results_window_5\split_1\mlp_model_trained.h5
# 2076/2076 [==============================] - 9s 4ms/step - loss: 41.2473 - val_loss: 37.8363
# Epoch 13/15
# 2068/2076 [============================>.] - ETA: 0s - loss: 40.8313
# Epoch 00013: val_loss improved from 37.83631 to 36.19723, saving model to ../results/experiment_set_21_time_window\results_window_5\split_1\mlp_model_trained.h5
# 2076/2076 [==============================] - 9s 4ms/step - loss: 40.8243 - val_loss: 36.1972
# Epoch 14/15
# 2065/2076 [============================>.] - ETA: 0s - loss: 39.9393
# Epoch 00014: val_loss did not improve from 36.19723
# 2076/2076 [==============================] - 9s 4ms/step - loss: 39.9458 - val_loss: 44.0010
# Epoch 15/15
# 2076/2076 [==============================] - ETA: 0s - loss: 38.7168
# Epoch 00015: val_loss did not improve from 36.19723
# 2076/2076 [==============================] - 9s 4ms/step - loss: 38.7168 - val_loss: 39.6104
# Saved object to file: ../results/experiment_set_21_time_window\results_window_5\split_1\history_1.pkl
# Test set:
# MSE: 148.77
# RMSE: 12.20
# CMAPSS score: 3.00
#
# Saved object to file: ../results/experiment_set_21_time_window\results_window_5\split_2\scaler.pkl
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_10 (Dense)             (None, 256)               6656
# _________________________________________________________________
# dense_11 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dense_12 (Dense)             (None, 512)               131584
# _________________________________________________________________
# dense_13 (Dense)             (None, 64)                32832
# _________________________________________________________________
# dense_14 (Dense)             (None, 1)                 65
# =================================================================
# Total params: 236,929
# Trainable params: 236,929
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/15
# 2063/2076 [============================>.] - ETA: 0s - loss: 358.8609
# Epoch 00001: val_loss improved from inf to 95.52923, saving model to ../results/experiment_set_21_time_window\results_window_5\split_2\mlp_model_trained.h5
# 2076/2076 [==============================] - 9s 4ms/step - loss: 357.2048 - val_loss: 95.5292
# Epoch 2/15
# 2069/2076 [============================>.] - ETA: 0s - loss: 80.2898
# Epoch 00002: val_loss improved from 95.52923 to 65.79289, saving model to ../results/experiment_set_21_time_window\results_window_5\split_2\mlp_model_trained.h5
# 2076/2076 [==============================] - 9s 4ms/step - loss: 80.2607 - val_loss: 65.7929
# Epoch 3/15
# 2068/2076 [============================>.] - ETA: 0s - loss: 66.0827
# Epoch 00003: val_loss improved from 65.79289 to 60.66050, saving model to ../results/experiment_set_21_time_window\results_window_5\split_2\mlp_model_trained.h5
# 2076/2076 [==============================] - 9s 4ms/step - loss: 66.0653 - val_loss: 60.6605
# Epoch 4/15
# 2070/2076 [============================>.] - ETA: 0s - loss: 60.6227
# Epoch 00004: val_loss improved from 60.66050 to 55.78423, saving model to ../results/experiment_set_21_time_window\results_window_5\split_2\mlp_model_trained.h5
# 2076/2076 [==============================] - 9s 4ms/step - loss: 60.6064 - val_loss: 55.7842
# Epoch 5/15
# 2060/2076 [============================>.] - ETA: 0s - loss: 55.8159
# Epoch 00005: val_loss did not improve from 55.78423
# 2076/2076 [==============================] - 8s 4ms/step - loss: 55.7921 - val_loss: 56.7906
# Epoch 6/15
# 2067/2076 [============================>.] - ETA: 0s - loss: 52.9058
# Epoch 00006: val_loss improved from 55.78423 to 52.39462, saving model to ../results/experiment_set_21_time_window\results_window_5\split_2\mlp_model_trained.h5
# 2076/2076 [==============================] - 9s 4ms/step - loss: 52.9160 - val_loss: 52.3946
# Epoch 7/15
# 2066/2076 [============================>.] - ETA: 0s - loss: 50.4518
# Epoch 00007: val_loss improved from 52.39462 to 47.16848, saving model to ../results/experiment_set_21_time_window\results_window_5\split_2\mlp_model_trained.h5
# 2076/2076 [==============================] - 9s 4ms/step - loss: 50.4225 - val_loss: 47.1685
# Epoch 8/15
# 2066/2076 [============================>.] - ETA: 0s - loss: 48.2402
# Epoch 00008: val_loss did not improve from 47.16848
# 2076/2076 [==============================] - 9s 4ms/step - loss: 48.2334 - val_loss: 49.6802
# Epoch 9/15
# 2066/2076 [============================>.] - ETA: 0s - loss: 46.5421
# Epoch 00009: val_loss did not improve from 47.16848
# 2076/2076 [==============================] - 9s 4ms/step - loss: 46.5561 - val_loss: 58.1072
# Epoch 10/15
# 2068/2076 [============================>.] - ETA: 0s - loss: 45.3549
# Epoch 00010: val_loss did not improve from 47.16848
# 2076/2076 [==============================] - 8s 4ms/step - loss: 45.3556 - val_loss: 48.1527
# Epoch 11/15
# 2067/2076 [============================>.] - ETA: 0s - loss: 43.3731
# Epoch 00011: val_loss did not improve from 47.16848
# 2076/2076 [==============================] - 8s 4ms/step - loss: 43.4007 - val_loss: 50.5591
# Epoch 12/15
# 2076/2076 [==============================] - ETA: 0s - loss: 42.4048
# Epoch 00012: val_loss improved from 47.16848 to 45.69994, saving model to ../results/experiment_set_21_time_window\results_window_5\split_2\mlp_model_trained.h5
# 2076/2076 [==============================] - 9s 4ms/step - loss: 42.4048 - val_loss: 45.6999
# Epoch 13/15
# 2076/2076 [==============================] - ETA: 0s - loss: 41.0984
# Epoch 00013: val_loss improved from 45.69994 to 39.64423, saving model to ../results/experiment_set_21_time_window\results_window_5\split_2\mlp_model_trained.h5
# 2076/2076 [==============================] - 9s 4ms/step - loss: 41.0984 - val_loss: 39.6442
# Epoch 14/15
# 2075/2076 [============================>.] - ETA: 0s - loss: 40.1608
# Epoch 00014: val_loss improved from 39.64423 to 35.75106, saving model to ../results/experiment_set_21_time_window\results_window_5\split_2\mlp_model_trained.h5
# 2076/2076 [==============================] - 8s 4ms/step - loss: 40.1639 - val_loss: 35.7511
# Epoch 15/15
# 2071/2076 [============================>.] - ETA: 0s - loss: 39.5572
# Epoch 00015: val_loss did not improve from 35.75106
# 2076/2076 [==============================] - 9s 4ms/step - loss: 39.5541 - val_loss: 37.3351
# Saved object to file: ../results/experiment_set_21_time_window\results_window_5\split_2\history_2.pkl
# Test set:
# MSE: 140.23
# RMSE: 11.84
# CMAPSS score: 2.89
#
# MSE: mean = 146.36   stddev = 4.37
# RMSE: mean = 12.10   stddev = 0.18
# CMAPSS: mean = 2.96   stddev = 0.05
# Saved object to file: ../results/experiment_set_21_time_window\results_window_10\split_0\scaler.pkl
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_15 (Dense)             (None, 256)               13056
# _________________________________________________________________
# dense_16 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dense_17 (Dense)             (None, 512)               131584
# _________________________________________________________________
# dense_18 (Dense)             (None, 64)                32832
# _________________________________________________________________
# dense_19 (Dense)             (None, 1)                 65
# =================================================================
# Total params: 243,329
# Trainable params: 243,329
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/15
#    1/1038 [..............................] - ETA: 0s - loss: 2038.4056WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0000s vs `on_train_batch_end` time: 0.0040s). Check your callbacks.
# 1038/1038 [==============================] - ETA: 0s - loss: 604.7544
# Epoch 00001: val_loss improved from inf to 176.06522, saving model to ../results/experiment_set_21_time_window\results_window_10\split_0\mlp_model_trained.h5
# 1038/1038 [==============================] - 5s 5ms/step - loss: 604.7544 - val_loss: 176.0652
# Epoch 2/15
# 1037/1038 [============================>.] - ETA: 0s - loss: 117.5931
# Epoch 00002: val_loss improved from 176.06522 to 85.67863, saving model to ../results/experiment_set_21_time_window\results_window_10\split_0\mlp_model_trained.h5
# 1038/1038 [==============================] - 5s 4ms/step - loss: 117.5773 - val_loss: 85.6786
# Epoch 3/15
# 1027/1038 [============================>.] - ETA: 0s - loss: 80.0311
# Epoch 00003: val_loss improved from 85.67863 to 70.07941, saving model to ../results/experiment_set_21_time_window\results_window_10\split_0\mlp_model_trained.h5
# 1038/1038 [==============================] - 5s 4ms/step - loss: 79.9265 - val_loss: 70.0794
# Epoch 4/15
# 1032/1038 [============================>.] - ETA: 0s - loss: 69.4014
# Epoch 00004: val_loss improved from 70.07941 to 64.12620, saving model to ../results/experiment_set_21_time_window\results_window_10\split_0\mlp_model_trained.h5
# 1038/1038 [==============================] - 5s 4ms/step - loss: 69.3734 - val_loss: 64.1262
# Epoch 5/15
# 1031/1038 [============================>.] - ETA: 0s - loss: 65.8105
# Epoch 00005: val_loss improved from 64.12620 to 61.04097, saving model to ../results/experiment_set_21_time_window\results_window_10\split_0\mlp_model_trained.h5
# 1038/1038 [==============================] - 5s 4ms/step - loss: 65.7836 - val_loss: 61.0410
# Epoch 6/15
# 1027/1038 [============================>.] - ETA: 0s - loss: 63.0883
# Epoch 00006: val_loss improved from 61.04097 to 56.94281, saving model to ../results/experiment_set_21_time_window\results_window_10\split_0\mlp_model_trained.h5
# 1038/1038 [==============================] - 5s 5ms/step - loss: 63.1488 - val_loss: 56.9428
# Epoch 7/15
# 1034/1038 [============================>.] - ETA: 0s - loss: 59.8049
# Epoch 00007: val_loss did not improve from 56.94281
# 1038/1038 [==============================] - 4s 4ms/step - loss: 59.8142 - val_loss: 72.0865
# Epoch 8/15
# 1032/1038 [============================>.] - ETA: 0s - loss: 57.4905
# Epoch 00008: val_loss improved from 56.94281 to 51.00561, saving model to ../results/experiment_set_21_time_window\results_window_10\split_0\mlp_model_trained.h5
# 1038/1038 [==============================] - 5s 5ms/step - loss: 57.4503 - val_loss: 51.0056
# Epoch 9/15
# 1037/1038 [============================>.] - ETA: 0s - loss: 54.9324
# Epoch 00009: val_loss improved from 51.00561 to 48.64065, saving model to ../results/experiment_set_21_time_window\results_window_10\split_0\mlp_model_trained.h5
# 1038/1038 [==============================] - 5s 4ms/step - loss: 54.9220 - val_loss: 48.6407
# Epoch 10/15
# 1037/1038 [============================>.] - ETA: 0s - loss: 53.5167
# Epoch 00010: val_loss did not improve from 48.64065
# 1038/1038 [==============================] - 4s 4ms/step - loss: 53.5121 - val_loss: 54.6104
# Epoch 11/15
# 1031/1038 [============================>.] - ETA: 0s - loss: 51.0010
# Epoch 00011: val_loss improved from 48.64065 to 48.01465, saving model to ../results/experiment_set_21_time_window\results_window_10\split_0\mlp_model_trained.h5
# 1038/1038 [==============================] - 5s 5ms/step - loss: 50.9831 - val_loss: 48.0146
# Epoch 12/15
# 1030/1038 [============================>.] - ETA: 0s - loss: 50.1108
# Epoch 00012: val_loss did not improve from 48.01465
# 1038/1038 [==============================] - 4s 4ms/step - loss: 50.1649 - val_loss: 58.2444
# Epoch 13/15
# 1036/1038 [============================>.] - ETA: 0s - loss: 48.7584
# Epoch 00013: val_loss did not improve from 48.01465
# 1038/1038 [==============================] - 4s 4ms/step - loss: 48.7511 - val_loss: 50.1259
# Epoch 14/15
# 1029/1038 [============================>.] - ETA: 0s - loss: 48.2218
# Epoch 00014: val_loss improved from 48.01465 to 42.20368, saving model to ../results/experiment_set_21_time_window\results_window_10\split_0\mlp_model_trained.h5
# 1038/1038 [==============================] - 5s 4ms/step - loss: 48.1971 - val_loss: 42.2037
# Epoch 15/15
# 1035/1038 [============================>.] - ETA: 0s - loss: 46.7141
# Epoch 00015: val_loss did not improve from 42.20368
# 1038/1038 [==============================] - 4s 4ms/step - loss: 46.7117 - val_loss: 43.7529
# Saved object to file: ../results/experiment_set_21_time_window\results_window_10\split_0\history_0.pkl
# Test set:
# MSE: 151.69
# RMSE: 12.32
# CMAPSS score: 3.05
#
# Saved object to file: ../results/experiment_set_21_time_window\results_window_10\split_1\scaler.pkl
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_20 (Dense)             (None, 256)               13056
# _________________________________________________________________
# dense_21 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dense_22 (Dense)             (None, 512)               131584
# _________________________________________________________________
# dense_23 (Dense)             (None, 64)                32832
# _________________________________________________________________
# dense_24 (Dense)             (None, 1)                 65
# =================================================================
# Total params: 243,329
# Trainable params: 243,329
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/15
# 1036/1038 [============================>.] - ETA: 0s - loss: 610.6590
# Epoch 00001: val_loss improved from inf to 174.61003, saving model to ../results/experiment_set_21_time_window\results_window_10\split_1\mlp_model_trained.h5
# 1038/1038 [==============================] - 4s 4ms/step - loss: 609.8443 - val_loss: 174.6100
# Epoch 2/15
# 1032/1038 [============================>.] - ETA: 0s - loss: 121.5919
# Epoch 00002: val_loss improved from 174.61003 to 88.15804, saving model to ../results/experiment_set_21_time_window\results_window_10\split_1\mlp_model_trained.h5
# 1038/1038 [==============================] - 5s 4ms/step - loss: 121.4390 - val_loss: 88.1580
# Epoch 3/15
# 1027/1038 [============================>.] - ETA: 0s - loss: 80.5305
# Epoch 00003: val_loss improved from 88.15804 to 69.47643, saving model to ../results/experiment_set_21_time_window\results_window_10\split_1\mlp_model_trained.h5
# 1038/1038 [==============================] - 5s 4ms/step - loss: 80.4747 - val_loss: 69.4764
# Epoch 4/15
# 1033/1038 [============================>.] - ETA: 0s - loss: 70.6820
# Epoch 00004: val_loss did not improve from 69.47643
# 1038/1038 [==============================] - 4s 4ms/step - loss: 70.7001 - val_loss: 71.5626
# Epoch 5/15
# 1028/1038 [============================>.] - ETA: 0s - loss: 66.1660
# Epoch 00005: val_loss improved from 69.47643 to 61.01051, saving model to ../results/experiment_set_21_time_window\results_window_10\split_1\mlp_model_trained.h5
# 1038/1038 [==============================] - 5s 4ms/step - loss: 66.1293 - val_loss: 61.0105
# Epoch 6/15
# 1027/1038 [============================>.] - ETA: 0s - loss: 62.0754
# Epoch 00006: val_loss improved from 61.01051 to 58.39861, saving model to ../results/experiment_set_21_time_window\results_window_10\split_1\mlp_model_trained.h5
# 1038/1038 [==============================] - 5s 4ms/step - loss: 62.0378 - val_loss: 58.3986
# Epoch 7/15
# 1026/1038 [============================>.] - ETA: 0s - loss: 59.2671
# Epoch 00007: val_loss improved from 58.39861 to 52.79091, saving model to ../results/experiment_set_21_time_window\results_window_10\split_1\mlp_model_trained.h5
# 1038/1038 [==============================] - 5s 4ms/step - loss: 59.2025 - val_loss: 52.7909
# Epoch 8/15
# 1026/1038 [============================>.] - ETA: 0s - loss: 57.0279
# Epoch 00008: val_loss improved from 52.79091 to 50.82462, saving model to ../results/experiment_set_21_time_window\results_window_10\split_1\mlp_model_trained.h5
# 1038/1038 [==============================] - 5s 4ms/step - loss: 57.0267 - val_loss: 50.8246
# Epoch 9/15
# 1028/1038 [============================>.] - ETA: 0s - loss: 56.0460
# Epoch 00009: val_loss did not improve from 50.82462
# 1038/1038 [==============================] - 4s 4ms/step - loss: 56.0055 - val_loss: 53.5607
# Epoch 10/15
# 1030/1038 [============================>.] - ETA: 0s - loss: 53.8913
# Epoch 00010: val_loss did not improve from 50.82462
# 1038/1038 [==============================] - 4s 4ms/step - loss: 53.8520 - val_loss: 53.7357
# Epoch 11/15
# 1033/1038 [============================>.] - ETA: 0s - loss: 51.6297
# Epoch 00011: val_loss improved from 50.82462 to 48.64603, saving model to ../results/experiment_set_21_time_window\results_window_10\split_1\mlp_model_trained.h5
# 1038/1038 [==============================] - 5s 4ms/step - loss: 51.6110 - val_loss: 48.6460
# Epoch 12/15
# 1031/1038 [============================>.] - ETA: 0s - loss: 50.2630
# Epoch 00012: val_loss improved from 48.64603 to 47.90867, saving model to ../results/experiment_set_21_time_window\results_window_10\split_1\mlp_model_trained.h5
# 1038/1038 [==============================] - 5s 5ms/step - loss: 50.2566 - val_loss: 47.9087
# Epoch 13/15
# 1037/1038 [============================>.] - ETA: 0s - loss: 48.9228
# Epoch 00013: val_loss did not improve from 47.90867
# 1038/1038 [==============================] - 4s 4ms/step - loss: 48.9151 - val_loss: 51.5689
# Epoch 14/15
# 1028/1038 [============================>.] - ETA: 0s - loss: 47.6570
# Epoch 00014: val_loss improved from 47.90867 to 43.56948, saving model to ../results/experiment_set_21_time_window\results_window_10\split_1\mlp_model_trained.h5
# 1038/1038 [==============================] - 5s 4ms/step - loss: 47.6017 - val_loss: 43.5695
# Epoch 15/15
# 1033/1038 [============================>.] - ETA: 0s - loss: 46.9777
# Epoch 00015: val_loss did not improve from 43.56948
# 1038/1038 [==============================] - 4s 4ms/step - loss: 46.9730 - val_loss: 47.7944
# Saved object to file: ../results/experiment_set_21_time_window\results_window_10\split_1\history_1.pkl
# Test set:
# MSE: 168.06
# RMSE: 12.96
# CMAPSS score: 3.26
#
# Saved object to file: ../results/experiment_set_21_time_window\results_window_10\split_2\scaler.pkl
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_25 (Dense)             (None, 256)               13056
# _________________________________________________________________
# dense_26 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dense_27 (Dense)             (None, 512)               131584
# _________________________________________________________________
# dense_28 (Dense)             (None, 64)                32832
# _________________________________________________________________
# dense_29 (Dense)             (None, 1)                 65
# =================================================================
# Total params: 243,329
# Trainable params: 243,329
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/15
# 1037/1038 [============================>.] - ETA: 0s - loss: 618.3115WARNING:tensorflow:Callbacks method `on_test_batch_end` is slow compared to the batch time (batch time: 0.0000s vs `on_test_batch_end` time: 0.0040s). Check your callbacks.
#
# Epoch 00001: val_loss improved from inf to 175.55890, saving model to ../results/experiment_set_21_time_window\results_window_10\split_2\mlp_model_trained.h5
# 1038/1038 [==============================] - 5s 4ms/step - loss: 617.9340 - val_loss: 175.5589
# Epoch 2/15
# 1038/1038 [==============================] - ETA: 0s - loss: 124.6718
# Epoch 00002: val_loss improved from 175.55890 to 107.25606, saving model to ../results/experiment_set_21_time_window\results_window_10\split_2\mlp_model_trained.h5
# 1038/1038 [==============================] - 5s 4ms/step - loss: 124.6718 - val_loss: 107.2561
# Epoch 3/15
# 1030/1038 [============================>.] - ETA: 0s - loss: 86.0008
# Epoch 00003: val_loss improved from 107.25606 to 76.79160, saving model to ../results/experiment_set_21_time_window\results_window_10\split_2\mlp_model_trained.h5
# 1038/1038 [==============================] - 5s 4ms/step - loss: 85.9505 - val_loss: 76.7916
# Epoch 4/15
# 1028/1038 [============================>.] - ETA: 0s - loss: 74.9028
# Epoch 00004: val_loss improved from 76.79160 to 73.15763, saving model to ../results/experiment_set_21_time_window\results_window_10\split_2\mlp_model_trained.h5
# 1038/1038 [==============================] - 5s 5ms/step - loss: 74.8650 - val_loss: 73.1576
# Epoch 5/15
# 1027/1038 [============================>.] - ETA: 0s - loss: 67.5776
# Epoch 00005: val_loss improved from 73.15763 to 64.12590, saving model to ../results/experiment_set_21_time_window\results_window_10\split_2\mlp_model_trained.h5
# 1038/1038 [==============================] - 4s 4ms/step - loss: 67.5214 - val_loss: 64.1259
# Epoch 6/15
# 1035/1038 [============================>.] - ETA: 0s - loss: 64.1456
# Epoch 00006: val_loss improved from 64.12590 to 64.05099, saving model to ../results/experiment_set_21_time_window\results_window_10\split_2\mlp_model_trained.h5
# 1038/1038 [==============================] - 5s 4ms/step - loss: 64.1363 - val_loss: 64.0510
# Epoch 7/15
# 1025/1038 [============================>.] - ETA: 0s - loss: 61.8955
# Epoch 00007: val_loss improved from 64.05099 to 63.71559, saving model to ../results/experiment_set_21_time_window\results_window_10\split_2\mlp_model_trained.h5
# 1038/1038 [==============================] - 5s 4ms/step - loss: 61.9928 - val_loss: 63.7156
# Epoch 8/15
# 1030/1038 [============================>.] - ETA: 0s - loss: 59.5100
# Epoch 00008: val_loss improved from 63.71559 to 53.78212, saving model to ../results/experiment_set_21_time_window\results_window_10\split_2\mlp_model_trained.h5
# 1038/1038 [==============================] - 5s 4ms/step - loss: 59.4491 - val_loss: 53.7821
# Epoch 9/15
# 1032/1038 [============================>.] - ETA: 0s - loss: 57.3829
# Epoch 00009: val_loss improved from 53.78212 to 49.48142, saving model to ../results/experiment_set_21_time_window\results_window_10\split_2\mlp_model_trained.h5
# 1038/1038 [==============================] - 4s 4ms/step - loss: 57.3533 - val_loss: 49.4814
# Epoch 10/15
# 1031/1038 [============================>.] - ETA: 0s - loss: 53.9229
# Epoch 00010: val_loss did not improve from 49.48142
# 1038/1038 [==============================] - 4s 4ms/step - loss: 53.8951 - val_loss: 51.2304
# Epoch 11/15
# 1029/1038 [============================>.] - ETA: 0s - loss: 53.3629
# Epoch 00011: val_loss did not improve from 49.48142
# 1038/1038 [==============================] - 4s 4ms/step - loss: 53.3179 - val_loss: 51.0185
# Epoch 12/15
# 1031/1038 [============================>.] - ETA: 0s - loss: 51.2661
# Epoch 00012: val_loss did not improve from 49.48142
# 1038/1038 [==============================] - 5s 4ms/step - loss: 51.2790 - val_loss: 51.5407
# Epoch 13/15
# 1030/1038 [============================>.] - ETA: 0s - loss: 49.6221
# Epoch 00013: val_loss improved from 49.48142 to 43.80905, saving model to ../results/experiment_set_21_time_window\results_window_10\split_2\mlp_model_trained.h5
# 1038/1038 [==============================] - 4s 4ms/step - loss: 49.6035 - val_loss: 43.8091
# Epoch 14/15
# 1029/1038 [============================>.] - ETA: 0s - loss: 49.2207
# Epoch 00014: val_loss did not improve from 43.80905
# 1038/1038 [==============================] - 4s 4ms/step - loss: 49.1835 - val_loss: 48.1166
# Epoch 15/15
# 1031/1038 [============================>.] - ETA: 0s - loss: 47.7454
# Epoch 00015: val_loss improved from 43.80905 to 43.00858, saving model to ../results/experiment_set_21_time_window\results_window_10\split_2\mlp_model_trained.h5
# 1038/1038 [==============================] - 5s 5ms/step - loss: 47.7552 - val_loss: 43.0086
# Saved object to file: ../results/experiment_set_21_time_window\results_window_10\split_2\history_2.pkl
# Test set:
# MSE: 155.37
# RMSE: 12.46
# CMAPSS score: 3.12
#
# MSE: mean = 158.38   stddev = 7.01
# RMSE: mean = 12.58   stddev = 0.28
# CMAPSS: mean = 3.15   stddev = 0.09
# Saved object to file: ../results/experiment_set_21_time_window\results_window_15\split_0\scaler.pkl
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_30 (Dense)             (None, 256)               19456
# _________________________________________________________________
# dense_31 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dense_32 (Dense)             (None, 512)               131584
# _________________________________________________________________
# dense_33 (Dense)             (None, 64)                32832
# _________________________________________________________________
# dense_34 (Dense)             (None, 1)                 65
# =================================================================
# Total params: 249,729
# Trainable params: 249,729
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/15
#   1/779 [..............................] - ETA: 0s - loss: 1920.9825WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0000s vs `on_train_batch_end` time: 0.0040s). Check your callbacks.
# 770/779 [============================>.] - ETA: 0s - loss: 725.2560
# Epoch 00001: val_loss improved from inf to 354.37259, saving model to ../results/experiment_set_21_time_window\results_window_15\split_0\mlp_model_trained.h5
# 779/779 [==============================] - 3s 4ms/step - loss: 720.5167 - val_loss: 354.3726
# Epoch 2/15
# 771/779 [============================>.] - ETA: 0s - loss: 171.5729
# Epoch 00002: val_loss improved from 354.37259 to 127.09752, saving model to ../results/experiment_set_21_time_window\results_window_15\split_0\mlp_model_trained.h5
# 779/779 [==============================] - 4s 5ms/step - loss: 171.0052 - val_loss: 127.0975
# Epoch 3/15
# 777/779 [============================>.] - ETA: 0s - loss: 93.7753
# Epoch 00003: val_loss improved from 127.09752 to 81.48392, saving model to ../results/experiment_set_21_time_window\results_window_15\split_0\mlp_model_trained.h5
# 779/779 [==============================] - 4s 5ms/step - loss: 93.7633 - val_loss: 81.4839
# Epoch 4/15
# 771/779 [============================>.] - ETA: 0s - loss: 80.0926
# Epoch 00004: val_loss improved from 81.48392 to 68.62020, saving model to ../results/experiment_set_21_time_window\results_window_15\split_0\mlp_model_trained.h5
# 779/779 [==============================] - 4s 5ms/step - loss: 79.9625 - val_loss: 68.6202
# Epoch 5/15
# 776/779 [============================>.] - ETA: 0s - loss: 73.4400
# Epoch 00005: val_loss did not improve from 68.62020
# 779/779 [==============================] - 3s 4ms/step - loss: 73.4100 - val_loss: 70.6261
# Epoch 6/15
# 776/779 [============================>.] - ETA: 0s - loss: 67.3220
# Epoch 00006: val_loss improved from 68.62020 to 67.84383, saving model to ../results/experiment_set_21_time_window\results_window_15\split_0\mlp_model_trained.h5
# 779/779 [==============================] - 4s 5ms/step - loss: 67.3475 - val_loss: 67.8438
# Epoch 7/15
# 775/779 [============================>.] - ETA: 0s - loss: 65.2054
# Epoch 00007: val_loss improved from 67.84383 to 65.98225, saving model to ../results/experiment_set_21_time_window\results_window_15\split_0\mlp_model_trained.h5
# 779/779 [==============================] - 3s 4ms/step - loss: 65.1781 - val_loss: 65.9822
# Epoch 8/15
# 772/779 [============================>.] - ETA: 0s - loss: 63.0795
# Epoch 00008: val_loss did not improve from 65.98225
# 779/779 [==============================] - 3s 4ms/step - loss: 63.0807 - val_loss: 70.2347
# Epoch 9/15
# 773/779 [============================>.] - ETA: 0s - loss: 59.5942
# Epoch 00009: val_loss did not improve from 65.98225
# 779/779 [==============================] - 3s 4ms/step - loss: 59.6166 - val_loss: 87.1101
# Epoch 10/15
# 767/779 [============================>.] - ETA: 0s - loss: 59.0009
# Epoch 00010: val_loss improved from 65.98225 to 52.45987, saving model to ../results/experiment_set_21_time_window\results_window_15\split_0\mlp_model_trained.h5
# 779/779 [==============================] - 4s 5ms/step - loss: 58.9152 - val_loss: 52.4599
# Epoch 11/15
# 773/779 [============================>.] - ETA: 0s - loss: 56.4870
# Epoch 00011: val_loss did not improve from 52.45987
# 779/779 [==============================] - 3s 4ms/step - loss: 56.4804 - val_loss: 55.0549
# Epoch 12/15
# 768/779 [============================>.] - ETA: 0s - loss: 55.2296
# Epoch 00012: val_loss improved from 52.45987 to 50.21279, saving model to ../results/experiment_set_21_time_window\results_window_15\split_0\mlp_model_trained.h5
# 779/779 [==============================] - 4s 4ms/step - loss: 55.2094 - val_loss: 50.2128
# Epoch 13/15
# 776/779 [============================>.] - ETA: 0s - loss: 53.1899
# Epoch 00013: val_loss did not improve from 50.21279
# 779/779 [==============================] - 3s 4ms/step - loss: 53.1752 - val_loss: 50.3154
# Epoch 14/15
# 768/779 [============================>.] - ETA: 0s - loss: 51.3958
# Epoch 00014: val_loss did not improve from 50.21279
# 779/779 [==============================] - 3s 4ms/step - loss: 51.3543 - val_loss: 59.8761
# Epoch 15/15
# 779/779 [==============================] - ETA: 0s - loss: 50.5803
# Epoch 00015: val_loss improved from 50.21279 to 44.28095, saving model to ../results/experiment_set_21_time_window\results_window_15\split_0\mlp_model_trained.h5
# 779/779 [==============================] - 4s 5ms/step - loss: 50.5803 - val_loss: 44.2809
# Saved object to file: ../results/experiment_set_21_time_window\results_window_15\split_0\history_0.pkl
# Test set:
# MSE: 167.43
# RMSE: 12.94
# CMAPSS score: 3.17
#
# Saved object to file: ../results/experiment_set_21_time_window\results_window_15\split_1\scaler.pkl
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_35 (Dense)             (None, 256)               19456
# _________________________________________________________________
# dense_36 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dense_37 (Dense)             (None, 512)               131584
# _________________________________________________________________
# dense_38 (Dense)             (None, 64)                32832
# _________________________________________________________________
# dense_39 (Dense)             (None, 1)                 65
# =================================================================
# Total params: 249,729
# Trainable params: 249,729
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/15
#   1/779 [..............................] - ETA: 0s - loss: 1935.1298WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0000s vs `on_train_batch_end` time: 0.0040s). Check your callbacks.
# 776/779 [============================>.] - ETA: 0s - loss: 723.1876WARNING:tensorflow:Callbacks method `on_test_batch_end` is slow compared to the batch time (batch time: 0.0000s vs `on_test_batch_end` time: 0.0040s). Check your callbacks.
#
# Epoch 00001: val_loss improved from inf to 274.42816, saving model to ../results/experiment_set_21_time_window\results_window_15\split_1\mlp_model_trained.h5
# 779/779 [==============================] - 3s 4ms/step - loss: 721.8495 - val_loss: 274.4282
# Epoch 2/15
# 772/779 [============================>.] - ETA: 0s - loss: 166.8625
# Epoch 00002: val_loss improved from 274.42816 to 109.50012, saving model to ../results/experiment_set_21_time_window\results_window_15\split_1\mlp_model_trained.h5
# 779/779 [==============================] - 4s 5ms/step - loss: 166.4166 - val_loss: 109.5001
# Epoch 3/15
# 774/779 [============================>.] - ETA: 0s - loss: 96.9954
# Epoch 00003: val_loss improved from 109.50012 to 76.34090, saving model to ../results/experiment_set_21_time_window\results_window_15\split_1\mlp_model_trained.h5
# 779/779 [==============================] - 4s 5ms/step - loss: 96.9077 - val_loss: 76.3409
# Epoch 4/15
# 778/779 [============================>.] - ETA: 0s - loss: 78.6045
# Epoch 00004: val_loss improved from 76.34090 to 70.44673, saving model to ../results/experiment_set_21_time_window\results_window_15\split_1\mlp_model_trained.h5
# 779/779 [==============================] - 3s 4ms/step - loss: 78.5929 - val_loss: 70.4467
# Epoch 5/15
# 775/779 [============================>.] - ETA: 0s - loss: 71.9960
# Epoch 00005: val_loss improved from 70.44673 to 61.55315, saving model to ../results/experiment_set_21_time_window\results_window_15\split_1\mlp_model_trained.h5
# 779/779 [==============================] - 4s 5ms/step - loss: 71.9433 - val_loss: 61.5531
# Epoch 6/15
# 774/779 [============================>.] - ETA: 0s - loss: 68.6946
# Epoch 00006: val_loss improved from 61.55315 to 60.89009, saving model to ../results/experiment_set_21_time_window\results_window_15\split_1\mlp_model_trained.h5
# 779/779 [==============================] - 3s 4ms/step - loss: 68.6730 - val_loss: 60.8901
# Epoch 7/15
# 774/779 [============================>.] - ETA: 0s - loss: 64.3772
# Epoch 00007: val_loss improved from 60.89009 to 57.30848, saving model to ../results/experiment_set_21_time_window\results_window_15\split_1\mlp_model_trained.h5
# 779/779 [==============================] - 4s 5ms/step - loss: 64.3447 - val_loss: 57.3085
# Epoch 8/15
# 766/779 [============================>.] - ETA: 0s - loss: 61.3589
# Epoch 00008: val_loss improved from 57.30848 to 55.98892, saving model to ../results/experiment_set_21_time_window\results_window_15\split_1\mlp_model_trained.h5
# 779/779 [==============================] - 4s 5ms/step - loss: 61.3175 - val_loss: 55.9889
# Epoch 9/15
# 767/779 [============================>.] - ETA: 0s - loss: 60.4701
# Epoch 00009: val_loss improved from 55.98892 to 53.96834, saving model to ../results/experiment_set_21_time_window\results_window_15\split_1\mlp_model_trained.h5
# 779/779 [==============================] - 4s 5ms/step - loss: 60.4157 - val_loss: 53.9683
# Epoch 10/15
# 774/779 [============================>.] - ETA: 0s - loss: 57.2571
# Epoch 00010: val_loss did not improve from 53.96834
# 779/779 [==============================] - 3s 4ms/step - loss: 57.3246 - val_loss: 78.3751
# Epoch 11/15
# 777/779 [============================>.] - ETA: 0s - loss: 56.0724
# Epoch 00011: val_loss did not improve from 53.96834
# 779/779 [==============================] - 3s 4ms/step - loss: 56.0816 - val_loss: 57.7154
# Epoch 12/15
# 778/779 [============================>.] - ETA: 0s - loss: 54.5826
# Epoch 00012: val_loss improved from 53.96834 to 53.61422, saving model to ../results/experiment_set_21_time_window\results_window_15\split_1\mlp_model_trained.h5
# 779/779 [==============================] - 4s 5ms/step - loss: 54.5831 - val_loss: 53.6142
# Epoch 13/15
# 778/779 [============================>.] - ETA: 0s - loss: 52.7520
# Epoch 00013: val_loss improved from 53.61422 to 52.88685, saving model to ../results/experiment_set_21_time_window\results_window_15\split_1\mlp_model_trained.h5
# 779/779 [==============================] - 3s 4ms/step - loss: 52.7598 - val_loss: 52.8868
# Epoch 14/15
# 778/779 [============================>.] - ETA: 0s - loss: 51.7290
# Epoch 00014: val_loss improved from 52.88685 to 48.38771, saving model to ../results/experiment_set_21_time_window\results_window_15\split_1\mlp_model_trained.h5
# 779/779 [==============================] - 3s 4ms/step - loss: 51.7321 - val_loss: 48.3877
# Epoch 15/15
# 778/779 [============================>.] - ETA: 0s - loss: 50.7544
# Epoch 00015: val_loss improved from 48.38771 to 46.51660, saving model to ../results/experiment_set_21_time_window\results_window_15\split_1\mlp_model_trained.h5
# 779/779 [==============================] - 4s 5ms/step - loss: 50.7527 - val_loss: 46.5166
# Saved object to file: ../results/experiment_set_21_time_window\results_window_15\split_1\history_1.pkl
# Test set:
# MSE: 163.74
# RMSE: 12.80
# CMAPSS score: 3.17
#
# Saved object to file: ../results/experiment_set_21_time_window\results_window_15\split_2\scaler.pkl
# Model: "sequential_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_40 (Dense)             (None, 256)               19456
# _________________________________________________________________
# dense_41 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dense_42 (Dense)             (None, 512)               131584
# ...
# dense_49 (Dense)             (None, 1)                 65
# =================================================================
# Total params: 256,129
# Trainable params: 256,129
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/15
# 567/567 [==============================] - ETA: 0s - loss: 909.1420
# Epoch 00001: val_loss improved from inf to 433.21173, saving model to ../results/experiment_set_21_time_window\results_window_20\split_0\mlp_model_trained.h5
# 567/567 [==============================] - 3s 5ms/step - loss: 909.1420 - val_loss: 433.2117
# Epoch 2/15
# 555/567 [============================>.] - ETA: 0s - loss: 286.7096
# Epoch 00002: val_loss improved from 433.21173 to 166.10478, saving model to ../results/experiment_set_21_time_window\results_window_20\split_0\mlp_model_trained.h5
# 567/567 [==============================] - 3s 5ms/step - loss: 284.7465 - val_loss: 166.1048
# Epoch 3/15
# 555/567 [============================>.] - ETA: 0s - loss: 137.5756
# Epoch 00003: val_loss improved from 166.10478 to 118.93372, saving model to ../results/experiment_set_21_time_window\results_window_20\split_0\mlp_model_trained.h5
# 567/567 [==============================] - 3s 5ms/step - loss: 137.1245 - val_loss: 118.9337
# Epoch 4/15
# 564/567 [============================>.] - ETA: 0s - loss: 98.0539
# Epoch 00004: val_loss improved from 118.93372 to 110.79250, saving model to ../results/experiment_set_21_time_window\results_window_20\split_0\mlp_model_trained.h5
# 567/567 [==============================] - 3s 5ms/step - loss: 97.9820 - val_loss: 110.7925
# Epoch 5/15
# 562/567 [============================>.] - ETA: 0s - loss: 84.7289
# Epoch 00005: val_loss improved from 110.79250 to 91.20996, saving model to ../results/experiment_set_21_time_window\results_window_20\split_0\mlp_model_trained.h5
# 567/567 [==============================] - 3s 5ms/step - loss: 84.6574 - val_loss: 91.2100
# Epoch 6/15
# 561/567 [============================>.] - ETA: 0s - loss: 78.5197
# Epoch 00006: val_loss improved from 91.20996 to 89.40627, saving model to ../results/experiment_set_21_time_window\results_window_20\split_0\mlp_model_trained.h5
# 567/567 [==============================] - 3s 5ms/step - loss: 78.5120 - val_loss: 89.4063
# Epoch 7/15
# 555/567 [============================>.] - ETA: 0s - loss: 72.8606
# Epoch 00007: val_loss did not improve from 89.40627
# 567/567 [==============================] - 2s 4ms/step - loss: 72.9044 - val_loss: 155.9690
# Epoch 8/15
# 557/567 [============================>.] - ETA: 0s - loss: 73.4820
# Epoch 00008: val_loss improved from 89.40627 to 66.99205, saving model to ../results/experiment_set_21_time_window\results_window_20\split_0\mlp_model_trained.h5
# 567/567 [==============================] - 3s 5ms/step - loss: 73.3689 - val_loss: 66.9921
# Epoch 9/15
# 560/567 [============================>.] - ETA: 0s - loss: 67.0059
# Epoch 00009: val_loss did not improve from 66.99205
# 567/567 [==============================] - 2s 4ms/step - loss: 66.9863 - val_loss: 78.7182
# Epoch 10/15
# 560/567 [============================>.] - ETA: 0s - loss: 65.8136
# Epoch 00010: val_loss did not improve from 66.99205
# 567/567 [==============================] - 2s 4ms/step - loss: 65.7327 - val_loss: 69.0052
# Epoch 11/15
# 565/567 [============================>.] - ETA: 0s - loss: 61.7150
# Epoch 00011: val_loss improved from 66.99205 to 64.56473, saving model to ../results/experiment_set_21_time_window\results_window_20\split_0\mlp_model_trained.h5
# 567/567 [==============================] - 3s 5ms/step - loss: 61.7175 - val_loss: 64.5647
# Epoch 12/15
# 559/567 [============================>.] - ETA: 0s - loss: 61.8098
# Epoch 00012: val_loss did not improve from 64.56473
# 567/567 [==============================] - 2s 4ms/step - loss: 61.7998 - val_loss: 67.5536
# Epoch 13/15
# 561/567 [============================>.] - ETA: 0s - loss: 59.8077
# Epoch 00013: val_loss did not improve from 64.56473
# 567/567 [==============================] - 2s 4ms/step - loss: 59.7704 - val_loss: 64.6953
# Epoch 14/15
# 566/567 [============================>.] - ETA: 0s - loss: 58.9939
# Epoch 00014: val_loss did not improve from 64.56473
# 567/567 [==============================] - 2s 4ms/step - loss: 58.9912 - val_loss: 75.0831
# Epoch 15/15
# 566/567 [============================>.] - ETA: 0s - loss: 57.7786
# Epoch 00015: val_loss did not improve from 64.56473
# 567/567 [==============================] - 2s 4ms/step - loss: 57.7788 - val_loss: 67.3625
# Saved object to file: ../results/experiment_set_21_time_window\results_window_20\split_0\history_0.pkl
# Test set:
# MSE: 207.89
# RMSE: 14.42
# CMAPSS score: 3.97
#
# Saved object to file: ../results/experiment_set_21_time_window\results_window_20\split_1\scaler.pkl
# Model: "sequential_10"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_50 (Dense)             (None, 256)               25856
# _________________________________________________________________
# dense_51 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dense_52 (Dense)             (None, 512)               131584
# _________________________________________________________________
# dense_53 (Dense)             (None, 64)                32832
# _________________________________________________________________
# dense_54 (Dense)             (None, 1)                 65
# =================================================================
# Total params: 256,129
# Trainable params: 256,129
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/15
# 556/567 [============================>.] - ETA: 0s - loss: 895.2385
# Epoch 00001: val_loss improved from inf to 432.85477, saving model to ../results/experiment_set_21_time_window\results_window_20\split_1\mlp_model_trained.h5
# 567/567 [==============================] - 3s 5ms/step - loss: 886.7368 - val_loss: 432.8548
# Epoch 2/15
# 557/567 [============================>.] - ETA: 0s - loss: 263.2700
# Epoch 00002: val_loss improved from 432.85477 to 159.80153, saving model to ../results/experiment_set_21_time_window\results_window_20\split_1\mlp_model_trained.h5
# 567/567 [==============================] - 3s 5ms/step - loss: 261.6828 - val_loss: 159.8015
# Epoch 3/15
# 564/567 [============================>.] - ETA: 0s - loss: 130.9734
# Epoch 00003: val_loss improved from 159.80153 to 95.77546, saving model to ../results/experiment_set_21_time_window\results_window_20\split_1\mlp_model_trained.h5
# 567/567 [==============================] - 3s 5ms/step - loss: 130.8973 - val_loss: 95.7755
# Epoch 4/15
# 563/567 [============================>.] - ETA: 0s - loss: 100.8754
# Epoch 00004: val_loss improved from 95.77546 to 94.18274, saving model to ../results/experiment_set_21_time_window\results_window_20\split_1\mlp_model_trained.h5
# 567/567 [==============================] - 3s 5ms/step - loss: 100.7841 - val_loss: 94.1827
# Epoch 5/15
# 561/567 [============================>.] - ETA: 0s - loss: 87.6346
# Epoch 00005: val_loss improved from 94.18274 to 88.43621, saving model to ../results/experiment_set_21_time_window\results_window_20\split_1\mlp_model_trained.h5
# 567/567 [==============================] - 3s 5ms/step - loss: 87.5777 - val_loss: 88.4362
# Epoch 6/15
# 562/567 [============================>.] - ETA: 0s - loss: 76.9723
# Epoch 00006: val_loss improved from 88.43621 to 72.18350, saving model to ../results/experiment_set_21_time_window\results_window_20\split_1\mlp_model_trained.h5
# 567/567 [==============================] - 3s 5ms/step - loss: 76.9056 - val_loss: 72.1835
# Epoch 7/15
# 559/567 [============================>.] - ETA: 0s - loss: 75.0693 ETA: 0s -
# Epoch 00007: val_loss did not improve from 72.18350
# 567/567 [==============================] - 2s 4ms/step - loss: 75.0544 - val_loss: 72.8449
# Epoch 8/15
# 563/567 [============================>.] - ETA: 0s - loss: 70.7959
# Epoch 00008: val_loss improved from 72.18350 to 70.18781, saving model to ../results/experiment_set_21_time_window\results_window_20\split_1\mlp_model_trained.h5
# 567/567 [==============================] - 3s 5ms/step - loss: 70.7670 - val_loss: 70.1878
# Epoch 9/15
# 562/567 [============================>.] - ETA: 0s - loss: 67.4510
# Epoch 00009: val_loss did not improve from 70.18781
# 567/567 [==============================] - 2s 4ms/step - loss: 67.4039 - val_loss: 77.1844
# Epoch 10/15
# 566/567 [============================>.] - ETA: 0s - loss: 64.6582
# Epoch 00010: val_loss did not improve from 70.18781
# 567/567 [==============================] - 2s 4ms/step - loss: 64.6575 - val_loss: 83.6232
# Epoch 11/15
# 563/567 [============================>.] - ETA: 0s - loss: 63.3379
# Epoch 00011: val_loss did not improve from 70.18781
# 567/567 [==============================] - 2s 4ms/step - loss: 63.3315 - val_loss: 78.3706
# Epoch 12/15
# 562/567 [============================>.] - ETA: 0s - loss: 60.8048
# Epoch 00012: val_loss did not improve from 70.18781
# 567/567 [==============================] - 2s 4ms/step - loss: 60.7688 - val_loss: 77.0985
# Epoch 13/15
# 567/567 [==============================] - ETA: 0s - loss: 59.1820
# Epoch 00013: val_loss improved from 70.18781 to 67.95947, saving model to ../results/experiment_set_21_time_window\results_window_20\split_1\mlp_model_trained.h5
# 567/567 [==============================] - 3s 5ms/step - loss: 59.1820 - val_loss: 67.9595
# Epoch 14/15
# 559/567 [============================>.] - ETA: 0s - loss: 57.1987
# Epoch 00014: val_loss improved from 67.95947 to 55.28292, saving model to ../results/experiment_set_21_time_window\results_window_20\split_1\mlp_model_trained.h5
# 567/567 [==============================] - 3s 5ms/step - loss: 57.1515 - val_loss: 55.2829
# Epoch 15/15
# 563/567 [============================>.] - ETA: 0s - loss: 57.5751
# Epoch 00015: val_loss improved from 55.28292 to 52.09537, saving model to ../results/experiment_set_21_time_window\results_window_20\split_1\mlp_model_trained.h5
# 567/567 [==============================] - 3s 5ms/step - loss: 57.5098 - val_loss: 52.0954
# Saved object to file: ../results/experiment_set_21_time_window\results_window_20\split_1\history_1.pkl
# Test set:
# MSE: 186.55
# RMSE: 13.66
# CMAPSS score: 3.63
#
# Saved object to file: ../results/experiment_set_21_time_window\results_window_20\split_2\scaler.pkl
# Model: "sequential_11"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_55 (Dense)             (None, 256)               25856
# _________________________________________________________________
# dense_56 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dense_57 (Dense)             (None, 512)               131584
# _________________________________________________________________
# dense_58 (Dense)             (None, 64)                32832
# _________________________________________________________________
# dense_59 (Dense)             (None, 1)                 65
# =================================================================
# Total params: 256,129
# Trainable params: 256,129
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/15
# 555/567 [============================>.] - ETA: 0s - loss: 880.0898
# Epoch 00001: val_loss improved from inf to 422.67276, saving model to ../results/experiment_set_21_time_window\results_window_20\split_2\mlp_model_trained.h5
# 567/567 [==============================] - 3s 5ms/step - loss: 871.3264 - val_loss: 422.6728
# Epoch 2/15
# 564/567 [============================>.] - ETA: 0s - loss: 257.8640
# Epoch 00002: val_loss improved from 422.67276 to 204.75075, saving model to ../results/experiment_set_21_time_window\results_window_20\split_2\mlp_model_trained.h5
# 567/567 [==============================] - 3s 5ms/step - loss: 257.5608 - val_loss: 204.7507
# Epoch 3/15
# 563/567 [============================>.] - ETA: 0s - loss: 128.7669
# Epoch 00003: val_loss improved from 204.75075 to 108.75880, saving model to ../results/experiment_set_21_time_window\results_window_20\split_2\mlp_model_trained.h5
# 567/567 [==============================] - 3s 5ms/step - loss: 128.6253 - val_loss: 108.7588
# Epoch 4/15
# 554/567 [============================>.] - ETA: 0s - loss: 125.7221
# Epoch 00004: val_loss did not improve from 108.75880
# 567/567 [==============================] - 2s 4ms/step - loss: 125.2358 - val_loss: 152.3747
# Epoch 5/15
# 563/567 [============================>.] - ETA: 0s - loss: 90.6033
# Epoch 00005: val_loss improved from 108.75880 to 91.10899, saving model to ../results/experiment_set_21_time_window\results_window_20\split_2\mlp_model_trained.h5
# 567/567 [==============================] - 3s 5ms/step - loss: 90.5266 - val_loss: 91.1090
# Epoch 6/15
# 556/567 [============================>.] - ETA: 0s - loss: 81.2992
# Epoch 00006: val_loss improved from 91.10899 to 75.18816, saving model to ../results/experiment_set_21_time_window\results_window_20\split_2\mlp_model_trained.h5
# 567/567 [==============================] - 3s 5ms/step - loss: 81.1305 - val_loss: 75.1882
# Epoch 7/15
# 558/567 [============================>.] - ETA: 0s - loss: 75.6970
# Epoch 00007: val_loss improved from 75.18816 to 72.87641, saving model to ../results/experiment_set_21_time_window\results_window_20\split_2\mlp_model_trained.h5
# 567/567 [==============================] - 3s 5ms/step - loss: 75.6158 - val_loss: 72.8764
# Epoch 8/15
# 555/567 [============================>.] - ETA: 0s - loss: 70.6426
# Epoch 00008: val_loss improved from 72.87641 to 63.44110, saving model to ../results/experiment_set_21_time_window\results_window_20\split_2\mlp_model_trained.h5
# 567/567 [==============================] - 3s 5ms/step - loss: 70.6971 - val_loss: 63.4411
# Epoch 9/15
# 559/567 [============================>.] - ETA: 0s - loss: 67.1716
# Epoch 00009: val_loss did not improve from 63.44110
# 567/567 [==============================] - 2s 4ms/step - loss: 67.2279 - val_loss: 65.5625
# Epoch 10/15
# 563/567 [============================>.] - ETA: 0s - loss: 64.8284
# Epoch 00010: val_loss did not improve from 63.44110
# 567/567 [==============================] - 2s 4ms/step - loss: 64.8555 - val_loss: 141.7858
# Epoch 11/15
# 554/567 [============================>.] - ETA: 0s - loss: 66.8766
# Epoch 00011: val_loss did not improve from 63.44110
# 567/567 [==============================] - 2s 4ms/step - loss: 66.7722 - val_loss: 75.6843
# Epoch 12/15
# 562/567 [============================>.] - ETA: 0s - loss: 61.1923
# Epoch 00012: val_loss improved from 63.44110 to 61.62692, saving model to ../results/experiment_set_21_time_window\results_window_20\split_2\mlp_model_trained.h5
# 567/567 [==============================] - 3s 5ms/step - loss: 61.2459 - val_loss: 61.6269
# Epoch 13/15
# 557/567 [============================>.] - ETA: 0s - loss: 58.9908
# Epoch 00013: val_loss did not improve from 61.62692
# 567/567 [==============================] - 2s 4ms/step - loss: 58.9547 - val_loss: 68.5803
# Epoch 14/15
# 559/567 [============================>.] - ETA: 0s - loss: 60.6431
# Epoch 00014: val_loss did not improve from 61.62692
# 567/567 [==============================] - 2s 4ms/step - loss: 60.6468 - val_loss: 73.3340
# Epoch 15/15
# 563/567 [============================>.] - ETA: 0s - loss: 58.3317
# Epoch 00015: val_loss did not improve from 61.62692
# 567/567 [==============================] - 2s 4ms/step - loss: 58.3107 - val_loss: 63.3665
# Saved object to file: ../results/experiment_set_21_time_window\results_window_20\split_2\history_2.pkl
# Test set:
# MSE: 191.74
# RMSE: 13.85
# CMAPSS score: 3.65
#
# MSE: mean = 195.39   stddev = 9.09
# RMSE: mean = 13.97   stddev = 0.32
# CMAPSS: mean = 3.75   stddev = 0.16
