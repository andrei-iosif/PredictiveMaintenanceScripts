# %%
import os
import sys

seed = 0
os.environ['PYTHONHASSEED'] = str(seed)

# %%
import numpy as np
import pandas as pd
import time
import random

from tensorflow.random import set_seed

from sklearn.model_selection import train_test_split

from keras.models import load_model

# %%
# Add modules path
module_path = os.path.abspath('../..')
if module_path not in sys.path:
    sys.path.append(module_path)

# %%
from src.data_reader import DataReader
from src.dataset_exploration import unit_cycle_info
from src.feature_engineering import add_time_lags
from src.metrics import compute_evaluation_metrics
from src.model_evaluation import evaluate_mlp, evaluate_mlp_multiple_splits
from src.plotting import plot_loss_curves
from src.serialization import load_object
from src.training import train_evaluate_mlp, MLPConfigParams
from src.utils import numbers_list_to_string

# %%
# Set seed
random.seed(seed)
np.random.seed(seed)
set_seed(seed)

# %%
# Set input and output paths
filename = '../data/N-CMAPSS_DS02-006.h5'
output_path = '../results/experiment_set_18_2'

if not os.path.exists(output_path):
    os.makedirs(output_path)

# %%
def preprocess_data(train_set, lags_list, selected_columns):
    train_set_lagged = add_time_lags(train_set, lags_list, selected_columns)
    x_train = train_set_lagged[[i for i in list(train_set_lagged.columns) if i != 'RUL']]
    y_train = train_set_lagged['RUL']
    return x_train, y_train

# %%
data_reader = DataReader()

start_time = time.process_time()  
data_reader.load_dataset(filename, load_train=True, load_test=True)
print("Operation time (sec): " , (time.process_time() - start_time))

if data_reader.train_set is not None:
    print("Train set shape: " + str(data_reader.train_set.shape))
    
if data_reader.test_set is not None:   
    print("Test set shape: " + str(data_reader.test_set.shape))
# Out:
# Operation time (sec):  4.53125
# Train set shape: (5263447, 47)
# Test set shape: (1253743, 47)

# %%
train_set = data_reader.train_set

selected_columns = data_reader.column_names.w_cols + data_reader.column_names.x_s_cols
selected_columns_with_unit = selected_columns + ['unit']
train_set = train_set[selected_columns_with_unit + ['RUL']]

train_set = train_set.astype(np.float32)

# %%
#########################################
# Effect of time lags (experiment set 18)
#########################################
NUM_TRIALS = 3
EPOCHS = 15
BATCH_SIZE = 512

mlp_params = MLPConfigParams(layer_sizes=[256, 256, 512, 64], activation='tanh', dropout=0.0)
lags_lists = [[1, 2, 3, 4, 5], [1, 5, 10, 15], [5, 10, 15, 20], [10, 15, 20, 25], [10, 20, 30, 40]]

results_file = os.path.join(output_path, "results_time_lags.csv")
with open(results_file, "w") as file:
    file.write("time_lags,mse,rmse,cmapss,mse(mean),mse(std),rmse(mean),rmse(std),cmapss(mean),cmapss(std)\n")

for idx, lags in enumerate(lags_lists):
    results_folder = f"results_lags_{idx}"
    results_path = os.path.join(output_path, results_folder)
    if not os.path.exists(results_path):
        os.makedirs(results_path)
    
    with open(results_file, "a") as file:
        file.write(f"{numbers_list_to_string(lags)},")
    
    # Add time lags
    x_train, y_train = preprocess_data(train_set, lags, selected_columns) 
    
    # Validation split
    x_train_split, x_holdout_split, y_train_split, y_holdout_split = train_test_split(
        x_train, 
        y_train, 
        test_size=0.3, 
        random_state=seed)
    
    mse_vals, rmse_vals, cmapss_vals = train_evaluate_mlp(
        x_train_split, y_train_split, 
        x_holdout_split, y_holdout_split,
        NUM_TRIALS, 
        mlp_params, 
        results_path, 
        EPOCHS, BATCH_SIZE,
        results_file=results_file)
# Out:
# Saved object to file: ../results/experiment_set_18\results_lags_0\split_0\scaler.pkl
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 256)               27904
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               131584
# _________________________________________________________________
# dense_3 (Dense)              (None, 64)                32832
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 258,177
# Trainable params: 258,177
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/15
# 6477/6477 [==============================] - ETA: 0s - loss: 136.1557
# Epoch 00001: val_loss improved from inf to 44.51247, saving model to ../results/experiment_set_18\results_lags_0\split_0\mlp_model_trained.h5
# 6477/6477 [==============================] - 26s 4ms/step - loss: 136.1557 - val_loss: 44.5125
# Epoch 2/15
# 6470/6477 [============================>.] - ETA: 0s - loss: 37.8087
# Epoch 00002: val_loss improved from 44.51247 to 30.84859, saving model to ../results/experiment_set_18\results_lags_0\split_0\mlp_model_trained.h5
# 6477/6477 [==============================] - 26s 4ms/step - loss: 37.8030 - val_loss: 30.8486
# Epoch 3/15
# 6471/6477 [============================>.] - ETA: 0s - loss: 32.6017
# Epoch 00003: val_loss improved from 30.84859 to 27.94448, saving model to ../results/experiment_set_18\results_lags_0\split_0\mlp_model_trained.h5
# 6477/6477 [==============================] - 27s 4ms/step - loss: 32.5971 - val_loss: 27.9445
# Epoch 4/15
# 6474/6477 [============================>.] - ETA: 0s - loss: 29.1249
# Epoch 00004: val_loss improved from 27.94448 to 24.58710, saving model to ../results/experiment_set_18\results_lags_0\split_0\mlp_model_trained.h5
# 6477/6477 [==============================] - 27s 4ms/step - loss: 29.1229 - val_loss: 24.5871
# Epoch 5/15
# 6473/6477 [============================>.] - ETA: 0s - loss: 26.5106
# Epoch 00005: val_loss did not improve from 24.58710
# 6477/6477 [==============================] - 27s 4ms/step - loss: 26.5090 - val_loss: 25.3836
# Epoch 6/15
# 6468/6477 [============================>.] - ETA: 0s - loss: 24.7509
# Epoch 00006: val_loss did not improve from 24.58710
# 6477/6477 [==============================] - 26s 4ms/step - loss: 24.7498 - val_loss: 27.3124
# Epoch 7/15
# 6470/6477 [============================>.] - ETA: 0s - loss: 23.1717
# Epoch 00007: val_loss improved from 24.58710 to 23.11493, saving model to ../results/experiment_set_18\results_lags_0\split_0\mlp_model_trained.h5
# 6477/6477 [==============================] - 27s 4ms/step - loss: 23.1745 - val_loss: 23.1149
# Epoch 8/15
# 6471/6477 [============================>.] - ETA: 0s - loss: 22.3647
# Epoch 00008: val_loss improved from 23.11493 to 22.13517, saving model to ../results/experiment_set_18\results_lags_0\split_0\mlp_model_trained.h5
# 6477/6477 [==============================] - 26s 4ms/step - loss: 22.3637 - val_loss: 22.1352
# Epoch 9/15
# 6465/6477 [============================>.] - ETA: 0s - loss: 21.4236
# Epoch 00009: val_loss did not improve from 22.13517
# 6477/6477 [==============================] - 26s 4ms/step - loss: 21.4236 - val_loss: 24.4520
# Epoch 10/15
# 6465/6477 [============================>.] - ETA: 0s - loss: 20.5385
# Epoch 00010: val_loss improved from 22.13517 to 18.34738, saving model to ../results/experiment_set_18\results_lags_0\split_0\mlp_model_trained.h5
# 6477/6477 [==============================] - 27s 4ms/step - loss: 20.5398 - val_loss: 18.3474
# Epoch 11/15
# 6468/6477 [============================>.] - ETA: 0s - loss: 19.6672
# Epoch 00011: val_loss did not improve from 18.34738
# 6477/6477 [==============================] - 26s 4ms/step - loss: 19.6661 - val_loss: 22.4351
# Epoch 12/15
# 6471/6477 [============================>.] - ETA: 0s - loss: 19.1474
# Epoch 00012: val_loss did not improve from 18.34738
# 6477/6477 [==============================] - 26s 4ms/step - loss: 19.1457 - val_loss: 20.8571
# Epoch 13/15
# 6474/6477 [============================>.] - ETA: 0s - loss: 18.8783
# Epoch 00013: val_loss did not improve from 18.34738
# 6477/6477 [==============================] - 27s 4ms/step - loss: 18.8779 - val_loss: 24.0194
# Epoch 14/15
# 6475/6477 [============================>.] - ETA: 0s - loss: 18.4144
# Epoch 00014: val_loss improved from 18.34738 to 15.46283, saving model to ../results/experiment_set_18\results_lags_0\split_0\mlp_model_trained.h5
# 6477/6477 [==============================] - 27s 4ms/step - loss: 18.4139 - val_loss: 15.4628
# Epoch 15/15
# 6468/6477 [============================>.] - ETA: 0s - loss: 17.8599
# Epoch 00015: val_loss did not improve from 15.46283
# 6477/6477 [==============================] - 27s 4ms/step - loss: 17.8582 - val_loss: 16.6503
# Saved object to file: ../results/experiment_set_18\results_lags_0\split_0\history_0.pkl
# Test set:
# MSE: 15.48
# RMSE: 3.93
# CMAPSS score: 1.29
#
# Saved object to file: ../results/experiment_set_18\results_lags_0\split_1\scaler.pkl
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_5 (Dense)              (None, 256)               27904
# _________________________________________________________________
# dense_6 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dense_7 (Dense)              (None, 512)               131584
# _________________________________________________________________
# dense_8 (Dense)              (None, 64)                32832
# _________________________________________________________________
# dense_9 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 258,177
# Trainable params: 258,177
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/15
# 6474/6477 [============================>.] - ETA: 0s - loss: 136.9583
# Epoch 00001: val_loss improved from inf to 44.55660, saving model to ../results/experiment_set_18\results_lags_0\split_1\mlp_model_trained.h5
# 6477/6477 [==============================] - 28s 4ms/step - loss: 136.9208 - val_loss: 44.5566
# Epoch 2/15
# 6472/6477 [============================>.] - ETA: 0s - loss: 37.8650
# Epoch 00002: val_loss improved from 44.55660 to 35.20836, saving model to ../results/experiment_set_18\results_lags_0\split_1\mlp_model_trained.h5
# 6477/6477 [==============================] - 27s 4ms/step - loss: 37.8630 - val_loss: 35.2084
# Epoch 3/15
# 6472/6477 [============================>.] - ETA: 0s - loss: 32.6325
# Epoch 00003: val_loss improved from 35.20836 to 27.68848, saving model to ../results/experiment_set_18\results_lags_0\split_1\mlp_model_trained.h5
# 6477/6477 [==============================] - 28s 4ms/step - loss: 32.6307 - val_loss: 27.6885
# Epoch 4/15
# 6466/6477 [============================>.] - ETA: 0s - loss: 29.1698
# Epoch 00004: val_loss did not improve from 27.68848
# 6477/6477 [==============================] - 27s 4ms/step - loss: 29.1721 - val_loss: 38.2390
# Epoch 5/15
# 6469/6477 [============================>.] - ETA: 0s - loss: 26.8377 ETA: 0s
# Epoch 00005: val_loss improved from 27.68848 to 25.80882, saving model to ../results/experiment_set_18\results_lags_0\split_1\mlp_model_trained.h5
# 6477/6477 [==============================] - 28s 4ms/step - loss: 26.8336 - val_loss: 25.8088
# Epoch 6/15
# 6464/6477 [============================>.] - ETA: 0s - loss: 25.1071
# Epoch 00006: val_loss did not improve from 25.80882
# 6477/6477 [==============================] - 26s 4ms/step - loss: 25.1067 - val_loss: 28.9078
# Epoch 7/15
# 6477/6477 [==============================] - ETA: 0s - loss: 23.6315
# Epoch 00007: val_loss improved from 25.80882 to 20.19994, saving model to ../results/experiment_set_18\results_lags_0\split_1\mlp_model_trained.h5
# 6477/6477 [==============================] - 27s 4ms/step - loss: 23.6315 - val_loss: 20.1999
# Epoch 8/15
# 6474/6477 [============================>.] - ETA: 0s - loss: 22.2734
# Epoch 00008: val_loss improved from 20.19994 to 19.37125, saving model to ../results/experiment_set_18\results_lags_0\split_1\mlp_model_trained.h5
# 6477/6477 [==============================] - 27s 4ms/step - loss: 22.2718 - val_loss: 19.3712
# Epoch 9/15
# 6466/6477 [============================>.] - ETA: 0s - loss: 21.5291
# Epoch 00009: val_loss did not improve from 19.37125
# 6477/6477 [==============================] - 27s 4ms/step - loss: 21.5266 - val_loss: 20.9319
# Epoch 10/15
# 6469/6477 [============================>.] - ETA: 0s - loss: 20.7408
# Epoch 00010: val_loss did not improve from 19.37125
# 6477/6477 [==============================] - 26s 4ms/step - loss: 20.7440 - val_loss: 26.4059
# Epoch 11/15
# 6471/6477 [============================>.] - ETA: 0s - loss: 20.2585
# Epoch 00011: val_loss did not improve from 19.37125
# 6477/6477 [==============================] - 26s 4ms/step - loss: 20.2591 - val_loss: 27.5959
# Epoch 12/15
# 6466/6477 [============================>.] - ETA: 0s - loss: 19.5291
# Epoch 00012: val_loss improved from 19.37125 to 16.39092, saving model to ../results/experiment_set_18\results_lags_0\split_1\mlp_model_trained.h5
# 6477/6477 [==============================] - 27s 4ms/step - loss: 19.5259 - val_loss: 16.3909
# Epoch 13/15
# 6472/6477 [============================>.] - ETA: 0s - loss: 19.1215
# Epoch 00013: val_loss did not improve from 16.39092
# 6477/6477 [==============================] - 27s 4ms/step - loss: 19.1208 - val_loss: 20.9429
# Epoch 14/15
# 6471/6477 [============================>.] - ETA: 0s - loss: 18.3455
# Epoch 00014: val_loss improved from 16.39092 to 15.71739, saving model to ../results/experiment_set_18\results_lags_0\split_1\mlp_model_trained.h5
# 6477/6477 [==============================] - 27s 4ms/step - loss: 18.3427 - val_loss: 15.7174
# Epoch 15/15
# 6471/6477 [============================>.] - ETA: 0s - loss: 18.1763
# Epoch 00015: val_loss improved from 15.71739 to 15.45469, saving model to ../results/experiment_set_18\results_lags_0\split_1\mlp_model_trained.h5
# 6477/6477 [==============================] - 27s 4ms/step - loss: 18.1737 - val_loss: 15.4547
# Saved object to file: ../results/experiment_set_18\results_lags_0\split_1\history_1.pkl
# Test set:
# MSE: 15.44
# RMSE: 3.93
# CMAPSS score: 1.30
#
# Saved object to file: ../results/experiment_set_18\results_lags_0\split_2\scaler.pkl
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_10 (Dense)             (None, 256)               27904
# _________________________________________________________________
# dense_11 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dense_12 (Dense)             (None, 512)               131584
# _________________________________________________________________
# dense_13 (Dense)             (None, 64)                32832
# _________________________________________________________________
# dense_14 (Dense)             (None, 1)                 65
# =================================================================
# Total params: 258,177
# Trainable params: 258,177
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/15
#    1/6477 [..............................] - ETA: 0s - loss: 2024.8679WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0000s vs `on_train_batch_end` time: 0.0156s). Check your callbacks.
# 6469/6477 [============================>.] - ETA: 0s - loss: 134.8191- ETA: 0s - loss: 135.4
# Epoch 00001: val_loss improved from inf to 40.72269, saving model to ../results/experiment_set_18\results_lags_0\split_2\mlp_model_trained.h5
# 6477/6477 [==============================] - 28s 4ms/step - loss: 134.7092 - val_loss: 40.7227
# Epoch 2/15
# 6473/6477 [============================>.] - ETA: 0s - loss: 37.0849
# Epoch 00002: val_loss improved from 40.72269 to 33.61155, saving model to ../results/experiment_set_18\results_lags_0\split_2\mlp_model_trained.h5
# 6477/6477 [==============================] - 29s 4ms/step - loss: 37.0832 - val_loss: 33.6116
# Epoch 3/15
# 6464/6477 [============================>.] - ETA: 0s - loss: 31.7646
# Epoch 00003: val_loss did not improve from 33.61155
# 6477/6477 [==============================] - 28s 4ms/step - loss: 31.7672 - val_loss: 36.2757
# Epoch 4/15
# 6470/6477 [============================>.] - ETA: 0s - loss: 28.4660
# Epoch 00004: val_loss improved from 33.61155 to 32.71084, saving model to ../results/experiment_set_18\results_lags_0\split_2\mlp_model_trained.h5
# 6477/6477 [==============================] - 28s 4ms/step - loss: 28.4697 - val_loss: 32.7108
# Epoch 5/15
# 6469/6477 [============================>.] - ETA: 0s - loss: 26.1437
# Epoch 00005: val_loss improved from 32.71084 to 28.13854, saving model to ../results/experiment_set_18\results_lags_0\split_2\mlp_model_trained.h5
# 6477/6477 [==============================] - 28s 4ms/step - loss: 26.1414 - val_loss: 28.1385
# Epoch 6/15
# 6475/6477 [============================>.] - ETA: 0s - loss: 24.7826
# Epoch 00006: val_loss improved from 28.13854 to 22.35409, saving model to ../results/experiment_set_18\results_lags_0\split_2\mlp_model_trained.h5
# 6477/6477 [==============================] - 27s 4ms/step - loss: 24.7813 - val_loss: 22.3541
# Epoch 7/15
# 6476/6477 [============================>.] - ETA: 0s - loss: 23.3090
# Epoch 00007: val_loss improved from 22.35409 to 20.72088, saving model to ../results/experiment_set_18\results_lags_0\split_2\mlp_model_trained.h5
# 6477/6477 [==============================] - 28s 4ms/step - loss: 23.3090 - val_loss: 20.7209
# Epoch 8/15
# 6474/6477 [============================>.] - ETA: 0s - loss: 22.3700
# Epoch 00008: val_loss did not improve from 20.72088
# 6477/6477 [==============================] - 27s 4ms/step - loss: 22.3708 - val_loss: 24.3930
# Epoch 9/15
# 6474/6477 [============================>.] - ETA: 0s - loss: 21.2924
# Epoch 00009: val_loss improved from 20.72088 to 18.59507, saving model to ../results/experiment_set_18\results_lags_0\split_2\mlp_model_trained.h5
# 6477/6477 [==============================] - 28s 4ms/step - loss: 21.2926 - val_loss: 18.5951
# Epoch 10/15
# 6474/6477 [============================>.] - ETA: 0s - loss: 20.5068
# Epoch 00010: val_loss did not improve from 18.59507
# 6477/6477 [==============================] - 27s 4ms/step - loss: 20.5073 - val_loss: 20.4809
# Epoch 11/15
# 6472/6477 [============================>.] - ETA: 0s - loss: 19.7963 E
# Epoch 00011: val_loss did not improve from 18.59507
# 6477/6477 [==============================] - 27s 4ms/step - loss: 19.7976 - val_loss: 25.6769
# Epoch 12/15
# 6467/6477 [============================>.] - ETA: 0s - loss: 19.1395
# Epoch 00012: val_loss improved from 18.59507 to 15.82594, saving model to ../results/experiment_set_18\results_lags_0\split_2\mlp_model_trained.h5
# 6477/6477 [==============================] - 28s 4ms/step - loss: 19.1366 - val_loss: 15.8259
# Epoch 13/15
# 6472/6477 [============================>.] - ETA: 0s - loss: 18.7694
# Epoch 00013: val_loss did not improve from 15.82594
# 6477/6477 [==============================] - 27s 4ms/step - loss: 18.7676 - val_loss: 20.9558
# Epoch 14/15
# 6468/6477 [============================>.] - ETA: 0s - loss: 18.0922
# Epoch 00014: val_loss did not improve from 15.82594
# 6477/6477 [==============================] - 28s 4ms/step - loss: 18.0895 - val_loss: 16.0205
# Epoch 15/15
# 6472/6477 [============================>.] - ETA: 0s - loss: 17.8105
# Epoch 00015: val_loss did not improve from 15.82594
# 6477/6477 [==============================] - 27s 4ms/step - loss: 17.8118 - val_loss: 16.0848
# Saved object to file: ../results/experiment_set_18\results_lags_0\split_2\history_2.pkl
# Test set:
# MSE: 16.03
# RMSE: 4.00
# CMAPSS score: 1.30
#
# MSE: mean = 15.65   stddev = 0.27
# RMSE: mean = 3.96   stddev = 0.03
# CMAPSS: mean = 1.30   stddev = 0.01
# Saved object to file: ../results/experiment_set_18\results_lags_1\split_0\scaler.pkl
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_15 (Dense)             (None, 256)               23296
# _________________________________________________________________
# dense_16 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dense_17 (Dense)             (None, 512)               131584
# _________________________________________________________________
# dense_18 (Dense)             (None, 64)                32832
# _________________________________________________________________
# dense_19 (Dense)             (None, 1)                 65
# =================================================================
# Total params: 253,569
# Trainable params: 253,569
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/15
# 6477/6477 [==============================] - ETA: 0s - loss: 138.0865
# Epoch 00001: val_loss improved from inf to 39.06980, saving model to ../results/experiment_set_18\results_lags_1\split_0\mlp_model_trained.h5
# 6477/6477 [==============================] - 27s 4ms/step - loss: 138.0865 - val_loss: 39.0698
# Epoch 2/15
# 6475/6477 [============================>.] - ETA: 0s - loss: 39.3759
# Epoch 00002: val_loss improved from 39.06980 to 34.70313, saving model to ../results/experiment_set_18\results_lags_1\split_0\mlp_model_trained.h5
# 6477/6477 [==============================] - 28s 4ms/step - loss: 39.3740 - val_loss: 34.7031
# Epoch 3/15
# 6468/6477 [============================>.] - ETA: 0s - loss: 34.7535 ETA: 0s - ETA: 0s - loss: 34.
# Epoch 00003: val_loss did not improve from 34.70313
# 6477/6477 [==============================] - 27s 4ms/step - loss: 34.7635 - val_loss: 36.6426
# Epoch 4/15
# 6468/6477 [============================>.] - ETA: 0s - loss: 31.7035
# Epoch 00004: val_loss improved from 34.70313 to 28.72137, saving model to ../results/experiment_set_18\results_lags_1\split_0\mlp_model_trained.h5
# 6477/6477 [==============================] - 28s 4ms/step - loss: 31.7035 - val_loss: 28.7214
# Epoch 5/15
# 6467/6477 [============================>.] - ETA: 0s - loss: 29.4651 ETA: 0s - loss:
# Epoch 00005: val_loss improved from 28.72137 to 26.85348, saving model to ../results/experiment_set_18\results_lags_1\split_0\mlp_model_trained.h5
# 6477/6477 [==============================] - 27s 4ms/step - loss: 29.4658 - val_loss: 26.8535
# Epoch 6/15
# 6468/6477 [============================>.] - ETA: 0s - loss: 27.5632
# Epoch 00006: val_loss improved from 26.85348 to 24.30004, saving model to ../results/experiment_set_18\results_lags_1\split_0\mlp_model_trained.h5
# 6477/6477 [==============================] - 27s 4ms/step - loss: 27.5568 - val_loss: 24.3000
# Epoch 7/15
# 6467/6477 [============================>.] - ETA: 0s - loss: 26.3536
# Epoch 00007: val_loss improved from 24.30004 to 23.18980, saving model to ../results/experiment_set_18\results_lags_1\split_0\mlp_model_trained.h5
# 6477/6477 [==============================] - 28s 4ms/step - loss: 26.3509 - val_loss: 23.1898
# Epoch 8/15
# 6475/6477 [============================>.] - ETA: 0s - loss: 25.0123 ETA: 0s - los - ETA: 0s - loss: 25.01
# Epoch 00008: val_loss did not improve from 23.18980
# 6477/6477 [==============================] - 28s 4ms/step - loss: 25.0120 - val_loss: 24.1367
# Epoch 9/15
# 6467/6477 [============================>.] - ETA: 0s - loss: 24.1007
# Epoch 00009: val_loss improved from 23.18980 to 22.52985, saving model to ../results/experiment_set_18\results_lags_1\split_0\mlp_model_trained.h5
# 6477/6477 [==============================] - 30s 5ms/step - loss: 24.0975 - val_loss: 22.5299
# Epoch 10/15
# 6474/6477 [============================>.] - ETA: 0s - loss: 23.2791
# Epoch 00010: val_loss did not improve from 22.52985
# 6477/6477 [==============================] - 27s 4ms/step - loss: 23.2791 - val_loss: 23.0472
# Epoch 11/15
# 6468/6477 [============================>.] - ETA: 0s - loss: 22.6092
# Epoch 00011: val_loss improved from 22.52985 to 20.06379, saving model to ../results/experiment_set_18\results_lags_1\split_0\mlp_model_trained.h5
# 6477/6477 [==============================] - 27s 4ms/step - loss: 22.6077 - val_loss: 20.0638
# Epoch 12/15
# 6473/6477 [============================>.] - ETA: 0s - loss: 21.9154
# Epoch 00012: val_loss did not improve from 20.06379
# 6477/6477 [==============================] - 26s 4ms/step - loss: 21.9151 - val_loss: 22.1673
# Epoch 13/15
# 6470/6477 [============================>.] - ETA: 0s - loss: 21.2548 ETA: 0s - loss:
# Epoch 00013: val_loss did not improve from 20.06379
# 6477/6477 [==============================] - 28s 4ms/step - loss: 21.2573 - val_loss: 22.9322
# Epoch 14/15
# 6475/6477 [============================>.] - ETA: 0s - loss: 20.9447
# Epoch 00014: val_loss improved from 20.06379 to 20.06124, saving model to ../results/experiment_set_18\results_lags_1\split_0\mlp_model_trained.h5
# 6477/6477 [==============================] - 28s 4ms/step - loss: 20.9441 - val_loss: 20.0612
# Epoch 15/15
# 6465/6477 [============================>.] - ETA: 0s - loss: 20.2079
# Epoch 00015: val_loss did not improve from 20.06124
# 6477/6477 [==============================] - 28s 4ms/step - loss: 20.2133 - val_loss: 26.9914
# Saved object to file: ../results/experiment_set_18\results_lags_1\split_0\history_0.pkl
# Test set:
# MSE: 19.92
# RMSE: 4.46
# CMAPSS score: 1.35
#
# Saved object to file: ../results/experiment_set_18\results_lags_1\split_1\scaler.pkl
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_20 (Dense)             (None, 256)               23296
# _________________________________________________________________
# dense_21 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dense_22 (Dense)             (None, 512)               131584
# _________________________________________________________________
# dense_23 (Dense)             (None, 64)                32832
# _________________________________________________________________
# dense_24 (Dense)             (None, 1)                 65
# =================================================================
# Total params: 253,569
# Trainable params: 253,569
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/15
# 6467/6477 [============================>.] - ETA: 0s - loss: 133.6137
# Epoch 00001: val_loss improved from inf to 51.29782, saving model to ../results/experiment_set_18\results_lags_1\split_1\mlp_model_trained.h5
# 6477/6477 [==============================] - 26s 4ms/step - loss: 133.4818 - val_loss: 51.2978
# Epoch 2/15
# 6464/6477 [============================>.] - ETA: 0s - loss: 39.1785
# Epoch 00002: val_loss improved from 51.29782 to 34.94978, saving model to ../results/experiment_set_18\results_lags_1\split_1\mlp_model_trained.h5
# 6477/6477 [==============================] - 27s 4ms/step - loss: 39.1735 - val_loss: 34.9498
# Epoch 3/15
# 6466/6477 [============================>.] - ETA: 0s - loss: 33.9760
# Epoch 00003: val_loss did not improve from 34.94978
# 6477/6477 [==============================] - 28s 4ms/step - loss: 33.9756 - val_loss: 38.5077
# Epoch 4/15
# 6468/6477 [============================>.] - ETA: 0s - loss: 31.0082
# Epoch 00004: val_loss improved from 34.94978 to 28.30870, saving model to ../results/experiment_set_18\results_lags_1\split_1\mlp_model_trained.h5
# 6477/6477 [==============================] - 28s 4ms/step - loss: 31.0026 - val_loss: 28.3087
# Epoch 5/15
# 6476/6477 [============================>.] - ETA: 0s - loss: 28.7339
# Epoch 00005: val_loss did not improve from 28.30870
# 6477/6477 [==============================] - 27s 4ms/step - loss: 28.7338 - val_loss: 32.3368
# Epoch 6/15
# 6472/6477 [============================>.] - ETA: 0s - loss: 27.2684 ETA:
# Epoch 00006: val_loss did not improve from 28.30870
# 6477/6477 [==============================] - 27s 4ms/step - loss: 27.2686 - val_loss: 29.6770
# Epoch 7/15
# 6473/6477 [============================>.] - ETA: 0s - loss: 25.9989
# Epoch 00007: val_loss improved from 28.30870 to 24.96008, saving model to ../results/experiment_set_18\results_lags_1\split_1\mlp_model_trained.h5
# 6477/6477 [==============================] - 28s 4ms/step - loss: 25.9969 - val_loss: 24.9601
# Epoch 8/15
# 6472/6477 [============================>.] - ETA: 0s - loss: 24.9094
# Epoch 00008: val_loss improved from 24.96008 to 24.26138, saving model to ../results/experiment_set_18\results_lags_1\split_1\mlp_model_trained.h5
# 6477/6477 [==============================] - 27s 4ms/step - loss: 24.9094 - val_loss: 24.2614
# Epoch 9/15
# 6473/6477 [============================>.] - ETA: 0s - loss: 23.8142
# Epoch 00009: val_loss improved from 24.26138 to 22.49887, saving model to ../results/experiment_set_18\results_lags_1\split_1\mlp_model_trained.h5
# 6477/6477 [==============================] - 28s 4ms/step - loss: 23.8134 - val_loss: 22.4989
# Epoch 10/15
# 6469/6477 [============================>.] - ETA: 0s - loss: 23.0613
# Epoch 00010: val_loss did not improve from 22.49887
# 6477/6477 [==============================] - 27s 4ms/step - loss: 23.0591 - val_loss: 24.6063
# Epoch 11/15
# 6468/6477 [============================>.] - ETA: 0s - loss: 22.3140
# Epoch 00011: val_loss did not improve from 22.49887
# 6477/6477 [==============================] - 27s 4ms/step - loss: 22.3131 - val_loss: 28.6058
# Epoch 12/15
# 6477/6477 [==============================] - ETA: 0s - loss: 21.8097
# Epoch 00012: val_loss did not improve from 22.49887
# 6477/6477 [==============================] - 27s 4ms/step - loss: 21.8097 - val_loss: 23.5635
# Epoch 13/15
# 6469/6477 [============================>.] - ETA: 0s - loss: 21.2810
# Epoch 00013: val_loss did not improve from 22.49887
# 6477/6477 [==============================] - 26s 4ms/step - loss: 21.2892 - val_loss: 29.5643
# Epoch 14/15
# 6471/6477 [============================>.] - ETA: 0s - loss: 20.6662
# Epoch 00014: val_loss improved from 22.49887 to 19.52564, saving model to ../results/experiment_set_18\results_lags_1\split_1\mlp_model_trained.h5
# 6477/6477 [==============================] - 27s 4ms/step - loss: 20.6664 - val_loss: 19.5256
# Epoch 15/15
# 6468/6477 [============================>.] - ETA: 0s - loss: 20.1041
# Epoch 00015: val_loss did not improve from 19.52564
# 6477/6477 [==============================] - 28s 4ms/step - loss: 20.1041 - val_loss: 20.9145
# Saved object to file: ../results/experiment_set_18\results_lags_1\split_1\history_1.pkl
# Test set:
# MSE: 19.44
# RMSE: 4.41
# CMAPSS score: 1.36
#
# Saved object to file: ../results/experiment_set_18\results_lags_1\split_2\scaler.pkl
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_25 (Dense)             (None, 256)               23296
# _________________________________________________________________
# dense_26 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dense_27 (Dense)             (None, 512)               131584
# _________________________________________________________________
# dense_28 (Dense)             (None, 64)                32832
# _________________________________________________________________
# dense_29 (Dense)             (None, 1)                 65
# =================================================================
# Total params: 253,569
# Trainable params: 253,569
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/15
# 6469/6477 [============================>.] - ETA: 0s - loss: 136.1287
# Epoch 00001: val_loss improved from inf to 59.17776, saving model to ../results/experiment_set_18\results_lags_1\split_2\mlp_model_trained.h5
# 6477/6477 [==============================] - 27s 4ms/step - loss: 136.0193 - val_loss: 59.1778
# Epoch 2/15
# 6476/6477 [============================>.] - ETA: 0s - loss: 39.0728
# Epoch 00002: val_loss improved from 59.17776 to 36.44846, saving model to ../results/experiment_set_18\results_lags_1\split_2\mlp_model_trained.h5
# 6477/6477 [==============================] - 27s 4ms/step - loss: 39.0730 - val_loss: 36.4485
# Epoch 3/15
# 6466/6477 [============================>.] - ETA: 0s - loss: 34.7198
# Epoch 00003: val_loss improved from 36.44846 to 34.24633, saving model to ../results/experiment_set_18\results_lags_1\split_2\mlp_model_trained.h5
# 6477/6477 [==============================] - 27s 4ms/step - loss: 34.7236 - val_loss: 34.2463
# Epoch 4/15
# 6471/6477 [============================>.] - ETA: 0s - loss: 31.6177
# Epoch 00004: val_loss improved from 34.24633 to 30.34759, saving model to ../results/experiment_set_18\results_lags_1\split_2\mlp_model_trained.h5
# 6477/6477 [==============================] - 26s 4ms/step - loss: 31.6175 - val_loss: 30.3476
# Epoch 5/15
# 6474/6477 [============================>.] - ETA: 0s - loss: 29.2940
# Epoch 00005: val_loss improved from 30.34759 to 26.65258, saving model to ../results/experiment_set_18\results_lags_1\split_2\mlp_model_trained.h5
# 6477/6477 [==============================] - 27s 4ms/step - loss: 29.2933 - val_loss: 26.6526
# Epoch 6/15
# 6468/6477 [============================>.] - ETA: 0s - loss: 27.5595
# Epoch 00006: val_loss did not improve from 26.65258
# 6477/6477 [==============================] - 26s 4ms/step - loss: 27.5607 - val_loss: 27.0510
# Epoch 7/15
# 6475/6477 [============================>.] - ETA: 0s - loss: 26.2927
# Epoch 00007: val_loss did not improve from 26.65258
# 6477/6477 [==============================] - 26s 4ms/step - loss: 26.2921 - val_loss: 28.3475
# Epoch 8/15
# 6472/6477 [============================>.] - ETA: 0s - loss: 25.0930
# Epoch 00008: val_loss improved from 26.65258 to 24.56129, saving model to ../results/experiment_set_18\results_lags_1\split_2\mlp_model_trained.h5
# 6477/6477 [==============================] - 27s 4ms/step - loss: 25.0928 - val_loss: 24.5613
# Epoch 9/15
# 6465/6477 [============================>.] - ETA: 0s - loss: 24.4517
# Epoch 00009: val_loss improved from 24.56129 to 24.27362, saving model to ../results/experiment_set_18\results_lags_1\split_2\mlp_model_trained.h5
# 6477/6477 [==============================] - 28s 4ms/step - loss: 24.4441 - val_loss: 24.2736
# Epoch 10/15
# 6467/6477 [============================>.] - ETA: 0s - loss: 23.3895
# Epoch 00010: val_loss did not improve from 24.27362
# 6477/6477 [==============================] - 27s 4ms/step - loss: 23.3958 - val_loss: 29.0480
# Epoch 11/15
# 6468/6477 [============================>.] - ETA: 0s - loss: 22.6083
# Epoch 00011: val_loss improved from 24.27362 to 20.52193, saving model to ../results/experiment_set_18\results_lags_1\split_2\mlp_model_trained.h5
# 6477/6477 [==============================] - 27s 4ms/step - loss: 22.6067 - val_loss: 20.5219
# Epoch 12/15
# 6463/6477 [============================>.] - ETA: 0s - loss: 22.0086
# Epoch 00012: val_loss did not improve from 20.52193
# 6477/6477 [==============================] - 27s 4ms/step - loss: 22.0148 - val_loss: 21.4971
# Epoch 13/15
# 6463/6477 [============================>.] - ETA: 0s - loss: 21.2839
# Epoch 00013: val_loss did not improve from 20.52193
# 6477/6477 [==============================] - 27s 4ms/step - loss: 21.2841 - val_loss: 22.8858
# Epoch 14/15
# 6465/6477 [============================>.] - ETA: 0s - loss: 20.8680
# Epoch 00014: val_loss improved from 20.52193 to 18.80138, saving model to ../results/experiment_set_18\results_lags_1\split_2\mlp_model_trained.h5
# 6477/6477 [==============================] - 28s 4ms/step - loss: 20.8641 - val_loss: 18.8014
# Epoch 15/15
# 6467/6477 [============================>.] - ETA: 0s - loss: 20.2310
# Epoch 00015: val_loss did not improve from 18.80138
# 6477/6477 [==============================] - 26s 4ms/step - loss: 20.2313 - val_loss: 26.6026
# Saved object to file: ../results/experiment_set_18\results_lags_1\split_2\history_2.pkl
# Test set:
# MSE: 18.68
# RMSE: 4.32
# CMAPSS score: 1.34
#
# MSE: mean = 19.35   stddev = 0.51
# RMSE: mean = 4.40   stddev = 0.06
# CMAPSS: mean = 1.35   stddev = 0.01
# Saved object to file: ../results/experiment_set_18\results_lags_2\split_0\scaler.pkl
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_30 (Dense)             (None, 256)               23296
# _________________________________________________________________
# dense_31 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dense_32 (Dense)             (None, 512)               131584
# _________________________________________________________________
# dense_33 (Dense)             (None, 64)                32832
# _________________________________________________________________
# dense_34 (Dense)             (None, 1)                 65
# =================================================================
# Total params: 253,569
# Trainable params: 253,569
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/15
# 6477/6477 [==============================] - ETA: 0s - loss: 131.7915- ETA: 0s
# Epoch 00001: val_loss improved from inf to 39.58862, saving model to ../results/experiment_set_18\results_lags_2\split_0\mlp_model_trained.h5
# 6477/6477 [==============================] - 30s 5ms/step - loss: 131.7915 - val_loss: 39.5886
# Epoch 2/15
# 6465/6477 [============================>.] - ETA: 0s - loss: 38.8069
# Epoch 00002: val_loss improved from 39.58862 to 34.59768, saving model to ../results/experiment_set_18\results_lags_2\split_0\mlp_model_trained.h5
# 6477/6477 [==============================] - 29s 4ms/step - loss: 38.8003 - val_loss: 34.5977
# Epoch 3/15
# 6475/6477 [============================>.] - ETA: 0s - loss: 33.8917
# Epoch 00003: val_loss improved from 34.59768 to 30.55381, saving model to ../results/experiment_set_18\results_lags_2\split_0\mlp_model_trained.h5
# 6477/6477 [==============================] - 28s 4ms/step - loss: 33.8926 - val_loss: 30.5538
# Epoch 4/15
# 6472/6477 [============================>.] - ETA: 0s - loss: 31.0531 ETA: 0s - l
# Epoch 00004: val_loss improved from 30.55381 to 29.26056, saving model to ../results/experiment_set_18\results_lags_2\split_0\mlp_model_trained.h5
# 6477/6477 [==============================] - 28s 4ms/step - loss: 31.0507 - val_loss: 29.2606
# Epoch 5/15
# 6477/6477 [==============================] - ETA: 0s - loss: 28.7101
# Epoch 00005: val_loss improved from 29.26056 to 27.41876, saving model to ../results/experiment_set_18\results_lags_2\split_0\mlp_model_trained.h5
# 6477/6477 [==============================] - 26s 4ms/step - loss: 28.7101 - val_loss: 27.4188
# Epoch 6/15
# 6466/6477 [============================>.] - ETA: 0s - loss: 27.3382
# Epoch 00006: val_loss improved from 27.41876 to 26.56980, saving model to ../results/experiment_set_18\results_lags_2\split_0\mlp_model_trained.h5
# 6477/6477 [==============================] - 27s 4ms/step - loss: 27.3386 - val_loss: 26.5698
# Epoch 7/15
# 6477/6477 [==============================] - ETA: 0s - loss: 26.2162
# Epoch 00007: val_loss did not improve from 26.56980
# 6477/6477 [==============================] - 27s 4ms/step - loss: 26.2162 - val_loss: 28.9759
# Epoch 8/15
# 6465/6477 [============================>.] - ETA: 0s - loss: 25.2782
# Epoch 00008: val_loss did not improve from 26.56980
# 6477/6477 [==============================] - 28s 4ms/step - loss: 25.2754 - val_loss: 28.1838
# Epoch 9/15
# 6467/6477 [============================>.] - ETA: 0s - loss: 24.5542
# Epoch 00009: val_loss improved from 26.56980 to 23.95978, saving model to ../results/experiment_set_18\results_lags_2\split_0\mlp_model_trained.h5
# 6477/6477 [==============================] - 27s 4ms/step - loss: 24.5499 - val_loss: 23.9598
# Epoch 10/15
# 6471/6477 [============================>.] - ETA: 0s - loss: 23.7860
# Epoch 00010: val_loss improved from 23.95978 to 23.66781, saving model to ../results/experiment_set_18\results_lags_2\split_0\mlp_model_trained.h5
# 6477/6477 [==============================] - 28s 4ms/step - loss: 23.7859 - val_loss: 23.6678
# Epoch 11/15
# 6469/6477 [============================>.] - ETA: 0s - loss: 23.2152
# Epoch 00011: val_loss improved from 23.66781 to 22.67901, saving model to ../results/experiment_set_18\results_lags_2\split_0\mlp_model_trained.h5
# 6477/6477 [==============================] - 26s 4ms/step - loss: 23.2148 - val_loss: 22.6790
# Epoch 12/15
# 6466/6477 [============================>.] - ETA: 0s - loss: 22.5675 ETA: 1s -
# Epoch 00012: val_loss improved from 22.67901 to 20.79906, saving model to ../results/experiment_set_18\results_lags_2\split_0\mlp_model_trained.h5
# 6477/6477 [==============================] - 27s 4ms/step - loss: 22.5672 - val_loss: 20.7991
# Epoch 13/15
# 6468/6477 [============================>.] - ETA: 0s - loss: 21.9202
# Epoch 00013: val_loss improved from 20.79906 to 20.34060, saving model to ../results/experiment_set_18\results_lags_2\split_0\mlp_model_trained.h5
# 6477/6477 [==============================] - 28s 4ms/step - loss: 21.9173 - val_loss: 20.3406
# Epoch 14/15
# 6477/6477 [==============================] - ETA: 0s - loss: 21.7370
# Epoch 00014: val_loss did not improve from 20.34060
# 6477/6477 [==============================] - 27s 4ms/step - loss: 21.7370 - val_loss: 21.1437
# Epoch 15/15
# 6466/6477 [============================>.] - ETA: 0s - loss: 21.0454
# Epoch 00015: val_loss improved from 20.34060 to 19.23452, saving model to ../results/experiment_set_18\results_lags_2\split_0\mlp_model_trained.h5
# 6477/6477 [==============================] - 27s 4ms/step - loss: 21.0439 - val_loss: 19.2345
# Saved object to file: ../results/experiment_set_18\results_lags_2\split_0\history_0.pkl
# Test set:
# MSE: 19.02
# RMSE: 4.36
# CMAPSS score: 1.36
#
# Saved object to file: ../results/experiment_set_18\results_lags_2\split_1\scaler.pkl
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_35 (Dense)             (None, 256)               23296
# _________________________________________________________________
# dense_36 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dense_37 (Dense)             (None, 512)               131584
# _________________________________________________________________
# dense_38 (Dense)             (None, 64)                32832
# _________________________________________________________________
# dense_39 (Dense)             (None, 1)                 65
# =================================================================
# Total params: 253,569
# Trainable params: 253,569
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/15
# 6468/6477 [============================>.] - ETA: 0s - loss: 134.8312
# Epoch 00001: val_loss improved from inf to 39.69501, saving model to ../results/experiment_set_18\results_lags_2\split_1\mlp_model_trained.h5
# 6477/6477 [==============================] - 27s 4ms/step - loss: 134.7106 - val_loss: 39.6950
# Epoch 2/15
# 6465/6477 [============================>.] - ETA: 0s - loss: 39.5624
# Epoch 00002: val_loss did not improve from 39.69501
# 6477/6477 [==============================] - 27s 4ms/step - loss: 39.5560 - val_loss: 40.2259
# Epoch 3/15
# 6473/6477 [============================>.] - ETA: 0s - loss: 35.1529
# Epoch 00003: val_loss improved from 39.69501 to 32.19464, saving model to ../results/experiment_set_18\results_lags_2\split_1\mlp_model_trained.h5
# 6477/6477 [==============================] - 27s 4ms/step - loss: 35.1526 - val_loss: 32.1946
# Epoch 4/15
# 6470/6477 [============================>.] - ETA: 0s - loss: 31.9516
# Epoch 00004: val_loss improved from 32.19464 to 28.89178, saving model to ../results/experiment_set_18\results_lags_2\split_1\mlp_model_trained.h5
# 6477/6477 [==============================] - 28s 4ms/step - loss: 31.9484 - val_loss: 28.8918
# Epoch 5/15
# 6475/6477 [============================>.] - ETA: 0s - loss: 29.9365 ETA: 0s - loss:
# Epoch 00005: val_loss improved from 28.89178 to 26.61582, saving model to ../results/experiment_set_18\results_lags_2\split_1\mlp_model_trained.h5
# 6477/6477 [==============================] - 28s 4ms/step - loss: 29.9368 - val_loss: 26.6158
# Epoch 6/15
# 6477/6477 [==============================] - ETA: 0s - loss: 28.3542
# Epoch 00006: val_loss did not improve from 26.61582
# 6477/6477 [==============================] - 27s 4ms/step - loss: 28.3542 - val_loss: 27.8835
# Epoch 7/15
# 6475/6477 [============================>.] - ETA: 0s - loss: 27.1498
# Epoch 00007: val_loss improved from 26.61582 to 26.40304, saving model to ../results/experiment_set_18\results_lags_2\split_1\mlp_model_trained.h5
# 6477/6477 [==============================] - 27s 4ms/step - loss: 27.1490 - val_loss: 26.4030
# Epoch 8/15
# 6476/6477 [============================>.] - ETA: 0s - loss: 26.0519 ETA: 0s -
# Epoch 00008: val_loss did not improve from 26.40304
# 6477/6477 [==============================] - 27s 4ms/step - loss: 26.0518 - val_loss: 26.6456
# Epoch 9/15
# 6462/6477 [============================>.] - ETA: 0s - loss: 25.3988
# Epoch 00009: val_loss improved from 26.40304 to 23.01463, saving model to ../results/experiment_set_18\results_lags_2\split_1\mlp_model_trained.h5
# 6477/6477 [==============================] - 27s 4ms/step - loss: 25.3958 - val_loss: 23.0146
# Epoch 10/15
# 6469/6477 [============================>.] - ETA: 0s - loss: 24.5090
# Epoch 00010: val_loss did not improve from 23.01463
# 6477/6477 [==============================] - 27s 4ms/step - loss: 24.5090 - val_loss: 27.6489
# Epoch 11/15
# 6473/6477 [============================>.] - ETA: 0s - loss: 23.8948
# Epoch 00011: val_loss did not improve from 23.01463
# 6477/6477 [==============================] - 28s 4ms/step - loss: 23.8938 - val_loss: 25.2689
# Epoch 12/15
# 6477/6477 [==============================] - ETA: 0s - loss: 23.1464 E
# Epoch 00012: val_loss did not improve from 23.01463
# 6477/6477 [==============================] - 27s 4ms/step - loss: 23.1464 - val_loss: 25.0565
# Epoch 13/15
# 6465/6477 [============================>.] - ETA: 0s - loss: 22.6764
# Epoch 00013: val_loss did not improve from 23.01463
# 6477/6477 [==============================] - 27s 4ms/step - loss: 22.6725 - val_loss: 24.5231
# Epoch 14/15
# 6463/6477 [============================>.] - ETA: 0s - loss: 22.2216
# Epoch 00014: val_loss did not improve from 23.01463
# 6477/6477 [==============================] - 27s 4ms/step - loss: 22.2223 - val_loss: 29.9284
# Epoch 00014: early stopping
# Saved object to file: ../results/experiment_set_18\results_lags_2\split_1\history_1.pkl
# Test set:
# MSE: 23.04
# RMSE: 4.80
# CMAPSS score: 1.42
#
# Saved object to file: ../results/experiment_set_18\results_lags_2\split_2\scaler.pkl
# Model: "sequential_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_40 (Dense)             (None, 256)               23296
# _________________________________________________________________
# dense_41 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dense_42 (Dense)             (None, 512)               131584
# _________________________________________________________________
# dense_43 (Dense)             (None, 64)                32832
# _________________________________________________________________
# dense_44 (Dense)             (None, 1)                 65
# =================================================================
# Total params: 253,569
# Trainable params: 253,569
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/15
#    1/6477 [..............................] - ETA: 0s - loss: 1963.8761WARNING:tensorflow:Callbacks method `on_train_batch_begin` is slow compared to the batch time (batch time: 0.0019s vs `on_train_batch_begin` time: 0.0156s). Check your callbacks.
# 6462/6477 [============================>.] - ETA: 0s - loss: 131.4222
# Epoch 00001: val_loss improved from inf to 41.56428, saving model to ../results/experiment_set_18\results_lags_2\split_2\mlp_model_trained.h5
# 6477/6477 [==============================] - 27s 4ms/step - loss: 131.2201 - val_loss: 41.5643
# Epoch 2/15
# 6475/6477 [============================>.] - ETA: 0s - loss: 38.7616
# Epoch 00002: val_loss improved from 41.56428 to 35.95632, saving model to ../results/experiment_set_18\results_lags_2\split_2\mlp_model_trained.h5
# 6477/6477 [==============================] - 27s 4ms/step - loss: 38.7600 - val_loss: 35.9563
# Epoch 3/15
# 6468/6477 [============================>.] - ETA: 0s - loss: 34.1851 ETA: 0s - los
# Epoch 00003: val_loss improved from 35.95632 to 30.91056, saving model to ../results/experiment_set_18\results_lags_2\split_2\mlp_model_trained.h5
# 6477/6477 [==============================] - 27s 4ms/step - loss: 34.1789 - val_loss: 30.9106
# Epoch 4/15
# 6473/6477 [============================>.] - ETA: 0s - loss: 31.3300
# Epoch 00004: val_loss did not improve from 30.91056
# 6477/6477 [==============================] - 27s 4ms/step - loss: 31.3302 - val_loss: 33.7740
# Epoch 5/15
# 6469/6477 [============================>.] - ETA: 0s - loss: 29.1961
# Epoch 00005: val_loss did not improve from 30.91056
# 6477/6477 [==============================] - 27s 4ms/step - loss: 29.1979 - val_loss: 35.8546
# Epoch 6/15
# 6465/6477 [============================>.] - ETA: 0s - loss: 27.8432
# Epoch 00006: val_loss improved from 30.91056 to 27.23710, saving model to ../results/experiment_set_18\results_lags_2\split_2\mlp_model_trained.h5
# 6477/6477 [==============================] - 27s 4ms/step - loss: 27.8426 - val_loss: 27.2371
# Epoch 7/15
# 6474/6477 [============================>.] - ETA: 0s - loss: 26.5988
# Epoch 00007: val_loss improved from 27.23710 to 26.31441, saving model to ../results/experiment_set_18\results_lags_2\split_2\mlp_model_trained.h5
# 6477/6477 [==============================] - 26s 4ms/step - loss: 26.6007 - val_loss: 26.3144
# Epoch 8/15
# 6469/6477 [============================>.] - ETA: 0s - loss: 25.5765
# Epoch 00008: val_loss did not improve from 26.31441
# 6477/6477 [==============================] - 26s 4ms/step - loss: 25.5804 - val_loss: 43.5960
# Epoch 9/15
# 6470/6477 [============================>.] - ETA: 0s - loss: 25.01 - ETA: 0s - loss: 25.0109
# Epoch 00009: val_loss improved from 26.31441 to 23.30972, saving model to ../results/experiment_set_18\results_lags_2\split_2\mlp_model_trained.h5
# 6477/6477 [==============================] - 26s 4ms/step - loss: 25.0106 - val_loss: 23.3097
# ...
# dense_61 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dense_62 (Dense)             (None, 512)               131584
# _________________________________________________________________
# dense_63 (Dense)             (None, 64)                32832
# _________________________________________________________________
# dense_64 (Dense)             (None, 1)                 65
# =================================================================
# Total params: 253,569
# Trainable params: 253,569
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/15
# 6477/6477 [==============================] - ETA: 0s - loss: 139.3370
# Epoch 00001: val_loss improved from inf to 47.48708, saving model to ../results/experiment_set_18\results_lags_4\split_0\mlp_model_trained.h5
# 6477/6477 [==============================] - 28s 4ms/step - loss: 139.3370 - val_loss: 47.4871
# Epoch 2/15
# 6468/6477 [============================>.] - ETA: 0s - loss: 40.9595
# Epoch 00002: val_loss improved from 47.48708 to 45.98786, saving model to ../results/experiment_set_18\results_lags_4\split_0\mlp_model_trained.h5
# 6477/6477 [==============================] - 28s 4ms/step - loss: 40.9540 - val_loss: 45.9879
# Epoch 3/15
# 6472/6477 [============================>.] - ETA: 0s - loss: 36.9965
# Epoch 00003: val_loss improved from 45.98786 to 37.02273, saving model to ../results/experiment_set_18\results_lags_4\split_0\mlp_model_trained.h5
# 6477/6477 [==============================] - 28s 4ms/step - loss: 36.9940 - val_loss: 37.0227
# Epoch 4/15
# 6477/6477 [==============================] - ETA: 0s - loss: 33.7845
# Epoch 00004: val_loss improved from 37.02273 to 34.57597, saving model to ../results/experiment_set_18\results_lags_4\split_0\mlp_model_trained.h5
# 6477/6477 [==============================] - 27s 4ms/step - loss: 33.7845 - val_loss: 34.5760
# Epoch 5/15
# 6470/6477 [============================>.] - ETA: 0s - loss: 31.7105
# Epoch 00005: val_loss improved from 34.57597 to 31.06783, saving model to ../results/experiment_set_18\results_lags_4\split_0\mlp_model_trained.h5
# 6477/6477 [==============================] - 28s 4ms/step - loss: 31.7077 - val_loss: 31.0678
# Epoch 6/15
# 6474/6477 [============================>.] - ETA: 0s - loss: 29.7074
# Epoch 00006: val_loss improved from 31.06783 to 28.91143, saving model to ../results/experiment_set_18\results_lags_4\split_0\mlp_model_trained.h5
# 6477/6477 [==============================] - 28s 4ms/step - loss: 29.7077 - val_loss: 28.9114
# Epoch 7/15
# 6477/6477 [==============================] - ETA: 0s - loss: 28.3511
# Epoch 00007: val_loss improved from 28.91143 to 26.91393, saving model to ../results/experiment_set_18\results_lags_4\split_0\mlp_model_trained.h5
# 6477/6477 [==============================] - 28s 4ms/step - loss: 28.3511 - val_loss: 26.9139
# Epoch 8/15
# 6468/6477 [============================>.] - ETA: 0s - loss: 27.2108
# Epoch 00008: val_loss did not improve from 26.91393
# 6477/6477 [==============================] - 27s 4ms/step - loss: 27.2141 - val_loss: 36.6988
# Epoch 9/15
# 6474/6477 [============================>.] - ETA: 0s - loss: 26.2528
# Epoch 00009: val_loss improved from 26.91393 to 25.80431, saving model to ../results/experiment_set_18\results_lags_4\split_0\mlp_model_trained.h5
# 6477/6477 [==============================] - 28s 4ms/step - loss: 26.2528 - val_loss: 25.8043
# Epoch 10/15
# 6465/6477 [============================>.] - ETA: 0s - loss: 25.4663
# Epoch 00010: val_loss improved from 25.80431 to 25.32970, saving model to ../results/experiment_set_18\results_lags_4\split_0\mlp_model_trained.h5
# 6477/6477 [==============================] - 28s 4ms/step - loss: 25.4712 - val_loss: 25.3297
# Epoch 11/15
# 6477/6477 [==============================] - ETA: 0s - loss: 24.6706
# Epoch 00011: val_loss improved from 25.32970 to 23.56468, saving model to ../results/experiment_set_18\results_lags_4\split_0\mlp_model_trained.h5
# 6477/6477 [==============================] - 28s 4ms/step - loss: 24.6706 - val_loss: 23.5647
# Epoch 12/15
# 6475/6477 [============================>.] - ETA: 0s - loss: 24.0476
# Epoch 00012: val_loss did not improve from 23.56468
# 6477/6477 [==============================] - 28s 4ms/step - loss: 24.0481 - val_loss: 29.4836
# Epoch 13/15
# 6468/6477 [============================>.] - ETA: 0s - loss: 23.1684
# Epoch 00013: val_loss did not improve from 23.56468
# 6477/6477 [==============================] - 28s 4ms/step - loss: 23.1688 - val_loss: 27.3261
# Epoch 14/15
# 6464/6477 [============================>.] - ETA: 0s - loss: 22.5934
# Epoch 00014: val_loss did not improve from 23.56468
# 6477/6477 [==============================] - 28s 4ms/step - loss: 22.5969 - val_loss: 23.8633
# Epoch 15/15
# 6473/6477 [============================>.] - ETA: 0s - loss: 22.4333
# Epoch 00015: val_loss did not improve from 23.56468
# 6477/6477 [==============================] - 28s 4ms/step - loss: 22.4338 - val_loss: 23.6336
# Saved object to file: ../results/experiment_set_18\results_lags_4\split_0\history_0.pkl
# Test set:
# MSE: 23.44
# RMSE: 4.84
# CMAPSS score: 1.39
#
# Saved object to file: ../results/experiment_set_18\results_lags_4\split_1\scaler.pkl
# Model: "sequential_13"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_65 (Dense)             (None, 256)               23296
# _________________________________________________________________
# dense_66 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dense_67 (Dense)             (None, 512)               131584
# _________________________________________________________________
# dense_68 (Dense)             (None, 64)                32832
# _________________________________________________________________
# dense_69 (Dense)             (None, 1)                 65
# =================================================================
# Total params: 253,569
# Trainable params: 253,569
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/15
# 6466/6477 [============================>.] - ETA: 0s - loss: 136.9650
# Epoch 00001: val_loss improved from inf to 47.00681, saving model to ../results/experiment_set_18\results_lags_4\split_1\mlp_model_trained.h5
# 6477/6477 [==============================] - 28s 4ms/step - loss: 136.8116 - val_loss: 47.0068
# Epoch 2/15
# 6477/6477 [==============================] - ETA: 0s - loss: 40.0732
# Epoch 00002: val_loss did not improve from 47.00681
# 6477/6477 [==============================] - 28s 4ms/step - loss: 40.0732 - val_loss: 64.6660
# Epoch 3/15
# 6471/6477 [============================>.] - ETA: 0s - loss: 35.3814
# Epoch 00003: val_loss improved from 47.00681 to 35.41477, saving model to ../results/experiment_set_18\results_lags_4\split_1\mlp_model_trained.h5
# 6477/6477 [==============================] - 28s 4ms/step - loss: 35.3825 - val_loss: 35.4148
# Epoch 4/15
# 6467/6477 [============================>.] - ETA: 0s - loss: 32.4131
# Epoch 00004: val_loss did not improve from 35.41477
# 6477/6477 [==============================] - 27s 4ms/step - loss: 32.4123 - val_loss: 39.0415
# Epoch 5/15
# 6470/6477 [============================>.] - ETA: 0s - loss: 30.2805
# Epoch 00005: val_loss did not improve from 35.41477
# 6477/6477 [==============================] - 28s 4ms/step - loss: 30.2832 - val_loss: 45.3080
# Epoch 6/15
# 6466/6477 [============================>.] - ETA: 0s - loss: 28.7497
# Epoch 00006: val_loss improved from 35.41477 to 27.34611, saving model to ../results/experiment_set_18\results_lags_4\split_1\mlp_model_trained.h5
# 6477/6477 [==============================] - 28s 4ms/step - loss: 28.7479 - val_loss: 27.3461
# Epoch 7/15
# 6475/6477 [============================>.] - ETA: 0s - loss: 27.4848
# Epoch 00007: val_loss did not improve from 27.34611
# 6477/6477 [==============================] - 27s 4ms/step - loss: 27.4857 - val_loss: 33.4068
# Epoch 8/15
# 6462/6477 [============================>.] - ETA: 0s - loss: 26.2675
# Epoch 00008: val_loss improved from 27.34611 to 24.20856, saving model to ../results/experiment_set_18\results_lags_4\split_1\mlp_model_trained.h5
# 6477/6477 [==============================] - 28s 4ms/step - loss: 26.2652 - val_loss: 24.2086
# Epoch 9/15
# 6468/6477 [============================>.] - ETA: 0s - loss: 25.3029
# Epoch 00009: val_loss improved from 24.20856 to 23.89185, saving model to ../results/experiment_set_18\results_lags_4\split_1\mlp_model_trained.h5
# 6477/6477 [==============================] - 28s 4ms/step - loss: 25.3002 - val_loss: 23.8918
# Epoch 10/15
# 6464/6477 [============================>.] - ETA: 0s - loss: 24.4297
# Epoch 00010: val_loss improved from 23.89185 to 22.98471, saving model to ../results/experiment_set_18\results_lags_4\split_1\mlp_model_trained.h5
# 6477/6477 [==============================] - 28s 4ms/step - loss: 24.4265 - val_loss: 22.9847
# Epoch 11/15
# 6475/6477 [============================>.] - ETA: 0s - loss: 23.5169 E
# Epoch 00011: val_loss did not improve from 22.98471
# 6477/6477 [==============================] - 27s 4ms/step - loss: 23.5175 - val_loss: 26.8889
# Epoch 12/15
# 6463/6477 [============================>.] - ETA: 0s - loss: 22.9506
# Epoch 00012: val_loss did not improve from 22.98471
# 6477/6477 [==============================] - 27s 4ms/step - loss: 22.9516 - val_loss: 23.5822
# Epoch 13/15
# 6470/6477 [============================>.] - ETA: 0s - loss: 22.2564
# Epoch 00013: val_loss did not improve from 22.98471
# 6477/6477 [==============================] - 28s 4ms/step - loss: 22.2634 - val_loss: 33.0060
# Epoch 14/15
# 6477/6477 [==============================] - ETA: 0s - loss: 21.5049
# Epoch 00014: val_loss improved from 22.98471 to 19.45650, saving model to ../results/experiment_set_18\results_lags_4\split_1\mlp_model_trained.h5
# 6477/6477 [==============================] - 28s 4ms/step - loss: 21.5049 - val_loss: 19.4565
# Epoch 15/15
# 6464/6477 [============================>.] - ETA: 0s - loss: 21.2377
# Epoch 00015: val_loss did not improve from 19.45650
# 6477/6477 [==============================] - 27s 4ms/step - loss: 21.2381 - val_loss: 20.6340
# Saved object to file: ../results/experiment_set_18\results_lags_4\split_1\history_1.pkl
# Test set:
# MSE: 19.45
# RMSE: 4.41
# CMAPSS score: 1.35
#
# Saved object to file: ../results/experiment_set_18\results_lags_4\split_2\scaler.pkl
# Model: "sequential_14"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_70 (Dense)             (None, 256)               23296
# _________________________________________________________________
# dense_71 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dense_72 (Dense)             (None, 512)               131584
# _________________________________________________________________
# dense_73 (Dense)             (None, 64)                32832
# _________________________________________________________________
# dense_74 (Dense)             (None, 1)                 65
# =================================================================
# Total params: 253,569
# Trainable params: 253,569
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/15
# 6470/6477 [============================>.] - ETA: 0s - loss: 138.0535
# Epoch 00001: val_loss improved from inf to 42.16594, saving model to ../results/experiment_set_18\results_lags_4\split_2\mlp_model_trained.h5
# 6477/6477 [==============================] - 26s 4ms/step - loss: 137.9663 - val_loss: 42.1659
# Epoch 2/15
# 6465/6477 [============================>.] - ETA: 0s - loss: 40.3266
# Epoch 00002: val_loss improved from 42.16594 to 34.94168, saving model to ../results/experiment_set_18\results_lags_4\split_2\mlp_model_trained.h5
# 6477/6477 [==============================] - 27s 4ms/step - loss: 40.3234 - val_loss: 34.9417
# Epoch 3/15
# 6466/6477 [============================>.] - ETA: 0s - loss: 35.8518
# Epoch 00003: val_loss did not improve from 34.94168
# 6477/6477 [==============================] - 26s 4ms/step - loss: 35.8495 - val_loss: 37.1160
# Epoch 4/15
# 6471/6477 [============================>.] - ETA: 0s - loss: 32.7874
# Epoch 00004: val_loss improved from 34.94168 to 32.45509, saving model to ../results/experiment_set_18\results_lags_4\split_2\mlp_model_trained.h5
# 6477/6477 [==============================] - 27s 4ms/step - loss: 32.7870 - val_loss: 32.4551
# Epoch 5/15
# 6465/6477 [============================>.] - ETA: 0s - loss: 30.3017
# Epoch 00005: val_loss improved from 32.45509 to 26.61604, saving model to ../results/experiment_set_18\results_lags_4\split_2\mlp_model_trained.h5
# 6477/6477 [==============================] - 28s 4ms/step - loss: 30.2959 - val_loss: 26.6160
# Epoch 6/15
# 6471/6477 [============================>.] - ETA: 0s - loss: 28.6332
# Epoch 00006: val_loss did not improve from 26.61604
# 6477/6477 [==============================] - 27s 4ms/step - loss: 28.6350 - val_loss: 31.3919
# Epoch 7/15
# 6475/6477 [============================>.] - ETA: 0s - loss: 27.3222
# Epoch 00007: val_loss did not improve from 26.61604
# 6477/6477 [==============================] - 26s 4ms/step - loss: 27.3243 - val_loss: 41.5443
# Epoch 8/15
# 6463/6477 [============================>.] - ETA: 0s - loss: 26.1475
# Epoch 00008: val_loss improved from 26.61604 to 23.57764, saving model to ../results/experiment_set_18\results_lags_4\split_2\mlp_model_trained.h5
# 6477/6477 [==============================] - 27s 4ms/step - loss: 26.1460 - val_loss: 23.5776
# Epoch 9/15
# 6472/6477 [============================>.] - ETA: 0s - loss: 25.3916
# Epoch 00009: val_loss did not improve from 23.57764
# 6477/6477 [==============================] - 26s 4ms/step - loss: 25.3911 - val_loss: 23.7469
# Epoch 10/15
# 6473/6477 [============================>.] - ETA: 0s - loss: 24.3398
# Epoch 00010: val_loss improved from 23.57764 to 21.95059, saving model to ../results/experiment_set_18\results_lags_4\split_2\mlp_model_trained.h5
# 6477/6477 [==============================] - 27s 4ms/step - loss: 24.3385 - val_loss: 21.9506
# Epoch 11/15
# 6475/6477 [============================>.] - ETA: 0s - loss: 23.4380
# Epoch 00011: val_loss did not improve from 21.95059
# 6477/6477 [==============================] - 26s 4ms/step - loss: 23.4384 - val_loss: 21.9921
# Epoch 12/15
# 6472/6477 [============================>.] - ETA: 0s - loss: 22.7820 ETA: 0s -
# Epoch 00012: val_loss did not improve from 21.95059
# 6477/6477 [==============================] - 27s 4ms/step - loss: 22.7809 - val_loss: 26.2624
# Epoch 13/15
# 6472/6477 [============================>.] - ETA: 0s - loss: 22.3131 ETA
# Epoch 00013: val_loss did not improve from 21.95059
# 6477/6477 [==============================] - 27s 4ms/step - loss: 22.3116 - val_loss: 23.6331
# Epoch 14/15
# 6473/6477 [============================>.] - ETA: 0s - loss: 21.6467
# Epoch 00014: val_loss improved from 21.95059 to 21.93978, saving model to ../results/experiment_set_18\results_lags_4\split_2\mlp_model_trained.h5
# 6477/6477 [==============================] - 27s 4ms/step - loss: 21.6453 - val_loss: 21.9398
# Epoch 15/15
# 6469/6477 [============================>.] - ETA: 0s - loss: 20.9817
# Epoch 00015: val_loss improved from 21.93978 to 20.20869, saving model to ../results/experiment_set_18\results_lags_4\split_2\mlp_model_trained.h5
# 6477/6477 [==============================] - 27s 4ms/step - loss: 20.9817 - val_loss: 20.2087
# Saved object to file: ../results/experiment_set_18\results_lags_4\split_2\history_2.pkl
# Test set:
# MSE: 20.24
# RMSE: 4.50
# CMAPSS score: 1.38
#
# MSE: mean = 21.04   stddev = 1.73
# RMSE: mean = 4.58   stddev = 0.19
# CMAPSS: mean = 1.37   stddev = 0.02

# %%
# Train on whole set
train_set = data_reader.train_set
test_set = data_reader.test_set

selected_columns = data_reader.column_names.w_cols + data_reader.column_names.x_s_cols
selected_columns_with_unit = selected_columns + ['unit']

train_set = train_set[selected_columns_with_unit + ['RUL']]
test_set = test_set[selected_columns_with_unit + ['RUL']]

train_set = train_set.astype(np.float32)
test_set = test_set.astype(np.float32)

# %%
###########################################
# Effect of time lags (experiment set 18_1)
###########################################
NUM_TRIALS = 3
EPOCHS = 60
BATCH_SIZE = 512

mlp_params = MLPConfigParams(layer_sizes=[256, 256, 512, 64], activation='tanh', dropout=0.0)
lags = [1, 2, 3, 4, 5]

results_file = os.path.join(output_path, "results_time_lags.csv")
with open(results_file, "w") as file:
    file.write("time_lags,mse,rmse,cmapss,mse(mean),mse(std),rmse(mean),rmse(std),cmapss(mean),cmapss(std)\n")

results_path = output_path
    
with open(results_file, "a") as file:
    file.write(f"{numbers_list_to_string(lags)},")
    
# Add time lags
x_train, y_train = preprocess_data(train_set, lags, selected_columns) 
x_test, y_test = preprocess_data(test_set, lags, selected_columns) 
      
mse_vals, rmse_vals, cmapss_vals = train_evaluate_mlp(
    x_train, y_train, 
    x_test, y_test,
    NUM_TRIALS, 
    mlp_params, 
    results_path, 
    EPOCHS, BATCH_SIZE,
    results_file=results_file)
# Out:
# Saved object to file: ../results/experiment_set_18_1\split_0\scaler.pkl
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 256)               27904
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               131584
# _________________________________________________________________
# dense_3 (Dense)              (None, 64)                32832
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 258,177
# Trainable params: 258,177
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/60
# 9246/9253 [============================>.] - ETA: 0s - loss: 107.7584
# Epoch 00001: val_loss improved from inf to 36.04058, saving model to ../results/experiment_set_18_1\split_0\mlp_model_trained.h5
# 9253/9253 [==============================] - 38s 4ms/step - loss: 107.7110 - val_loss: 36.0406
# Epoch 2/60
# 9246/9253 [============================>.] - ETA: 0s - loss: 34.4774
# Epoch 00002: val_loss improved from 36.04058 to 28.96757, saving model to ../results/experiment_set_18_1\split_0\mlp_model_trained.h5
# 9253/9253 [==============================] - 39s 4ms/step - loss: 34.4761 - val_loss: 28.9676
# Epoch 3/60
# 9245/9253 [============================>.] - ETA: 0s - loss: 29.2772
# Epoch 00003: val_loss did not improve from 28.96757
# 9253/9253 [==============================] - 38s 4ms/step - loss: 29.2743 - val_loss: 30.0110
# Epoch 4/60
# 9243/9253 [============================>.] - ETA: 0s - loss: 25.9350
# Epoch 00004: val_loss did not improve from 28.96757
# 9253/9253 [==============================] - 38s 4ms/step - loss: 25.9365 - val_loss: 29.6762
# Epoch 5/60
# 9245/9253 [============================>.] - ETA: 0s - loss: 23.6655
# Epoch 00005: val_loss improved from 28.96757 to 23.40369, saving model to ../results/experiment_set_18_1\split_0\mlp_model_trained.h5
# 9253/9253 [==============================] - 38s 4ms/step - loss: 23.6625 - val_loss: 23.4037
# Epoch 6/60
# 9248/9253 [============================>.] - ETA: 0s - loss: 21.8942
# Epoch 00006: val_loss improved from 23.40369 to 19.44157, saving model to ../results/experiment_set_18_1\split_0\mlp_model_trained.h5
# 9253/9253 [==============================] - 38s 4ms/step - loss: 21.8932 - val_loss: 19.4416
# Epoch 7/60
# 9251/9253 [============================>.] - ETA: 0s - loss: 20.6548
# Epoch 00007: val_loss did not improve from 19.44157
# 9253/9253 [==============================] - 38s 4ms/step - loss: 20.6546 - val_loss: 20.9450
# Epoch 8/60
# 9242/9253 [============================>.] - ETA: 0s - loss: 19.6984
# Epoch 00008: val_loss improved from 19.44157 to 19.15187, saving model to ../results/experiment_set_18_1\split_0\mlp_model_trained.h5
# 9253/9253 [==============================] - 39s 4ms/step - loss: 19.6996 - val_loss: 19.1519
# Epoch 9/60
# 9247/9253 [============================>.] - ETA: 0s - loss: 18.8736
# Epoch 00009: val_loss improved from 19.15187 to 16.16238, saving model to ../results/experiment_set_18_1\split_0\mlp_model_trained.h5
# 9253/9253 [==============================] - 37s 4ms/step - loss: 18.8732 - val_loss: 16.1624
# Epoch 10/60
# 9251/9253 [============================>.] - ETA: 0s - loss: 18.1070
# Epoch 00010: val_loss did not improve from 16.16238
# 9253/9253 [==============================] - 37s 4ms/step - loss: 18.1072 - val_loss: 20.2226
# Epoch 11/60
# 9252/9253 [============================>.] - ETA: 0s - loss: 17.7362
# Epoch 00011: val_loss did not improve from 16.16238
# 9253/9253 [==============================] - 37s 4ms/step - loss: 17.7362 - val_loss: 26.3123
# Epoch 12/60
# 9244/9253 [============================>.] - ETA: 0s - loss: 17.2343
# Epoch 00012: val_loss did not improve from 16.16238
# 9253/9253 [==============================] - 36s 4ms/step - loss: 17.2363 - val_loss: 20.4990
# Epoch 13/60
# 9245/9253 [============================>.] - ETA: 0s - loss: 16.8930
# Epoch 00013: val_loss did not improve from 16.16238
# 9253/9253 [==============================] - 37s 4ms/step - loss: 16.8923 - val_loss: 23.2256
# Epoch 14/60
# 9243/9253 [============================>.] - ETA: 0s - loss: 16.3469
# Epoch 00014: val_loss improved from 16.16238 to 15.78534, saving model to ../results/experiment_set_18_1\split_0\mlp_model_trained.h5
# 9253/9253 [==============================] - 37s 4ms/step - loss: 16.3465 - val_loss: 15.7853
# Epoch 15/60
# 9252/9253 [============================>.] - ETA: 0s - loss: 15.9724
# Epoch 00015: val_loss did not improve from 15.78534
# 9253/9253 [==============================] - 37s 4ms/step - loss: 15.9723 - val_loss: 15.9027
# Epoch 16/60
# 9248/9253 [============================>.] - ETA: 0s - loss: 15.8879
# Epoch 00016: val_loss improved from 15.78534 to 13.55884, saving model to ../results/experiment_set_18_1\split_0\mlp_model_trained.h5
# 9253/9253 [==============================] - 37s 4ms/step - loss: 15.8878 - val_loss: 13.5588
# Epoch 17/60
# 9243/9253 [============================>.] - ETA: 0s - loss: 15.5271
# Epoch 00017: val_loss did not improve from 13.55884
# 9253/9253 [==============================] - 37s 4ms/step - loss: 15.5262 - val_loss: 16.4171
# Epoch 18/60
# 9253/9253 [==============================] - ETA: 0s - loss: 15.4828
# Epoch 00018: val_loss did not improve from 13.55884
# 9253/9253 [==============================] - 37s 4ms/step - loss: 15.4828 - val_loss: 16.6964
# Epoch 19/60
# 9244/9253 [============================>.] - ETA: 0s - loss: 15.1325
# Epoch 00019: val_loss did not improve from 13.55884
# 9253/9253 [==============================] - 37s 4ms/step - loss: 15.1340 - val_loss: 17.4666
# Epoch 20/60
# 9250/9253 [============================>.] - ETA: 0s - loss: 14.8617
# Epoch 00020: val_loss improved from 13.55884 to 12.92497, saving model to ../results/experiment_set_18_1\split_0\mlp_model_trained.h5
# 9253/9253 [==============================] - 38s 4ms/step - loss: 14.8610 - val_loss: 12.9250
# Epoch 21/60
# 9240/9253 [============================>.] - ETA: 0s - loss: 14.6739
# Epoch 00021: val_loss improved from 12.92497 to 12.40567, saving model to ../results/experiment_set_18_1\split_0\mlp_model_trained.h5
# 9253/9253 [==============================] - 38s 4ms/step - loss: 14.6738 - val_loss: 12.4057
# Epoch 22/60
# 9252/9253 [============================>.] - ETA: 0s - loss: 14.3953
# Epoch 00022: val_loss did not improve from 12.40567
# 9253/9253 [==============================] - 37s 4ms/step - loss: 14.3954 - val_loss: 13.5198
# Epoch 23/60
# 9246/9253 [============================>.] - ETA: 0s - loss: 14.4830
# Epoch 00023: val_loss did not improve from 12.40567
# 9253/9253 [==============================] - 37s 4ms/step - loss: 14.4806 - val_loss: 13.1300
# Epoch 24/60
# 9244/9253 [============================>.] - ETA: 0s - loss: 14.3784
# Epoch 00024: val_loss did not improve from 12.40567
# 9253/9253 [==============================] - 38s 4ms/step - loss: 14.3782 - val_loss: 13.2639
# Epoch 25/60
# 9253/9253 [==============================] - ETA: 0s - loss: 14.0818
# Epoch 00025: val_loss did not improve from 12.40567
# 9253/9253 [==============================] - 37s 4ms/step - loss: 14.0818 - val_loss: 17.6582
# Epoch 26/60
# 9248/9253 [============================>.] - ETA: 0s - loss: 14.0397
# Epoch 00026: val_loss did not improve from 12.40567
# 9253/9253 [==============================] - 37s 4ms/step - loss: 14.0410 - val_loss: 13.3362
# Epoch 00026: early stopping
# Saved object to file: ../results/experiment_set_18_1\split_0\history_0.pkl
# Test set:
# MSE: 66.35
# RMSE: 8.15
# CMAPSS score: 1.82
#
# Saved object to file: ../results/experiment_set_18_1\split_1\scaler.pkl
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_5 (Dense)              (None, 256)               27904
# _________________________________________________________________
# dense_6 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dense_7 (Dense)              (None, 512)               131584
# _________________________________________________________________
# dense_8 (Dense)              (None, 64)                32832
# _________________________________________________________________
# dense_9 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 258,177
# Trainable params: 258,177
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/60
# 9243/9253 [============================>.] - ETA: 0s - loss: 107.9752
# Epoch 00001: val_loss improved from inf to 47.54068, saving model to ../results/experiment_set_18_1\split_1\mlp_model_trained.h5
# 9253/9253 [==============================] - 39s 4ms/step - loss: 107.9067 - val_loss: 47.5407
# Epoch 2/60
# 9253/9253 [==============================] - ETA: 0s - loss: 33.9332
# Epoch 00002: val_loss improved from 47.54068 to 28.38743, saving model to ../results/experiment_set_18_1\split_1\mlp_model_trained.h5
# 9253/9253 [==============================] - 39s 4ms/step - loss: 33.9332 - val_loss: 28.3874
# Epoch 3/60
# 9244/9253 [============================>.] - ETA: 0s - loss: 28.7230
# Epoch 00003: val_loss did not improve from 28.38743
# 9253/9253 [==============================] - 38s 4ms/step - loss: 28.7187 - val_loss: 28.9919
# Epoch 4/60
# 9250/9253 [============================>.] - ETA: 0s - loss: 25.3405
# Epoch 00004: val_loss improved from 28.38743 to 24.54458, saving model to ../results/experiment_set_18_1\split_1\mlp_model_trained.h5
# 9253/9253 [==============================] - 38s 4ms/step - loss: 25.3404 - val_loss: 24.5446
# Epoch 5/60
# 9251/9253 [============================>.] - ETA: 0s - loss: 23.1512
# Epoch 00005: val_loss improved from 24.54458 to 21.24170, saving model to ../results/experiment_set_18_1\split_1\mlp_model_trained.h5
# 9253/9253 [==============================] - 38s 4ms/step - loss: 23.1509 - val_loss: 21.2417
# Epoch 6/60
# 9247/9253 [============================>.] - ETA: 0s - loss: 21.7120
# Epoch 00006: val_loss did not improve from 21.24170
# 9253/9253 [==============================] - 38s 4ms/step - loss: 21.7109 - val_loss: 24.5471
# Epoch 7/60
# 9244/9253 [============================>.] - ETA: 0s - loss: 20.5334
# Epoch 00007: val_loss did not improve from 21.24170
# 9253/9253 [==============================] - 39s 4ms/step - loss: 20.5336 - val_loss: 21.9279
# Epoch 8/60
# 9251/9253 [============================>.] - ETA: 0s - loss: 19.6782
# Epoch 00008: val_loss improved from 21.24170 to 18.89826, saving model to ../results/experiment_set_18_1\split_1\mlp_model_trained.h5
# 9253/9253 [==============================] - 39s 4ms/step - loss: 19.6779 - val_loss: 18.8983
# Epoch 9/60
# 9247/9253 [============================>.] - ETA: 0s - loss: 18.8990
# Epoch 00009: val_loss improved from 18.89826 to 17.56199, saving model to ../results/experiment_set_18_1\split_1\mlp_model_trained.h5
# 9253/9253 [==============================] - 40s 4ms/step - loss: 18.8986 - val_loss: 17.5620
# Epoch 10/60
# 9244/9253 [============================>.] - ETA: 0s - loss: 18.1996
# Epoch 00010: val_loss improved from 17.56199 to 17.04608, saving model to ../results/experiment_set_18_1\split_1\mlp_model_trained.h5
# 9253/9253 [==============================] - 39s 4ms/step - loss: 18.1985 - val_loss: 17.0461
# Epoch 11/60
# 9243/9253 [============================>.] - ETA: 0s - loss: 17.7113
# Epoch 00011: val_loss did not improve from 17.04608
# 9253/9253 [==============================] - 39s 4ms/step - loss: 17.7119 - val_loss: 23.6411
# Epoch 12/60
# 9242/9253 [============================>.] - ETA: 0s - loss: 17.2241
# Epoch 00012: val_loss did not improve from 17.04608
# 9253/9253 [==============================] - 38s 4ms/step - loss: 17.2254 - val_loss: 19.1323
# Epoch 13/60
# 9246/9253 [============================>.] - ETA: 0s - loss: 16.7775
# Epoch 00013: val_loss improved from 17.04608 to 14.91694, saving model to ../results/experiment_set_18_1\split_1\mlp_model_trained.h5
# 9253/9253 [==============================] - 39s 4ms/step - loss: 16.7772 - val_loss: 14.9169
# Epoch 14/60
# 9248/9253 [============================>.] - ETA: 0s - loss: 16.4925
# Epoch 00014: val_loss did not improve from 14.91694
# 9253/9253 [==============================] - 39s 4ms/step - loss: 16.4919 - val_loss: 17.3688
# Epoch 15/60
# 9249/9253 [============================>.] - ETA: 0s - loss: 16.0210
# Epoch 00015: val_loss did not improve from 14.91694
# 9253/9253 [==============================] - 38s 4ms/step - loss: 16.0218 - val_loss: 21.8518
# Epoch 16/60
# 9242/9253 [============================>.] - ETA: 0s - loss: 15.9642
# Epoch 00016: val_loss did not improve from 14.91694
# 9253/9253 [==============================] - 38s 4ms/step - loss: 15.9687 - val_loss: 36.1905
# Epoch 17/60
# 9251/9253 [============================>.] - ETA: 0s - loss: 15.4910
# Epoch 00017: val_loss improved from 14.91694 to 13.22403, saving model to ../results/experiment_set_18_1\split_1\mlp_model_trained.h5
# 9253/9253 [==============================] - 39s 4ms/step - loss: 15.4907 - val_loss: 13.2240
# Epoch 18/60
# 9250/9253 [============================>.] - ETA: 0s - loss: 15.1937
# Epoch 00018: val_loss did not improve from 13.22403
# 9253/9253 [==============================] - 39s 4ms/step - loss: 15.1944 - val_loss: 15.6969
# Epoch 19/60
# 9246/9253 [============================>.] - ETA: 0s - loss: 15.0054
# Epoch 00019: val_loss did not improve from 13.22403
# 9253/9253 [==============================] - 39s 4ms/step - loss: 15.0106 - val_loss: 24.9630
# Epoch 20/60
# 9241/9253 [============================>.] - ETA: 0s - loss: 14.8105
# Epoch 00020: val_loss did not improve from 13.22403
# 9253/9253 [==============================] - 39s 4ms/step - loss: 14.8076 - val_loss: 13.5359
# Epoch 21/60
# 9242/9253 [============================>.] - ETA: 0s - loss: 14.6041
# Epoch 00021: val_loss improved from 13.22403 to 12.60817, saving model to ../results/experiment_set_18_1\split_1\mlp_model_trained.h5
# 9253/9253 [==============================] - 39s 4ms/step - loss: 14.6051 - val_loss: 12.6082
# Epoch 22/60
# 9252/9253 [============================>.] - ETA: 0s - loss: 14.3000
# Epoch 00022: val_loss did not improve from 12.60817
# 9253/9253 [==============================] - 38s 4ms/step - loss: 14.3000 - val_loss: 14.0714
# Epoch 23/60
# 9242/9253 [============================>.] - ETA: 0s - loss: 14.1386
# Epoch 00023: val_loss did not improve from 12.60817
# 9253/9253 [==============================] - 38s 4ms/step - loss: 14.1373 - val_loss: 13.5473
# Epoch 24/60
# 9244/9253 [============================>.] - ETA: 0s - loss: 13.9355
# Epoch 00024: val_loss did not improve from 12.60817
# 9253/9253 [==============================] - 39s 4ms/step - loss: 13.9335 - val_loss: 14.5471
# Epoch 25/60
# 9248/9253 [============================>.] - ETA: 0s - loss: 13.9175
# Epoch 00025: val_loss improved from 12.60817 to 12.14002, saving model to ../results/experiment_set_18_1\split_1\mlp_model_trained.h5
# 9253/9253 [==============================] - 39s 4ms/step - loss: 13.9162 - val_loss: 12.1400
# Epoch 26/60
# 9248/9253 [============================>.] - ETA: 0s - loss: 13.8497
# Epoch 00026: val_loss did not improve from 12.14002
# 9253/9253 [==============================] - 39s 4ms/step - loss: 13.8501 - val_loss: 16.3094
# Epoch 27/60
# 9252/9253 [============================>.] - ETA: 0s - loss: 13.7639
# Epoch 00027: val_loss did not improve from 12.14002
# 9253/9253 [==============================] - 39s 4ms/step - loss: 13.7640 - val_loss: 13.2040
# Epoch 28/60
# 9249/9253 [============================>.] - ETA: 0s - loss: 13.5243
# Epoch 00028: val_loss did not improve from 12.14002
# 9253/9253 [==============================] - 38s 4ms/step - loss: 13.5245 - val_loss: 14.9953
# Epoch 29/60
# 9241/9253 [============================>.] - ETA: 0s - loss: 13.4632
# Epoch 00029: val_loss did not improve from 12.14002
# 9253/9253 [==============================] - 39s 4ms/step - loss: 13.4687 - val_loss: 17.8726
# Epoch 30/60
# 9247/9253 [============================>.] - ETA: 0s - loss: 13.3018
# Epoch 00030: val_loss did not improve from 12.14002
# 9253/9253 [==============================] - 39s 4ms/step - loss: 13.3018 - val_loss: 14.8948
# Epoch 00030: early stopping
# Saved object to file: ../results/experiment_set_18_1\split_1\history_1.pkl
# Test set:
# MSE: 69.05
# RMSE: 8.31
# CMAPSS score: 1.84
#
# Saved object to file: ../results/experiment_set_18_1\split_2\scaler.pkl
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_10 (Dense)             (None, 256)               27904
# _________________________________________________________________
# dense_11 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dense_12 (Dense)             (None, 512)               131584
# _________________________________________________________________
# dense_13 (Dense)             (None, 64)                32832
# _________________________________________________________________
# dense_14 (Dense)             (None, 1)                 65
# =================================================================
# Total params: 258,177
# Trainable params: 258,177
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/60
# 9253/9253 [==============================] - ETA: 0s - loss: 105.4082
# Epoch 00001: val_loss improved from inf to 35.66529, saving model to ../results/experiment_set_18_1\split_2\mlp_model_trained.h5
# 9253/9253 [==============================] - 41s 4ms/step - loss: 105.4082 - val_loss: 35.6653
# Epoch 2/60
# 9245/9253 [============================>.] - ETA: 0s - loss: 34.0435
# Epoch 00002: val_loss improved from 35.66529 to 32.89286, saving model to ../results/experiment_set_18_1\split_2\mlp_model_trained.h5
# 9253/9253 [==============================] - 40s 4ms/step - loss: 34.0417 - val_loss: 32.8929
# Epoch 3/60
# 9252/9253 [============================>.] - ETA: 0s - loss: 28.6405
# Epoch 00003: val_loss improved from 32.89286 to 25.32767, saving model to ../results/experiment_set_18_1\split_2\mlp_model_trained.h5
# 9253/9253 [==============================] - 40s 4ms/step - loss: 28.6404 - val_loss: 25.3277
# Epoch 4/60
# 9252/9253 [============================>.] - ETA: 0s - loss: 25.7465
# Epoch 00004: val_loss did not improve from 25.32767
# 9253/9253 [==============================] - 39s 4ms/step - loss: 25.7467 - val_loss: 27.2826
# Epoch 5/60
# 9246/9253 [============================>.] - ETA: 0s - loss: 23.7980
# Epoch 00005: val_loss improved from 25.32767 to 20.68805, saving model to ../results/experiment_set_18_1\split_2\mlp_model_trained.h5
# 9253/9253 [==============================] - 39s 4ms/step - loss: 23.7966 - val_loss: 20.6881
# Epoch 6/60
# 9246/9253 [============================>.] - ETA: 0s - loss: 22.0787
# Epoch 00006: val_loss did not improve from 20.68805
# 9253/9253 [==============================] - 39s 4ms/step - loss: 22.0770 - val_loss: 22.7614
# Epoch 7/60
# 9243/9253 [============================>.] - ETA: 0s - loss: 20.8977
# Epoch 00007: val_loss did not improve from 20.68805
# 9253/9253 [==============================] - 39s 4ms/step - loss: 20.8986 - val_loss: 22.2330
# Epoch 8/60
# 9247/9253 [============================>.] - ETA: 0s - loss: 19.7004
# Epoch 00008: val_loss did not improve from 20.68805
# 9253/9253 [==============================] - 39s 4ms/step - loss: 19.7004 - val_loss: 23.9712
# Epoch 9/60
# 9247/9253 [============================>.] - ETA: 0s - loss: 18.9448
# Epoch 00009: val_loss improved from 20.68805 to 16.32951, saving model to ../results/experiment_set_18_1\split_2\mlp_model_trained.h5
# 9253/9253 [==============================] - 40s 4ms/step - loss: 18.9448 - val_loss: 16.3295
# Epoch 10/60
# 9242/9253 [============================>.] - ETA: 0s - loss: 18.3673
# Epoch 00010: val_loss did not improve from 16.32951
# 9253/9253 [==============================] - 39s 4ms/step - loss: 18.3629 - val_loss: 21.2124
# Epoch 11/60
# 9251/9253 [============================>.] - ETA: 0s - loss: 17.7717
# Epoch 00011: val_loss did not improve from 16.32951
# 9253/9253 [==============================] - 39s 4ms/step - loss: 17.7712 - val_loss: 17.6630
# Epoch 12/60
# 9246/9253 [============================>.] - ETA: 0s - loss: 17.0323
# Epoch 00012: val_loss did not improve from 16.32951
# 9253/9253 [==============================] - 39s 4ms/step - loss: 17.0321 - val_loss: 41.4735
# Epoch 13/60
# 9243/9253 [============================>.] - ETA: 0s - loss: 16.6072
# Epoch 00013: val_loss did not improve from 16.32951
# 9253/9253 [==============================] - 39s 4ms/step - loss: 16.6059 - val_loss: 16.4815
# Epoch 14/60
# 9242/9253 [============================>.] - ETA: 0s - loss: 16.5806
# Epoch 00014: val_loss improved from 16.32951 to 15.68505, saving model to ../results/experiment_set_18_1\split_2\mlp_model_trained.h5
# 9253/9253 [==============================] - 39s 4ms/step - loss: 16.5799 - val_loss: 15.6850
# Epoch 15/60
# 9250/9253 [============================>.] - ETA: 0s - loss: 16.0404
# Epoch 00015: val_loss improved from 15.68505 to 13.66639, saving model to ../results/experiment_set_18_1\split_2\mlp_model_trained.h5
# 9253/9253 [==============================] - 39s 4ms/step - loss: 16.0394 - val_loss: 13.6664
# Epoch 16/60
# 9243/9253 [============================>.] - ETA: 0s - loss: 15.9112
# Epoch 00016: val_loss did not improve from 13.66639
# 9253/9253 [==============================] - 39s 4ms/step - loss: 15.9116 - val_loss: 18.7657
# Epoch 17/60
# 9245/9253 [============================>.] - ETA: 0s - loss: 15.4655
# Epoch 00017: val_loss did not improve from 13.66639
# 9253/9253 [==============================] - 39s 4ms/step - loss: 15.4665 - val_loss: 15.3888
# Epoch 18/60
# 9246/9253 [============================>.] - ETA: 0s - loss: 15.3012
# Epoch 00018: val_loss did not improve from 13.66639
# 9253/9253 [==============================] - 40s 4ms/step - loss: 15.3018 - val_loss: 18.7917
# Epoch 19/60
# 9246/9253 [============================>.] - ETA: 0s - loss: 15.2359
# Epoch 00019: val_loss did not improve from 13.66639
# 9253/9253 [==============================] - 38s 4ms/step - loss: 15.2349 - val_loss: 14.0226
# Epoch 20/60
# 9243/9253 [============================>.] - ETA: 0s - loss: 14.9147
# Epoch 00020: val_loss did not improve from 13.66639
# 9253/9253 [==============================] - 38s 4ms/step - loss: 14.9157 - val_loss: 27.6719
# Epoch 00020: early stopping
# Saved object to file: ../results/experiment_set_18_1\split_2\history_2.pkl
# Test set:
# MSE: 64.48
# RMSE: 8.03
# CMAPSS score: 1.80
#
# MSE: mean = 66.63   stddev = 1.88
# RMSE: mean = 8.16   stddev = 0.11
# CMAPSS: mean = 1.82   stddev = 0.01

# %%
###########################################
# Effect of time lags (experiment set 18_2)
###########################################
NUM_TRIALS = 3
EPOCHS = 60
BATCH_SIZE = 512

mlp_params = MLPConfigParams(layer_sizes=[256, 256, 512, 64], activation='tanh', dropout=0.0)
lags = [1, 5, 10, 15]

results_file = os.path.join(output_path, "results_time_lags.csv")
with open(results_file, "w") as file:
    file.write("time_lags,mse,rmse,cmapss,mse(mean),mse(std),rmse(mean),rmse(std),cmapss(mean),cmapss(std)\n")

results_path = output_path
    
with open(results_file, "a") as file:
    file.write(f"{numbers_list_to_string(lags)},")
    
# Add time lags
x_train, y_train = preprocess_data(train_set, lags, selected_columns) 
x_test, y_test = preprocess_data(test_set, lags, selected_columns) 
      
mse_vals, rmse_vals, cmapss_vals = train_evaluate_mlp(
    x_train, y_train, 
    x_test, y_test,
    NUM_TRIALS, 
    mlp_params, 
    results_path, 
    EPOCHS, BATCH_SIZE,
    results_file=results_file)
# Out:
# Saved object to file: ../results/experiment_set_18_2\split_0\scaler.pkl
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 256)               23296
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               131584
# _________________________________________________________________
# dense_3 (Dense)              (None, 64)                32832
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 253,569
# Trainable params: 253,569
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/60
# 9241/9252 [============================>.] - ETA: 0s - loss: 106.5056
# Epoch 00001: val_loss improved from inf to 41.89182, saving model to ../results/experiment_set_18_2\split_0\mlp_model_trained.h5
# 9252/9252 [==============================] - 39s 4ms/step - loss: 106.4292 - val_loss: 41.8918
# Epoch 2/60
# 9241/9252 [============================>.] - ETA: 0s - loss: 36.2506
# Epoch 00002: val_loss improved from 41.89182 to 35.83100, saving model to ../results/experiment_set_18_2\split_0\mlp_model_trained.h5
# 9252/9252 [==============================] - 38s 4ms/step - loss: 36.2470 - val_loss: 35.8310
# Epoch 3/60
# 9246/9252 [============================>.] - ETA: 0s - loss: 31.3718
# Epoch 00003: val_loss improved from 35.83100 to 31.16850, saving model to ../results/experiment_set_18_2\split_0\mlp_model_trained.h5
# 9252/9252 [==============================] - 39s 4ms/step - loss: 31.3702 - val_loss: 31.1685
# Epoch 4/60
# 9248/9252 [============================>.] - ETA: 0s - loss: 28.3191
# Epoch 00004: val_loss improved from 31.16850 to 24.80012, saving model to ../results/experiment_set_18_2\split_0\mlp_model_trained.h5
# 9252/9252 [==============================] - 38s 4ms/step - loss: 28.3187 - val_loss: 24.8001
# Epoch 5/60
# 9250/9252 [============================>.] - ETA: 0s - loss: 26.4205
# Epoch 00005: val_loss improved from 24.80012 to 23.85946, saving model to ../results/experiment_set_18_2\split_0\mlp_model_trained.h5
# 9252/9252 [==============================] - 38s 4ms/step - loss: 26.4198 - val_loss: 23.8595
# Epoch 6/60
# 9247/9252 [============================>.] - ETA: 0s - loss: 25.0007
# Epoch 00006: val_loss did not improve from 23.85946
# 9252/9252 [==============================] - 39s 4ms/step - loss: 25.0017 - val_loss: 24.0648
# Epoch 7/60
# 9246/9252 [============================>.] - ETA: 0s - loss: 23.8020
# Epoch 00007: val_loss did not improve from 23.85946
# 9252/9252 [==============================] - 46s 5ms/step - loss: 23.8022 - val_loss: 26.6460
# Epoch 8/60
# 9252/9252 [==============================] - ETA: 0s - loss: 22.6137
# Epoch 00008: val_loss improved from 23.85946 to 20.24456, saving model to ../results/experiment_set_18_2\split_0\mlp_model_trained.h5
# 9252/9252 [==============================] - 40s 4ms/step - loss: 22.6137 - val_loss: 20.2446
# Epoch 9/60
# 9247/9252 [============================>.] - ETA: 0s - loss: 21.6002
# Epoch 00009: val_loss improved from 20.24456 to 19.54408, saving model to ../results/experiment_set_18_2\split_0\mlp_model_trained.h5
# 9252/9252 [==============================] - 39s 4ms/step - loss: 21.5995 - val_loss: 19.5441
# Epoch 10/60
# 9250/9252 [============================>.] - ETA: 0s - loss: 21.0069
# Epoch 00010: val_loss improved from 19.54408 to 18.87270, saving model to ../results/experiment_set_18_2\split_0\mlp_model_trained.h5
# 9252/9252 [==============================] - 38s 4ms/step - loss: 21.0058 - val_loss: 18.8727
# Epoch 11/60
# 9252/9252 [==============================] - ETA: 0s - loss: 20.1064
# Epoch 00011: val_loss did not improve from 18.87270
# 9252/9252 [==============================] - 37s 4ms/step - loss: 20.1064 - val_loss: 19.3567
# Epoch 12/60
# 9251/9252 [============================>.] - ETA: 0s - loss: 19.4920
# Epoch 00012: val_loss improved from 18.87270 to 18.69061, saving model to ../results/experiment_set_18_2\split_0\mlp_model_trained.h5
# 9252/9252 [==============================] - 38s 4ms/step - loss: 19.4917 - val_loss: 18.6906
# Epoch 13/60
# 9245/9252 [============================>.] - ETA: 0s - loss: 19.1188
# Epoch 00013: val_loss improved from 18.69061 to 16.21496, saving model to ../results/experiment_set_18_2\split_0\mlp_model_trained.h5
# 9252/9252 [==============================] - 37s 4ms/step - loss: 19.1186 - val_loss: 16.2150
# Epoch 14/60
# 9246/9252 [============================>.] - ETA: 0s - loss: 18.6892
# Epoch 00014: val_loss did not improve from 16.21496
# 9252/9252 [==============================] - 37s 4ms/step - loss: 18.6884 - val_loss: 22.4486
# Epoch 15/60
# 9251/9252 [============================>.] - ETA: 0s - loss: 18.1368
# Epoch 00015: val_loss did not improve from 16.21496
# 9252/9252 [==============================] - 37s 4ms/step - loss: 18.1364 - val_loss: 17.7499
# Epoch 16/60
# 9246/9252 [============================>.] - ETA: 0s - loss: 18.0299
# Epoch 00016: val_loss did not improve from 16.21496
# 9252/9252 [==============================] - 37s 4ms/step - loss: 18.0303 - val_loss: 17.0671
# Epoch 17/60
# 9240/9252 [============================>.] - ETA: 0s - loss: 17.5307
# Epoch 00017: val_loss did not improve from 16.21496
# 9252/9252 [==============================] - 37s 4ms/step - loss: 17.5298 - val_loss: 17.3596
# Epoch 18/60
# 9247/9252 [============================>.] - ETA: 0s - loss: 17.1963
# Epoch 00018: val_loss did not improve from 16.21496
# 9252/9252 [==============================] - 38s 4ms/step - loss: 17.1957 - val_loss: 16.3404
# Epoch 00018: early stopping
# Saved object to file: ../results/experiment_set_18_2\split_0\history_0.pkl
# Test set:
# MSE: 63.12
# RMSE: 7.94
# CMAPSS score: 1.79
#
# Saved object to file: ../results/experiment_set_18_2\split_1\scaler.pkl
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_5 (Dense)              (None, 256)               23296
# _________________________________________________________________
# dense_6 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dense_7 (Dense)              (None, 512)               131584
# _________________________________________________________________
# dense_8 (Dense)              (None, 64)                32832
# _________________________________________________________________
# dense_9 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 253,569
# Trainable params: 253,569
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/60
# 9250/9252 [============================>.] - ETA: 0s - loss: 108.1690
# Epoch 00001: val_loss improved from inf to 36.54130, saving model to ../results/experiment_set_18_2\split_1\mlp_model_trained.h5
# 9252/9252 [==============================] - 38s 4ms/step - loss: 108.1543 - val_loss: 36.5413
# Epoch 2/60
# 9244/9252 [============================>.] - ETA: 0s - loss: 37.3667
# Epoch 00002: val_loss improved from 36.54130 to 36.44260, saving model to ../results/experiment_set_18_2\split_1\mlp_model_trained.h5
# 9252/9252 [==============================] - 38s 4ms/step - loss: 37.3632 - val_loss: 36.4426
# Epoch 3/60
# 9251/9252 [============================>.] - ETA: 0s - loss: 32.4298
# Epoch 00003: val_loss improved from 36.44260 to 28.66131, saving model to ../results/experiment_set_18_2\split_1\mlp_model_trained.h5
# 9252/9252 [==============================] - 38s 4ms/step - loss: 32.4296 - val_loss: 28.6613
# Epoch 4/60
# 9252/9252 [==============================] - ETA: 0s - loss: 29.2440
# Epoch 00004: val_loss improved from 28.66131 to 26.41257, saving model to ../results/experiment_set_18_2\split_1\mlp_model_trained.h5
# 9252/9252 [==============================] - 38s 4ms/step - loss: 29.2440 - val_loss: 26.4126
# Epoch 5/60
# 9252/9252 [==============================] - ETA: 0s - loss: 27.1063
# Epoch 00005: val_loss improved from 26.41257 to 24.15704, saving model to ../results/experiment_set_18_2\split_1\mlp_model_trained.h5
# 9252/9252 [==============================] - 38s 4ms/step - loss: 27.1063 - val_loss: 24.1570
# Epoch 6/60
# 9241/9252 [============================>.] - ETA: 0s - loss: 25.5425
# Epoch 00006: val_loss did not improve from 24.15704
# 9252/9252 [==============================] - 38s 4ms/step - loss: 25.5426 - val_loss: 29.0218
# Epoch 7/60
# 9246/9252 [============================>.] - ETA: 0s - loss: 24.4553
# Epoch 00007: val_loss did not improve from 24.15704
# 9252/9252 [==============================] - 38s 4ms/step - loss: 24.4542 - val_loss: 24.3016
# Epoch 8/60
# 9244/9252 [============================>.] - ETA: 0s - loss: 23.1279
# Epoch 00008: val_loss improved from 24.15704 to 20.89642, saving model to ../results/experiment_set_18_2\split_1\mlp_model_trained.h5
# 9252/9252 [==============================] - 38s 4ms/step - loss: 23.1281 - val_loss: 20.8964
# Epoch 9/60
# 9245/9252 [============================>.] - ETA: 0s - loss: 22.3955
# Epoch 00009: val_loss did not improve from 20.89642
# 9252/9252 [==============================] - 38s 4ms/step - loss: 22.4018 - val_loss: 23.1591
# Epoch 10/60
# 9250/9252 [============================>.] - ETA: 0s - loss: 21.3373
# Epoch 00010: val_loss did not improve from 20.89642
# 9252/9252 [==============================] - 37s 4ms/step - loss: 21.3368 - val_loss: 20.9460
# Epoch 11/60
# 9243/9252 [============================>.] - ETA: 0s - loss: 20.7759
# Epoch 00011: val_loss improved from 20.89642 to 18.45696, saving model to ../results/experiment_set_18_2\split_1\mlp_model_trained.h5
# 9252/9252 [==============================] - 37s 4ms/step - loss: 20.7731 - val_loss: 18.4570
# Epoch 12/60
# 9243/9252 [============================>.] - ETA: 0s - loss: 20.0884
# Epoch 00012: val_loss did not improve from 18.45696
# 9252/9252 [==============================] - 38s 4ms/step - loss: 20.0885 - val_loss: 21.8756
# Epoch 13/60
# 9248/9252 [============================>.] - ETA: 0s - loss: 19.4320
# Epoch 00013: val_loss did not improve from 18.45696
# 9252/9252 [==============================] - 38s 4ms/step - loss: 19.4315 - val_loss: 19.2737
# Epoch 14/60
# 9244/9252 [============================>.] - ETA: 0s - loss: 18.9352
# Epoch 00014: val_loss did not improve from 18.45696
# 9252/9252 [==============================] - 38s 4ms/step - loss: 18.9376 - val_loss: 22.8295
# Epoch 15/60
# 9247/9252 [============================>.] - ETA: 0s - loss: 18.6777
# Epoch 00015: val_loss improved from 18.45696 to 17.27553, saving model to ../results/experiment_set_18_2\split_1\mlp_model_trained.h5
# 9252/9252 [==============================] - 37s 4ms/step - loss: 18.6773 - val_loss: 17.2755
# Epoch 16/60
# 9249/9252 [============================>.] - ETA: 0s - loss: 18.3517
# Epoch 00016: val_loss did not improve from 17.27553
# 9252/9252 [==============================] - 37s 4ms/step - loss: 18.3525 - val_loss: 17.9779
# Epoch 17/60
# 9246/9252 [============================>.] - ETA: 0s - loss: 18.0100
# Epoch 00017: val_loss improved from 17.27553 to 16.87085, saving model to ../results/experiment_set_18_2\split_1\mlp_model_trained.h5
# 9252/9252 [==============================] - 37s 4ms/step - loss: 18.0081 - val_loss: 16.8709
# Epoch 18/60
# 9245/9252 [============================>.] - ETA: 0s - loss: 17.7134
# Epoch 00018: val_loss did not improve from 16.87085
# 9252/9252 [==============================] - 37s 4ms/step - loss: 17.7135 - val_loss: 17.9931
# Epoch 19/60
# 9250/9252 [============================>.] - ETA: 0s - loss: 17.2970
# Epoch 00019: val_loss did not improve from 16.87085
# 9252/9252 [==============================] - 36s 4ms/step - loss: 17.2974 - val_loss: 16.8989
# Epoch 20/60
# 9245/9252 [============================>.] - ETA: 0s - loss: 17.0822
# Epoch 00020: val_loss improved from 16.87085 to 15.83035, saving model to ../results/experiment_set_18_2\split_1\mlp_model_trained.h5
# 9252/9252 [==============================] - 37s 4ms/step - loss: 17.0813 - val_loss: 15.8303
# Epoch 21/60
# 9246/9252 [============================>.] - ETA: 0s - loss: 16.9677
# Epoch 00021: val_loss did not improve from 15.83035
# 9252/9252 [==============================] - 37s 4ms/step - loss: 16.9700 - val_loss: 19.7538
# Epoch 22/60
# 9243/9252 [============================>.] - ETA: 0s - loss: 16.5621
# Epoch 00022: val_loss did not improve from 15.83035
# 9252/9252 [==============================] - 37s 4ms/step - loss: 16.5609 - val_loss: 18.3753
# Epoch 23/60
# 9242/9252 [============================>.] - ETA: 0s - loss: 16.5503
# Epoch 00023: val_loss did not improve from 15.83035
# 9252/9252 [==============================] - 37s 4ms/step - loss: 16.5543 - val_loss: 18.8273
# Epoch 24/60
# 9250/9252 [============================>.] - ETA: 0s - loss: 16.3472
# Epoch 00024: val_loss did not improve from 15.83035
# 9252/9252 [==============================] - 37s 4ms/step - loss: 16.3468 - val_loss: 16.6829
# Epoch 25/60
# 9240/9252 [============================>.] - ETA: 0s - loss: 16.1101
# Epoch 00025: val_loss improved from 15.83035 to 13.97172, saving model to ../results/experiment_set_18_2\split_1\mlp_model_trained.h5
# 9252/9252 [==============================] - 38s 4ms/step - loss: 16.1105 - val_loss: 13.9717
# Epoch 26/60
# 9242/9252 [============================>.] - ETA: 0s - loss: 16.0584
# Epoch 00026: val_loss did not improve from 13.97172
# 9252/9252 [==============================] - 37s 4ms/step - loss: 16.0604 - val_loss: 18.2774
# Epoch 27/60
# 9248/9252 [============================>.] - ETA: 0s - loss: 15.9840
# Epoch 00027: val_loss improved from 13.97172 to 13.12077, saving model to ../results/experiment_set_18_2\split_1\mlp_model_trained.h5
# 9252/9252 [==============================] - 37s 4ms/step - loss: 15.9831 - val_loss: 13.1208
# Epoch 28/60
# 9248/9252 [============================>.] - ETA: 0s - loss: 15.8567
# Epoch 00028: val_loss did not improve from 13.12077
# 9252/9252 [==============================] - 37s 4ms/step - loss: 15.8598 - val_loss: 17.6235
# Epoch 29/60
# 9247/9252 [============================>.] - ETA: 0s - loss: 15.5810
# Epoch 00029: val_loss did not improve from 13.12077
# 9252/9252 [==============================] - 37s 4ms/step - loss: 15.5803 - val_loss: 13.6393
# Epoch 30/60
# 9249/9252 [============================>.] - ETA: 0s - loss: 15.4060
# Epoch 00030: val_loss did not improve from 13.12077
# 9252/9252 [==============================] - 37s 4ms/step - loss: 15.4053 - val_loss: 14.8268
# Epoch 31/60
# 9242/9252 [============================>.] - ETA: 0s - loss: 15.2707
# Epoch 00031: val_loss did not improve from 13.12077
# 9252/9252 [==============================] - 38s 4ms/step - loss: 15.2706 - val_loss: 15.1836
# Epoch 32/60
# 9252/9252 [==============================] - ETA: 0s - loss: 15.2197
# Epoch 00032: val_loss did not improve from 13.12077
# 9252/9252 [==============================] - 37s 4ms/step - loss: 15.2197 - val_loss: 17.6961
# Epoch 00032: early stopping
# Saved object to file: ../results/experiment_set_18_2\split_1\history_1.pkl
# Test set:
# MSE: 66.87
# RMSE: 8.18
# CMAPSS score: 1.84
#
# Saved object to file: ../results/experiment_set_18_2\split_2\scaler.pkl
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_10 (Dense)             (None, 256)               23296
# _________________________________________________________________
# dense_11 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dense_12 (Dense)             (None, 512)               131584
# _________________________________________________________________
# dense_13 (Dense)             (None, 64)                32832
# _________________________________________________________________
# dense_14 (Dense)             (None, 1)                 65
# =================================================================
# Total params: 253,569
# Trainable params: 253,569
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/60
# 9247/9252 [============================>.] - ETA: 0s - loss: 105.8067WARNING:tensorflow:Callbacks method `on_test_batch_end` is slow compared to the batch time (batch time: 0.0000s vs `on_test_batch_end` time: 0.0040s). Check your callbacks.
#
# Epoch 00001: val_loss improved from inf to 38.89161, saving model to ../results/experiment_set_18_2\split_2\mlp_model_trained.h5
# 9252/9252 [==============================] - 39s 4ms/step - loss: 105.7716 - val_loss: 38.8916
# Epoch 2/60
# 9245/9252 [============================>.] - ETA: 0s - loss: 35.8880
# Epoch 00002: val_loss improved from 38.89161 to 32.72950, saving model to ../results/experiment_set_18_2\split_2\mlp_model_trained.h5
# 9252/9252 [==============================] - 39s 4ms/step - loss: 35.8902 - val_loss: 32.7295
# Epoch 3/60
# 9245/9252 [============================>.] - ETA: 0s - loss: 31.0939
# Epoch 00003: val_loss improved from 32.72950 to 26.70110, saving model to ../results/experiment_set_18_2\split_2\mlp_model_trained.h5
# 9252/9252 [==============================] - 39s 4ms/step - loss: 31.0916 - val_loss: 26.7011
# Epoch 4/60
# 9247/9252 [============================>.] - ETA: 0s - loss: 28.1486 E
# Epoch 00004: val_loss did not improve from 26.70110
# 9252/9252 [==============================] - 39s 4ms/step - loss: 28.1489 - val_loss: 34.5745
# Epoch 5/60
# 9245/9252 [============================>.] - ETA: 0s - loss: 25.9843
# Epoch 00005: val_loss improved from 26.70110 to 25.17023, saving model to ../results/experiment_set_18_2\split_2\mlp_model_trained.h5
# 9252/9252 [==============================] - 39s 4ms/step - loss: 25.9849 - val_loss: 25.1702
# Epoch 6/60
# 9250/9252 [============================>.] - ETA: 0s - loss: 24.6440
# Epoch 00006: val_loss did not improve from 25.17023
# 9252/9252 [==============================] - 39s 4ms/step - loss: 24.6440 - val_loss: 32.2522
# Epoch 7/60
# 9250/9252 [============================>.] - ETA: 0s - loss: 23.3677
# Epoch 00007: val_loss improved from 25.17023 to 21.49337, saving model to ../results/experiment_set_18_2\split_2\mlp_model_trained.h5
# 9252/9252 [==============================] - 39s 4ms/step - loss: 23.3676 - val_loss: 21.4934
# Epoch 8/60
# 9243/9252 [============================>.] - ETA: 0s - loss: 22.4265
# Epoch 00008: val_loss did not improve from 21.49337
# 9252/9252 [==============================] - 39s 4ms/step - loss: 22.4265 - val_loss: 22.5583
# Epoch 9/60
# 9245/9252 [============================>.] - ETA: 0s - loss: 21.4394
# Epoch 00009: val_loss improved from 21.49337 to 20.42572, saving model to ../results/experiment_set_18_2\split_2\mlp_model_trained.h5
# 9252/9252 [==============================] - 41s 4ms/step - loss: 21.4388 - val_loss: 20.4257
# Epoch 10/60
# 9241/9252 [============================>.] - ETA: 0s - loss: 20.7789
# Epoch 00010: val_loss did not improve from 20.42572
# 9252/9252 [==============================] - 40s 4ms/step - loss: 20.7843 - val_loss: 24.0739
# Epoch 11/60
# 9252/9252 [==============================] - ETA: 0s - loss: 20.2147
# Epoch 00011: val_loss improved from 20.42572 to 19.76948, saving model to ../results/experiment_set_18_2\split_2\mlp_model_trained.h5
# 9252/9252 [==============================] - 38s 4ms/step - loss: 20.2147 - val_loss: 19.7695
# Epoch 12/60
# 9246/9252 [============================>.] - ETA: 0s - loss: 19.6195
# Epoch 00012: val_loss improved from 19.76948 to 18.32448, saving model to ../results/experiment_set_18_2\split_2\mlp_model_trained.h5
# 9252/9252 [==============================] - 37s 4ms/step - loss: 19.6197 - val_loss: 18.3245
# Epoch 13/60
# 9241/9252 [============================>.] - ETA: 0s - loss: 19.0842
# Epoch 00013: val_loss improved from 18.32448 to 18.19324, saving model to ../results/experiment_set_18_2\split_2\mlp_model_trained.h5
# 9252/9252 [==============================] - 37s 4ms/step - loss: 19.0828 - val_loss: 18.1932
# Epoch 14/60
# 9246/9252 [============================>.] - ETA: 0s - loss: 18.7601
# Epoch 00014: val_loss improved from 18.19324 to 17.84702, saving model to ../results/experiment_set_18_2\split_2\mlp_model_trained.h5
# 9252/9252 [==============================] - 37s 4ms/step - loss: 18.7606 - val_loss: 17.8470
# Epoch 15/60
# 9242/9252 [============================>.] - ETA: 0s - loss: 18.4267
# Epoch 00015: val_loss did not improve from 17.84702
# 9252/9252 [==============================] - 38s 4ms/step - loss: 18.4309 - val_loss: 26.7514
# Epoch 16/60
# 9243/9252 [============================>.] - ETA: 0s - loss: 18.0233
# Epoch 00016: val_loss did not improve from 17.84702
# 9252/9252 [==============================] - 39s 4ms/step - loss: 18.0212 - val_loss: 20.0734
# Epoch 17/60
# 9244/9252 [============================>.] - ETA: 0s - loss: 17.7466
# Epoch 00017: val_loss did not improve from 17.84702
# 9252/9252 [==============================] - 38s 4ms/step - loss: 17.7534 - val_loss: 18.3664
# Epoch 18/60
# 9245/9252 [============================>.] - ETA: 0s - loss: 17.3038
# Epoch 00018: val_loss did not improve from 17.84702
# 9252/9252 [==============================] - 38s 4ms/step - loss: 17.3055 - val_loss: 20.9155
# Epoch 19/60
# 9249/9252 [============================>.] - ETA: 0s - loss: 17.0630
# Epoch 00019: val_loss did not improve from 17.84702
# 9252/9252 [==============================] - 39s 4ms/step - loss: 17.0636 - val_loss: 18.7050
# Epoch 00019: early stopping
# Saved object to file: ../results/experiment_set_18_2\split_2\history_2.pkl
# Test set:
# MSE: 67.22
# RMSE: 8.20
# CMAPSS score: 1.82
#
# MSE: mean = 65.73   stddev = 1.86
# RMSE: mean = 8.11   stddev = 0.12
# CMAPSS: mean = 1.82   stddev = 0.02
