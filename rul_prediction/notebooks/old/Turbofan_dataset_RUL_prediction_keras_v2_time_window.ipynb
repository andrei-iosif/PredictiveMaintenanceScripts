# %%
import os
seed = 0
os.environ['PYTHONHASSEED'] = str(seed)

# %%
# Disable GPU
# os.environ["CUDA_VISIBLE_DEVICES"] = "-1"

# %%
import h5py
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import time
import random
import pickle
from decimal import Decimal

from tensorflow.random import set_seed

from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.feature_selection import VarianceThreshold
from sklearn.metrics import mean_squared_error

from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.models import load_model

# %%
# Set seed
random.seed(seed)
np.random.seed(seed)
set_seed(seed)

# %%
filename = '../data/turbofan_dataset/N-CMAPSS_DS02-006.h5'
output_path = 'DS02/experiment_set_7'

# %%
if not os.path.exists(output_path):
    os.makedirs(output_path)

# %%
def load_dataset(filename):
    """ Reads a dataset from a given .h5 file and compose (in memory) the train and test data. 
    Args:
        filename(str): path to the .h5 file
    Returns:
        train_set(pd.DataFrame), test_set(pd.DataFrame)
    """
    with h5py.File(filename, 'r') as hdf:
        # Development set
        W_dev = np.array(hdf.get('W_dev'))             # W
        X_s_dev = np.array(hdf.get('X_s_dev'))         # X_s
        X_v_dev = np.array(hdf.get('X_v_dev'))         # X_v
        T_dev = np.array(hdf.get('T_dev'))             # T
        Y_dev = np.array(hdf.get('Y_dev'))             # RUL  
        A_dev = np.array(hdf.get('A_dev'))             # Auxiliary

        # Test set
        W_test = np.array(hdf.get('W_test'))           # W
        X_s_test = np.array(hdf.get('X_s_test'))       # X_s
        X_v_test = np.array(hdf.get('X_v_test'))       # X_v
        T_test = np.array(hdf.get('T_test'))           # T
        Y_test = np.array(hdf.get('Y_test'))           # RUL  
        A_test = np.array(hdf.get('A_test'))           # Auxiliary
        
        # Varnams
        W_var = np.array(hdf.get('W_var'))
        X_s_var = np.array(hdf.get('X_s_var'))  
        X_v_var = np.array(hdf.get('X_v_var')) 
        T_var = np.array(hdf.get('T_var'))
        A_var = np.array(hdf.get('A_var'))
        
        columns = []
        columns += list(np.array(A_var, dtype='U20'))
        columns += list(np.array(T_var, dtype='U20'))
        columns += list(np.array(X_s_var, dtype='U20'))
        columns += list(np.array(X_v_var, dtype='U20'))
        columns += list(np.array(W_var, dtype='U20'))
        columns += ['RUL']
        
    train_set = np.concatenate((A_dev, T_dev, X_s_dev, X_v_dev, W_dev, Y_dev), axis=1)
    test_set = np.concatenate((A_test, T_test, X_s_test, X_v_test, W_test, Y_test), axis=1)
    
    return pd.DataFrame(data=train_set, columns=columns), pd.DataFrame(data=test_set, columns=columns)

# %%
start_time = time.process_time()  
train_set, test_set = load_dataset(filename)
print('')
print("Operation time (sec): " , (time.process_time() - start_time))
print('')
print ("Train set shape: " + str(train_set.shape))
print ("Test set shape: " + str(test_set.shape))

# %%
def unit_cycle_info(df, compute_cycle_len=False):
    unit_ids = np.unique(df['unit'])
    print('Engine units in df: ', unit_ids)
    for i in unit_ids:
        num_cycles = len(np.unique(df.loc[df['unit'] == i, 'cycle']))
        print('Unit: ', i, ' - Number of flight cycles: ', num_cycles)
        
    if compute_cycle_len:
        cycle_ids = np.unique(df['cycle'])
        print('Total number of cycles: ', len(cycle_ids))
        min_len = np.inf
        max_len = 0
        for i in cycle_ids:
            cycle_len = len(df.loc[df['cycle'] == i, 'cycle'])
            if cycle_len < min_len:
                min_len = cycle_len
            elif cycle_len > max_len:
                max_len = cycle_len
        print('Min cycle length: ', min_len)
        print('Max cycle length: ', max_len)
    
    return unit_ids

# %%
# Filter constant and quasi-constant features
def get_quasi_constant_features(dataset, variance_th=0.01, debug=True):
    constant_filter = VarianceThreshold(threshold=variance_th)
    constant_filter.fit(dataset)
    constant_features = [col for col in dataset.columns 
                         if col not in dataset.columns[constant_filter.get_support()]]
    
    if debug:
        print("Number of non-constant features: ", len(dataset.columns[constant_filter.get_support()]))
        
        print("Number of quasi-constant features: ", len(constant_features))
        print("Quasi-constant features: ")
        for col in constant_features:
            print(col)
    return constant_features

def get_non_correlated_features(dataset, corr_th=0.9, debug=True):
    corr_mat = dataset.corr()
    corr_mat = np.abs(corr_mat)
    
    N = corr_mat.shape[0]
    columns = np.full((N,), True, dtype=bool)
    for i in range(N):
        for j in range(i+1, N):
            if corr_mat.iloc[i, j] >= corr_th:
                if columns[j]:
                    columns[j] = False
    if debug:        
        correlated_features = dataset.columns[~columns]
        print("Number of correlated features: ", len(correlated_features))
        print("Correlated features: ")
        for col in correlated_features:
            print(col)
    
    selected_columns = dataset.columns[columns]
    return selected_columns

# %%
train_unit_ids = unit_cycle_info(train_set)
test_unit_ids = unit_cycle_info(test_set)

# %%
y_train = train_set['RUL']
x_train = train_set.drop(['RUL'], axis=1)

# %%
constant_features = get_quasi_constant_features(x_train)
x_train.drop(labels=constant_features, axis=1, inplace=True)
print("Train shape: ", x_train.shape)

# %%
# Remove highly correlated features
selected_columns = get_non_correlated_features(x_train)
x_train = x_train[selected_columns]
print("Train shape: ", x_train.shape)

# %%
# Drop auxiliary data columns
auxiliary_columns = ['cycle', 'hs', 'Fc']
x_train.drop(labels=[x for x in auxiliary_columns if x in x_train.columns], axis=1, inplace=True)

# %%
y_test = test_set['RUL']
x_test = test_set.drop(['RUL'], axis=1)
x_test = x_test[x_train.columns]

# %%
x_train = x_train.astype('float32')
y_train = y_train.astype('float32')
x_test = x_test.astype('float32')
y_test = y_test.astype('float32')

# %%
W = 10
col_names = [col for col in x_train.columns if col != 'unit']
print('Columns: ', col_names)
print('Train unit ids: ', train_unit_ids)
print('Test unit ids: ', test_unit_ids)
# Out:
# Columns:  ['T24', 'T30', 'P15', 'SmFan', 'SmLPC']
# Train unit ids:  [ 2.  5. 10. 16. 18. 20.]
# Test unit ids:  [11. 14. 15.]

# %%
def time_window_processing(X, y, column_names, unit_ids, window_size):
    df = pd.concat([X, y], axis=1)
    lag_columns = []
    
    for col_name in column_names:
        for i in range(1, window_size):
            partial_columns = []
            for j in range(len(unit_ids)):
                unit_df = df.loc[df['unit'] == unit_ids[j], :]
                col = unit_df[col_name].shift(i)
                col.name = '{}(t-{})'.format(col_name, i)
                partial_columns.append(col)
            column = pd.concat(partial_columns)
            lag_columns.append(column)
    
    df = pd.concat([df] + lag_columns, axis=1)
    df.dropna(inplace=True)
    df.drop(labels=['unit'], axis=1, inplace=True)
    df.reset_index(drop=True, inplace=True)
    
    feature_columns = [col for col in df.columns.values if col != 'RUL']    
    return df[feature_columns], df['RUL']

# %%
x_train_tw, y_train_tw = time_window_processing(x_train, y_train, col_names, train_unit_ids, W)
x_test_tw, y_test_tw = time_window_processing(x_test, y_test, col_names, test_unit_ids, W)

# %%
x_train_split, x_val_split, y_train_split, y_val_split = train_test_split(x_train_tw, y_train_tw, 
                                                                          test_size=0.3, 
                                                                          random_state=seed)

scaler = StandardScaler()
x_train_scaled = scaler.fit_transform(x_train_split)
x_val_scaled = scaler.transform(x_val_split)
x_test_scaled = scaler.transform(x_test_tw)

# %%
x_train_final, y_train_final = x_train_scaled, y_train_split
x_val_final, y_val_final = x_val_scaled, y_val_split
x_test_final, y_test_final = x_test_scaled, y_test_tw

# %%
def cmapss_score_function(actual, predictions, normalize=True):
    # diff < 0 -> over-estimation
    # diff > 0 -> under-estimation
    diff = actual - predictions
    alpha = np.full_like(diff, 1/13)
    negative_diff_mask = diff < 0
    alpha[negative_diff_mask] = 1/10
    score = np.sum(np.exp(alpha * np.abs(diff)))
    
    if normalize:
        N = len(predictions)
        score /= N
    return score

def compute_evaluation_metrics(actual, predictions, label='Test'):
    mse = mean_squared_error(actual, predictions)
    rmse = np.sqrt(mse)
    cmapss_score = cmapss_score_function(actual, predictions)
    print('{} set:\nMSE: {:.2f}\nRMSE: {:.2f}\nCMAPSS score: {:.2f}\n'.format(label, mse, rmse, 
                                                                     Decimal(cmapss_score)))
    return mse, rmse, cmapss_score
    
def plot_loss_curves(history, output_path=None, y_lim=[0, 150]):
    plt.plot(history['loss'])
    plt.plot(history['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.ylim(y_lim)
    plt.legend(['train', 'validation'], loc='upper left')
    
    if output_path is not None:
        plt.savefig(os.path.join(output_path, 'loss_curves.png'), format='png', dpi=300) 
    plt.show()
    
def plot_rul(expected, predicted):
    plt.figure()
    plt.plot(range(len(expected)), expected, label='Expected')
    plt.plot(range(len(predicted)), predicted, label='Predicted')
    plt.legend()
    
    
def create_mlp_model(input_dim, hidden_layer_sizes, activation='relu', output_weights_file=None):
    model = Sequential()
    model.add(Dense(hidden_layer_sizes[0], 
                    input_dim=input_dim, 
                    kernel_initializer='random_normal', 
                    activation=activation))

    for layer_size in hidden_layer_sizes[1:]:
        model.add(Dense(layer_size, 
                        kernel_initializer='random_normal', 
                        activation=activation))
    
    model.add(Dense(1, kernel_initializer='random_normal'))
    
    model.compile(loss='mean_squared_error', optimizer='adam')
    
    if output_weights_file is not None:
        model.save_weights(output_weights_file)
    return model

def train_model_existing_weights(model, weights_file, x_train, y_train, x_val, y_val, epochs=200, batch_size=512, callbacks=[]):
    model.compile(loss='mean_squared_error', optimizer='adam')
    model.load_weights(weights_file)
    return model.fit(x_train, y_train,
                     validation_data=(x_val, y_val),
                     epochs=epochs,
                     batch_size=batch_size,
                     verbose=1,
                     callbacks=callbacks)

def save_history(history, output_file=os.path.join(output_path, "history.pkl")):
    with open(output_file, 'wb') as file:
        pickle.dump(history.history, file)
    print("Saved training history to file: {}".format(output_file))

def load_history(file):
    return pickle.load(open(file, "rb"))

def model_evaluation(model, x_test, y_test, x_train=None, y_train=None, plot_range=[0, 10**3]):
    if x_train is not None and y_train is not None:
        predictions_train = model.predict(x_train).flatten()
        compute_evaluation_metrics(predictions_train, y_train, 'Train')
        
        expected = y_train[plot_range[0]:plot_range[1]]
        predicted = predictions_train[plot_range[0]:plot_range[1]]
        plot_rul(expected, predicted)
        
    predictions_test = model.predict(x_test).flatten()
    compute_evaluation_metrics(predictions_test, y_test)
    
    expected = y_test[plot_range[0]:plot_range[1]]
    predicted = predictions_test[plot_range[0]:plot_range[1]]
    plot_rul(expected, predicted)

# %%
# Retrain best model in experiment set 4
weights_file = r"D:\Licenta\notebooks\DS02\experiment_set_7\mlp_weights.h5"
batch_size = 512
epochs = 200

layer_sizes = [256, 256, 512, 64]
input_dim = x_train_final.shape[1]

model = create_mlp_model(input_dim, layer_sizes, 
                         output_weights_file=weights_file, 
                         activation='tanh')
model.summary()

es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=10)
mc = ModelCheckpoint(os.path.join(output_path, 'mlp_model_trained.h5'), 
                     monitor='val_loss', mode='min', verbose=1, save_best_only=True)

history = train_model_existing_weights(model, weights_file, x_train_final, y_train_final, 
                                       x_val_final, y_val_final, 
                                       batch_size=batch_size, 
                                       epochs=epochs, 
                                       callbacks=[es, mc])

save_history(history)

# %%
history_path = r'D:\Licenta\notebooks\DS02\experiment_set_7\history.pkl'
model_path = r'D:\Licenta\notebooks\DS02\experiment_set_7\mlp_model_trained.h5'

history = load_history(history_path)
plot_loss_curves(history, output_path, y_lim=[0, 120])

# %%
loaded_model = load_model(model_path)
model_evaluation(loaded_model, x_test=x_test_final, y_test=y_test_final, 
                 x_train=x_train_final, y_train=y_train_final)

# %%
######################
# Test multiple splits
######################
weights_file = r"D:\Licenta\notebooks\DS02\experiment_set_7\window_{}\mlp_weights.h5".format(W)
batch_size = 512
epochs = 200

layer_sizes = [256, 256, 512, 64]
input_dim = x_train_tw.shape[1]

results = []

for random_seed in range(1, 5):
    model_path = os.path.join(output_path, "window_{}".format(W), 
                              "split_seed_{}".format(random_seed))
    if not os.path.exists(model_path):
        os.makedirs(model_path)
    
    x_train_split, x_val_split, y_train_split, y_val_split = train_test_split(x_train_tw, y_train_tw, 
                                                                              test_size=0.3, 
                                                                              random_state=random_seed)
    scaler = StandardScaler()
    x_train_scaled = scaler.fit_transform(x_train_split)
    x_val_scaled = scaler.transform(x_val_split)

    model = create_mlp_model(input_dim, layer_sizes, activation='tanh')
    model.summary()
    
    es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=10)
    mc = ModelCheckpoint(os.path.join(model_path, 'mlp_model_trained.h5'),
                         monitor='val_loss', mode='min', verbose=1, save_best_only=True)

    history = train_model_existing_weights(model, weights_file, 
                                           x_train_scaled, y_train_split, 
                                           x_val_scaled, y_val_split, 
                                           batch_size=batch_size, 
                                           epochs=epochs, 
                                           callbacks=[es, mc])
    
    history_path = os.path.join(model_path, "history.pkl")
    save_history(history, history_path)
    results.append((model, history, scaler))
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 256)               13056
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               131584
# _________________________________________________________________
# dense_3 (Dense)              (None, 64)                32832
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 243,329
# Trainable params: 243,329
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/200
# 7191/7197 [============================>.] - ETA: 0s - loss: 173.9858
# Epoch 00001: val_loss improved from inf to 77.43362, saving model to DS02/experiment_set_7\window_10\split_seed_1\mlp_model_trained.h5
# 7197/7197 [==============================] - 34s 5ms/step - loss: 173.9187 - val_loss: 77.4336
# Epoch 2/200
# 7193/7197 [============================>.] - ETA: 0s - loss: 65.6726
# Epoch 00002: val_loss did not improve from 77.43362
# 7197/7197 [==============================] - 34s 5ms/step - loss: 65.6668 - val_loss: 112.7207
# Epoch 3/200
# 7187/7197 [============================>.] - ETA: 0s - loss: 56.6730
# Epoch 00003: val_loss improved from 77.43362 to 62.16982, saving model to DS02/experiment_set_7\window_10\split_seed_1\mlp_model_trained.h5
# 7197/7197 [==============================] - 34s 5ms/step - loss: 56.6606 - val_loss: 62.1698
# Epoch 4/200
# 7193/7197 [============================>.] - ETA: 0s - loss: 50.6244 ETA:
# Epoch 00004: val_loss improved from 62.16982 to 43.16954, saving model to DS02/experiment_set_7\window_10\split_seed_1\mlp_model_trained.h5
# 7197/7197 [==============================] - 34s 5ms/step - loss: 50.6215 - val_loss: 43.1695
# Epoch 5/200
# 7197/7197 [==============================] - ETA: 0s - loss: 46.1520
# Epoch 00005: val_loss did not improve from 43.16954
# 7197/7197 [==============================] - 34s 5ms/step - loss: 46.1520 - val_loss: 45.6346
# Epoch 6/200
# 7192/7197 [============================>.] - ETA: 0s - loss: 43.6184
# Epoch 00006: val_loss did not improve from 43.16954
# 7197/7197 [==============================] - 35s 5ms/step - loss: 43.6163 - val_loss: 59.4931
# Epoch 7/200
# 7186/7197 [============================>.] - ETA: 0s - loss: 41.1368
# Epoch 00007: val_loss did not improve from 43.16954
# 7197/7197 [==============================] - 35s 5ms/step - loss: 41.1339 - val_loss: 97.5899
# Epoch 8/200
# 7190/7197 [============================>.] - ETA: 0s - loss: 39.2157
# Epoch 00008: val_loss did not improve from 43.16954
# 7197/7197 [==============================] - 34s 5ms/step - loss: 39.2219 - val_loss: 64.4741
# Epoch 9/200
# 7192/7197 [============================>.] - ETA: 0s - loss: 37.2655
# Epoch 00009: val_loss did not improve from 43.16954
# 7197/7197 [==============================] - 35s 5ms/step - loss: 37.2664 - val_loss: 75.0476
# Epoch 10/200
# 7197/7197 [==============================] - ETA: 0s - loss: 36.2313
# Epoch 00010: val_loss did not improve from 43.16954
# 7197/7197 [==============================] - 34s 5ms/step - loss: 36.2313 - val_loss: 149.5550
# Epoch 11/200
# 7189/7197 [============================>.] - ETA: 0s - loss: 34.9760
# Epoch 00011: val_loss improved from 43.16954 to 38.75838, saving model to DS02/experiment_set_7\window_10\split_seed_1\mlp_model_trained.h5
# 7197/7197 [==============================] - 35s 5ms/step - loss: 34.9712 - val_loss: 38.7584
# Epoch 12/200
# 7186/7197 [============================>.] - ETA: 0s - loss: 33.8794
# Epoch 00012: val_loss did not improve from 38.75838
# 7197/7197 [==============================] - 33s 5ms/step - loss: 33.8776 - val_loss: 45.7322
# Epoch 13/200
# 7195/7197 [============================>.] - ETA: 0s - loss: 32.8225
# Epoch 00013: val_loss did not improve from 38.75838
# 7197/7197 [==============================] - 33s 5ms/step - loss: 32.8219 - val_loss: 48.1552
# Epoch 14/200
# 7185/7197 [============================>.] - ETA: 0s - loss: 31.9389
# Epoch 00014: val_loss improved from 38.75838 to 34.57800, saving model to DS02/experiment_set_7\window_10\split_seed_1\mlp_model_trained.h5
# 7197/7197 [==============================] - 35s 5ms/step - loss: 31.9396 - val_loss: 34.5780
# Epoch 15/200
# 7195/7197 [============================>.] - ETA: 0s - loss: 31.1703
# Epoch 00015: val_loss did not improve from 34.57800
# 7197/7197 [==============================] - 36s 5ms/step - loss: 31.1719 - val_loss: 80.1856
# Epoch 16/200
# 7197/7197 [==============================] - ETA: 0s - loss: 30.6665
# Epoch 00016: val_loss improved from 34.57800 to 33.27102, saving model to DS02/experiment_set_7\window_10\split_seed_1\mlp_model_trained.h5
# 7197/7197 [==============================] - 34s 5ms/step - loss: 30.6665 - val_loss: 33.2710
# Epoch 17/200
# 7189/7197 [============================>.] - ETA: 0s - loss: 30.1604
# Epoch 00017: val_loss did not improve from 33.27102
# 7197/7197 [==============================] - 33s 5ms/step - loss: 30.1582 - val_loss: 33.5855
# Epoch 18/200
# 7189/7197 [============================>.] - ETA: 0s - loss: 29.2771
# Epoch 00018: val_loss improved from 33.27102 to 33.05482, saving model to DS02/experiment_set_7\window_10\split_seed_1\mlp_model_trained.h5
# 7197/7197 [==============================] - 34s 5ms/step - loss: 29.2750 - val_loss: 33.0548
# Epoch 19/200
# 7182/7197 [============================>.] - ETA: 0s - loss: 28.8676
# Epoch 00019: val_loss did not improve from 33.05482
# 7197/7197 [==============================] - 35s 5ms/step - loss: 28.8876 - val_loss: 74.7348
# Epoch 20/200
# 7186/7197 [============================>.] - ETA: 0s - loss: 28.3893
# Epoch 00020: val_loss did not improve from 33.05482
# 7197/7197 [==============================] - 34s 5ms/step - loss: 28.3846 - val_loss: 69.5489
# Epoch 21/200
# 7192/7197 [============================>.] - ETA: 0s - loss: 28.0188
# Epoch 00021: val_loss did not improve from 33.05482
# 7197/7197 [==============================] - 33s 5ms/step - loss: 28.0203 - val_loss: 54.8492
# Epoch 22/200
# 7194/7197 [============================>.] - ETA: 0s - loss: 27.5400
# Epoch 00022: val_loss did not improve from 33.05482
# 7197/7197 [==============================] - 33s 5ms/step - loss: 27.5395 - val_loss: 52.6340
# Epoch 23/200
# 7194/7197 [============================>.] - ETA: 0s - loss: 27.0739
# Epoch 00023: val_loss improved from 33.05482 to 28.46976, saving model to DS02/experiment_set_7\window_10\split_seed_1\mlp_model_trained.h5
# 7197/7197 [==============================] - 34s 5ms/step - loss: 27.0721 - val_loss: 28.4698
# Epoch 24/200
# 7190/7197 [============================>.] - ETA: 0s - loss: 26.7645
# Epoch 00024: val_loss improved from 28.46976 to 22.54233, saving model to DS02/experiment_set_7\window_10\split_seed_1\mlp_model_trained.h5
# 7197/7197 [==============================] - 34s 5ms/step - loss: 26.7626 - val_loss: 22.5423
# Epoch 25/200
# 7194/7197 [============================>.] - ETA: 0s - loss: 26.4169
# Epoch 00025: val_loss did not improve from 22.54233
# 7197/7197 [==============================] - 34s 5ms/step - loss: 26.4167 - val_loss: 32.4129
# Epoch 26/200
# 7193/7197 [============================>.] - ETA: 0s - loss: 26.1790
# Epoch 00026: val_loss did not improve from 22.54233
# 7197/7197 [==============================] - 33s 5ms/step - loss: 26.1788 - val_loss: 62.4556
# Epoch 27/200
# 7192/7197 [============================>.] - ETA: 0s - loss: 25.8715
# Epoch 00027: val_loss did not improve from 22.54233
# 7197/7197 [==============================] - 34s 5ms/step - loss: 25.8707 - val_loss: 24.3360
# Epoch 28/200
# 7196/7197 [============================>.] - ETA: 0s - loss: 25.4139
# Epoch 00028: val_loss did not improve from 22.54233
# 7197/7197 [==============================] - 34s 5ms/step - loss: 25.4143 - val_loss: 32.1660
# Epoch 29/200
# 7187/7197 [============================>.] - ETA: 0s - loss: 25.3885
# Epoch 00029: val_loss did not improve from 22.54233
# 7197/7197 [==============================] - 34s 5ms/step - loss: 25.3870 - val_loss: 50.5568
# Epoch 30/200
# 7195/7197 [============================>.] - ETA: 0s - loss: 25.1237
# Epoch 00030: val_loss did not improve from 22.54233
# 7197/7197 [==============================] - 34s 5ms/step - loss: 25.1256 - val_loss: 33.7644
# Epoch 31/200
# 7189/7197 [============================>.] - ETA: 0s - loss: 24.9809
# Epoch 00031: val_loss did not improve from 22.54233
# 7197/7197 [==============================] - 34s 5ms/step - loss: 24.9791 - val_loss: 24.6285
# Epoch 32/200
# 7196/7197 [============================>.] - ETA: 0s - loss: 24.6521
# Epoch 00032: val_loss did not improve from 22.54233
# 7197/7197 [==============================] - 34s 5ms/step - loss: 24.6520 - val_loss: 27.3339
# Epoch 33/200
# 7187/7197 [============================>.] - ETA: 0s - loss: 24.3032
# Epoch 00033: val_loss did not improve from 22.54233
# 7197/7197 [==============================] - 34s 5ms/step - loss: 24.3046 - val_loss: 74.1338
# Epoch 34/200
# 7195/7197 [============================>.] - ETA: 0s - loss: 24.2668
# Epoch 00034: val_loss did not improve from 22.54233
# 7197/7197 [==============================] - 34s 5ms/step - loss: 24.2663 - val_loss: 34.7135
# Epoch 00034: early stopping
# Saved training history to file: DS02/experiment_set_7\window_10\split_seed_1\history.pkl
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_5 (Dense)              (None, 256)               13056
# _________________________________________________________________
# dense_6 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dense_7 (Dense)              (None, 512)               131584
# _________________________________________________________________
# dense_8 (Dense)              (None, 64)                32832
# _________________________________________________________________
# dense_9 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 243,329
# Trainable params: 243,329
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/200
# 7196/7197 [============================>.] - ETA: 0s - loss: 165.8620
# Epoch 00001: val_loss improved from inf to 162.93686, saving model to DS02/experiment_set_7\window_10\split_seed_2\mlp_model_trained.h5
# 7197/7197 [==============================] - 33s 5ms/step - loss: 165.8613 - val_loss: 162.9369
# Epoch 2/200
# 7196/7197 [============================>.] - ETA: 0s - loss: 64.1084
# Epoch 00002: val_loss improved from 162.93686 to 118.83075, saving model to DS02/experiment_set_7\window_10\split_seed_2\mlp_model_trained.h5
# 7197/7197 [==============================] - 33s 5ms/step - loss: 64.1084 - val_loss: 118.8307
# Epoch 3/200
# 7194/7197 [============================>.] - ETA: 0s - loss: 55.3993
# Epoch 00003: val_loss improved from 118.83075 to 55.29757, saving model to DS02/experiment_set_7\window_10\split_seed_2\mlp_model_trained.h5
# 7197/7197 [==============================] - 33s 5ms/step - loss: 55.3972 - val_loss: 55.2976
# Epoch 4/200
# 7191/7197 [============================>.] - ETA: 0s - loss: 49.9556
# Epoch 00004: val_loss did not improve from 55.29757
# 7197/7197 [==============================] - 33s 5ms/step - loss: 49.9529 - val_loss: 106.8632
# Epoch 5/200
# 7193/7197 [============================>.] - ETA: 0s - loss: 46.4348
# Epoch 00005: val_loss did not improve from 55.29757
# 7197/7197 [==============================] - 33s 5ms/step - loss: 46.4338 - val_loss: 88.3361
# Epoch 6/200
# 7195/7197 [============================>.] - ETA: 0s - loss: 43.8034
# Epoch 00006: val_loss improved from 55.29757 to 42.74017, saving model to DS02/experiment_set_7\window_10\split_seed_2\mlp_model_trained.h5
# 7197/7197 [==============================] - 33s 5ms/step - loss: 43.8027 - val_loss: 42.7402
# Epoch 7/200
# 7197/7197 [==============================] - ETA: 0s - loss: 41.3552
# Epoch 00007: val_loss did not improve from 42.74017
# 7197/7197 [==============================] - 33s 5ms/step - loss: 41.3552 - val_loss: 45.7765
# Epoch 8/200
# 7196/7197 [============================>.] - ETA: 0s - loss: 39.3625
# Epoch 00008: val_loss improved from 42.74017 to 38.97919, saving model to DS02/experiment_set_7\window_10\split_seed_2\mlp_model_trained.h5
# 7197/7197 [==============================] - 34s 5ms/step - loss: 39.3624 - val_loss: 38.9792
# Epoch 9/200
# 7188/7197 [============================>.] - ETA: 0s - loss: 37.8613
# Epoch 00009: val_loss did not improve from 38.97919
# 7197/7197 [==============================] - 33s 5ms/step - loss: 37.8596 - val_loss: 42.3914
# Epoch 10/200
# 7184/7197 [============================>.] - ETA: 0s - loss: 36.3824
# Epoch 00010: val_loss did not improve from 38.97919
# 7197/7197 [==============================] - 33s 5ms/step - loss: 36.3886 - val_loss: 67.3229
# Epoch 11/200
# 7188/7197 [============================>.] - ETA: 0s - loss: 35.2279
# Epoch 00011: val_loss did not improve from 38.97919
# 7197/7197 [==============================] - 33s 5ms/step - loss: 35.2350 - val_loss: 42.9427
# Epoch 12/200
# 7185/7197 [============================>.] - ETA: 0s - loss: 34.2291
# Epoch 00012: val_loss improved from 38.97919 to 33.22985, saving model to DS02/experiment_set_7\window_10\split_seed_2\mlp_model_trained.h5
# 7197/7197 [==============================] - 33s 5ms/step - loss: 34.2289 - val_loss: 33.2299
# Epoch 13/200
# 7186/7197 [============================>.] - ETA: 0s - loss: 33.1348
# Epoch 00013: val_loss did not improve from 33.22985
# 7197/7197 [==============================] - 33s 5ms/step - loss: 33.1327 - val_loss: 43.8222
# Epoch 14/200
# 7191/7197 [============================>.] - ETA: 0s - loss: 32.6877
# Epoch 00014: val_loss did not improve from 33.22985
# 7197/7197 [==============================] - 33s 5ms/step - loss: 32.6879 - val_loss: 75.5849
# Epoch 15/200
# 7195/7197 [============================>.] - ETA: 0s - loss: 31.6639
# Epoch 00015: val_loss did not improve from 33.22985
# 7197/7197 [==============================] - 33s 5ms/step - loss: 31.6672 - val_loss: 56.8898
# Epoch 16/200
# 7190/7197 [============================>.] - ETA: 0s - loss: 30.8879
# Epoch 00016: val_loss did not improve from 33.22985
# 7197/7197 [==============================] - 33s 5ms/step - loss: 30.8853 - val_loss: 43.9982
# Epoch 17/200
# 7187/7197 [============================>.] - ETA: 0s - loss: 30.2222
# Epoch 00017: val_loss did not improve from 33.22985
# 7197/7197 [==============================] - 33s 5ms/step - loss: 30.2259 - val_loss: 35.2270
# Epoch 18/200
# 7197/7197 [==============================] - ETA: 0s - loss: 29.7686
# Epoch 00018: val_loss did not improve from 33.22985
# 7197/7197 [==============================] - 33s 5ms/step - loss: 29.7686 - val_loss: 57.7986
# Epoch 19/200
# 7196/7197 [============================>.] - ETA: 0s - loss: 29.1804
# Epoch 00019: val_loss improved from 33.22985 to 32.74642, saving model to DS02/experiment_set_7\window_10\split_seed_2\mlp_model_trained.h5
# 7197/7197 [==============================] - 34s 5ms/step - loss: 29.1804 - val_loss: 32.7464
# Epoch 20/200
# 7186/7197 [============================>.] - ETA: 0s - loss: 28.6759
# Epoch 00020: val_loss did not improve from 32.74642
# 7197/7197 [==============================] - 36s 5ms/step - loss: 28.6721 - val_loss: 49.0387
# Epoch 21/200
# 7186/7197 [============================>.] - ETA: 0s - loss: 28.3942
# Epoch 00021: val_loss improved from 32.74642 to 26.40287, saving model to DS02/experiment_set_7\window_10\split_seed_2\mlp_model_trained.h5
# 7197/7197 [==============================] - 35s 5ms/step - loss: 28.3907 - val_loss: 26.4029
# Epoch 22/200
# 7190/7197 [============================>.] - ETA: 0s - loss: 27.6956
# Epoch 00022: val_loss did not improve from 26.40287
# 7197/7197 [==============================] - 33s 5ms/step - loss: 27.6952 - val_loss: 28.7346
# Epoch 23/200
# 7196/7197 [============================>.] - ETA: 0s - loss: 27.2378
# Epoch 00023: val_loss did not improve from 26.40287
# 7197/7197 [==============================] - 34s 5ms/step - loss: 27.2379 - val_loss: 38.1242
# Epoch 24/200
# 7195/7197 [============================>.] - ETA: 0s - loss: 26.9348
# Epoch 00024: val_loss did not improve from 26.40287
# 7197/7197 [==============================] - 33s 5ms/step - loss: 26.9358 - val_loss: 35.1895
# Epoch 25/200
# 7193/7197 [============================>.] - ETA: 0s - loss: 26.5440
# Epoch 00025: val_loss did not improve from 26.40287
# 7197/7197 [==============================] - 34s 5ms/step - loss: 26.5424 - val_loss: 26.9771
# Epoch 26/200
# 7197/7197 [==============================] - ETA: 0s - loss: 26.4466
# Epoch 00026: val_loss did not improve from 26.40287
# 7197/7197 [==============================] - 35s 5ms/step - loss: 26.4466 - val_loss: 30.6188
# Epoch 27/200
# 7189/7197 [============================>.] - ETA: 0s - loss: 26.0374
# Epoch 00027: val_loss did not improve from 26.40287
# 7197/7197 [==============================] - 34s 5ms/step - loss: 26.0335 - val_loss: 48.4879
# Epoch 28/200
# 7197/7197 [==============================] - ETA: 0s - loss: 25.7175
# Epoch 00028: val_loss did not improve from 26.40287
# 7197/7197 [==============================] - 35s 5ms/step - loss: 25.7175 - val_loss: 45.0520
# Epoch 29/200
# 7193/7197 [============================>.] - ETA: 0s - loss: 25.3969
# Epoch 00029: val_loss did not improve from 26.40287
# 7197/7197 [==============================] - 35s 5ms/step - loss: 25.3971 - val_loss: 36.5996
# Epoch 30/200
# 7188/7197 [============================>.] - ETA: 0s - loss: 25.2289
# Epoch 00030: val_loss improved from 26.40287 to 25.15457, saving model to DS02/experiment_set_7\window_10\split_seed_2\mlp_model_trained.h5
# 7197/7197 [==============================] - 35s 5ms/step - loss: 25.2294 - val_loss: 25.1546
# Epoch 31/200
# 7194/7197 [============================>.] - ETA: 0s - loss: 24.9405
# Epoch 00031: val_loss did not improve from 25.15457
# 7197/7197 [==============================] - 36s 5ms/step - loss: 24.9404 - val_loss: 31.2509
# Epoch 32/200
# 7195/7197 [============================>.] - ETA: 0s - loss: 24.6312
# Epoch 00032: val_loss did not improve from 25.15457
# 7197/7197 [==============================] - 36s 5ms/step - loss: 24.6311 - val_loss: 39.5641
# Epoch 33/200
# 7191/7197 [============================>.] - ETA: 0s - loss: 24.6255 ETA: 0s
# Epoch 00033: val_loss did not improve from 25.15457
# 7197/7197 [==============================] - 34s 5ms/step - loss: 24.6294 - val_loss: 29.1987
# Epoch 34/200
# 7194/7197 [============================>.] - ETA: 0s - loss: 24.1767
# Epoch 00034: val_loss did not improve from 25.15457
# 7197/7197 [==============================] - 34s 5ms/step - loss: 24.1764 - val_loss: 32.3623
# Epoch 35/200
# 7196/7197 [============================>.] - ETA: 0s - loss: 24.0201
# Epoch 00035: val_loss did not improve from 25.15457
# 7197/7197 [==============================] - 34s 5ms/step - loss: 24.0200 - val_loss: 26.4940
# Epoch 36/200
# 7196/7197 [============================>.] - ETA: 0s - loss: 23.7195
# Epoch 00036: val_loss did not improve from 25.15457
# 7197/7197 [==============================] - 35s 5ms/step - loss: 23.7195 - val_loss: 68.9739
# Epoch 37/200
# 7195/7197 [============================>.] - ETA: 0s - loss: 23.7858
# Epoch 00037: val_loss improved from 25.15457 to 24.13155, saving model to DS02/experiment_set_7\window_10\split_seed_2\mlp_model_trained.h5
# 7197/7197 [==============================] - 35s 5ms/step - loss: 23.7858 - val_loss: 24.1315
# Epoch 38/200
# 7196/7197 [============================>.] - ETA: 0s - loss: 23.6353
# Epoch 00038: val_loss improved from 24.13155 to 22.88667, saving model to DS02/experiment_set_7\window_10\split_seed_2\mlp_model_trained.h5
# 7197/7197 [==============================] - 35s 5ms/step - loss: 23.6355 - val_loss: 22.8867
# Epoch 39/200
# 7193/7197 [============================>.] - ETA: 0s - loss: 23.2819
# Epoch 00039: val_loss did not improve from 22.88667
# 7197/7197 [==============================] - 35s 5ms/step - loss: 23.2830 - val_loss: 30.1710
# Epoch 40/200
# 7193/7197 [============================>.] - ETA: 0s - loss: 23.2387
# Epoch 00040: val_loss did not improve from 22.88667
# 7197/7197 [==============================] - 35s 5ms/step - loss: 23.2399 - val_loss: 36.7781
# Epoch 41/200
# 7195/7197 [============================>.] - ETA: 0s - loss: 22.9634
# Epoch 00041: val_loss did not improve from 22.88667
# 7197/7197 [==============================] - 34s 5ms/step - loss: 22.9634 - val_loss: 52.1126
# Epoch 42/200
# 7185/7197 [============================>.] - ETA: 0s - loss: 22.7058
# Epoch 00042: val_loss improved from 22.88667 to 21.54973, saving model to DS02/experiment_set_7\window_10\split_seed_2\mlp_model_trained.h5
# 7197/7197 [==============================] - 35s 5ms/step - loss: 22.7024 - val_loss: 21.5497
# Epoch 43/200
# 7197/7197 [==============================] - ETA: 0s - loss: 22.4674
# Epoch 00043: val_loss did not improve from 21.54973
# 7197/7197 [==============================] - 35s 5ms/step - loss: 22.4674 - val_loss: 22.5864
# Epoch 44/200
# 7187/7197 [============================>.] - ETA: 0s - loss: 22.3362 ETA: 0s -
# Epoch 00044: val_loss did not improve from 21.54973
# 7197/7197 [==============================] - 35s 5ms/step - loss: 22.3380 - val_loss: 52.6016
# Epoch 45/200
# 7189/7197 [============================>.] - ETA: 0s - loss: 22.4926
# Epoch 00045: val_loss improved from 21.54973 to 21.47394, saving model to DS02/experiment_set_7\window_10\split_seed_2\mlp_model_trained.h5
# 7197/7197 [==============================] - 36s 5ms/step - loss: 22.4896 - val_loss: 21.4739
# Epoch 46/200
# 7189/7197 [============================>.] - ETA: 0s - loss: 22.1196
# Epoch 00046: val_loss did not improve from 21.47394
# 7197/7197 [==============================] - 35s 5ms/step - loss: 22.1254 - val_loss: 30.9291
# Epoch 47/200
# 7190/7197 [============================>.] - ETA: 0s - loss: 22.0825
# Epoch 00047: val_loss improved from 21.47394 to 20.37637, saving model to DS02/experiment_set_7\window_10\split_seed_2\mlp_model_trained.h5
# 7197/7197 [==============================] - 35s 5ms/step - loss: 22.0822 - val_loss: 20.3764
# Epoch 48/200
# 7191/7197 [============================>.] - ETA: 0s - loss: 21.6707
# Epoch 00048: val_loss did not improve from 20.37637
# 7197/7197 [==============================] - 36s 5ms/step - loss: 21.6709 - val_loss: 52.9467
# Epoch 49/200
# 7195/7197 [============================>.] - ETA: 0s - loss: 21.8425
# Epoch 00049: val_loss did not improve from 20.37637
# 7197/7197 [==============================] - 36s 5ms/step - loss: 21.8417 - val_loss: 30.2655
# Epoch 50/200
# 7186/7197 [============================>.] - ETA: 0s - loss: 21.5695
# Epoch 00050: val_loss did not improve from 20.37637
# 7197/7197 [==============================] - 35s 5ms/step - loss: 21.5678 - val_loss: 21.3345
# Epoch 51/200
# 7196/7197 [============================>.] - ETA: 0s - loss: 21.4999
# Epoch 00051: val_loss did not improve from 20.37637
# 7197/7197 [==============================] - 35s 5ms/step - loss: 21.4998 - val_loss: 29.9438
# Epoch 52/200
# 7190/7197 [============================>.] - ETA: 0s - loss: 21.4370
# Epoch 00052: val_loss did not improve from 20.37637
# 7197/7197 [==============================] - 35s 5ms/step - loss: 21.4338 - val_loss: 22.0020
# Epoch 53/200
# 7192/7197 [============================>.] - ETA: 0s - loss: 21.3499
# Epoch 00053: val_loss did not improve from 20.37637
# 7197/7197 [==============================] - 35s 5ms/step - loss: 21.3496 - val_loss: 26.6095
# Epoch 54/200
# 7184/7197 [============================>.] - ETA: 0s - loss: 21.2415
# Epoch 00054: val_loss did not improve from 20.37637
# 7197/7197 [==============================] - 35s 5ms/step - loss: 21.2390 - val_loss: 31.0626
# Epoch 55/200
# 7184/7197 [============================>.] - ETA: 0s - loss: 21.0034
# Epoch 00055: val_loss did not improve from 20.37637
# 7197/7197 [==============================] - 37s 5ms/step - loss: 20.9968 - val_loss: 37.2914
# Epoch 56/200
# 7193/7197 [============================>.] - ETA: 0s - loss: 21.0949
# Epoch 00056: val_loss did not improve from 20.37637
# 7197/7197 [==============================] - 35s 5ms/step - loss: 21.0966 - val_loss: 26.3293
# Epoch 57/200
# 7187/7197 [============================>.] - ETA: 0s - loss: 20.9087
# Epoch 00057: val_loss did not improve from 20.37637
# 7197/7197 [==============================] - 36s 5ms/step - loss: 20.9180 - val_loss: 28.4781
# Epoch 00057: early stopping
# Saved training history to file: DS02/experiment_set_7\window_10\split_seed_2\history.pkl
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_10 (Dense)             (None, 256)               13056
# _________________________________________________________________
# dense_11 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dense_12 (Dense)             (None, 512)               131584
# _________________________________________________________________
# dense_13 (Dense)             (None, 64)                32832
# _________________________________________________________________
# dense_14 (Dense)             (None, 1)                 65
# =================================================================
# Total params: 243,329
# Trainable params: 243,329
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/200
# 7192/7197 [============================>.] - ETA: 0s - loss: 171.4904
# Epoch 00001: val_loss improved from inf to 76.85152, saving model to DS02/experiment_set_7\window_10\split_seed_3\mlp_model_trained.h5
# 7197/7197 [==============================] - 36s 5ms/step - loss: 171.4356 - val_loss: 76.8515
# Epoch 2/200
# 7185/7197 [============================>.] - ETA: 0s - loss: 62.9793
# Epoch 00002: val_loss did not improve from 76.85152
# 7197/7197 [==============================] - 36s 5ms/step - loss: 62.9657 - val_loss: 78.9964
# Epoch 3/200
# 7191/7197 [============================>.] - ETA: 0s - loss: 54.6297
# Epoch 00003: val_loss did not improve from 76.85152
# 7197/7197 [==============================] - 36s 5ms/step - loss: 54.6358 - val_loss: 79.6827
# Epoch 4/200
# 7190/7197 [============================>.] - ETA: 0s - loss: 49.6174
# Epoch 00004: val_loss improved from 76.85152 to 47.68084, saving model to DS02/experiment_set_7\window_10\split_seed_3\mlp_model_trained.h5
# 7197/7197 [==============================] - 36s 5ms/step - loss: 49.6148 - val_loss: 47.6808
# Epoch 5/200
# 7195/7197 [============================>.] - ETA: 0s - loss: 45.9508
# Epoch 00005: val_loss did not improve from 47.68084
# 7197/7197 [==============================] - 35s 5ms/step - loss: 45.9501 - val_loss: 151.7970
# Epoch 6/200
# 7185/7197 [============================>.] - ETA: 0s - loss: 42.9336
# Epoch 00006: val_loss did not improve from 47.68084
# 7197/7197 [==============================] - 36s 5ms/step - loss: 42.9311 - val_loss: 53.5901
# Epoch 7/200
# 7192/7197 [============================>.] - ETA: 0s - loss: 40.2513
# Epoch 00007: val_loss improved from 47.68084 to 35.60111, saving model to DS02/experiment_set_7\window_10\split_seed_3\mlp_model_trained.h5
# 7197/7197 [==============================] - 36s 5ms/step - loss: 40.2499 - val_loss: 35.6011
# Epoch 8/200
# 7187/7197 [============================>.] - ETA: 0s - loss: 38.5575
# Epoch 00008: val_loss did not improve from 35.60111
# 7197/7197 [==============================] - 35s 5ms/step - loss: 38.5510 - val_loss: 63.8578
# Epoch 9/200
# 7190/7197 [============================>.] - ETA: 0s - loss: 36.9218
# Epoch 00009: val_loss did not improve from 35.60111
# 7197/7197 [==============================] - 35s 5ms/step - loss: 36.9214 - val_loss: 69.9919
# Epoch 10/200
# 7187/7197 [============================>.] - ETA: 0s - loss: 35.4362
# Epoch 00010: val_loss improved from 35.60111 to 35.02350, saving model to DS02/experiment_set_7\window_10\split_seed_3\mlp_model_trained.h5
# 7197/7197 [==============================] - 35s 5ms/step - loss: 35.4330 - val_loss: 35.0235
# Epoch 11/200
# 7193/7197 [============================>.] - ETA: 0s - loss: 34.3144
# Epoch 00011: val_loss did not improve from 35.02350
# 7197/7197 [==============================] - 34s 5ms/step - loss: 34.3122 - val_loss: 65.6530
# Epoch 12/200
# 7192/7197 [============================>.] - ETA: 0s - loss: 32.9717
# Epoch 00012: val_loss improved from 35.02350 to 31.91795, saving model to DS02/experiment_set_7\window_10\split_seed_3\mlp_model_trained.h5
# 7197/7197 [==============================] - 35s 5ms/step - loss: 32.9699 - val_loss: 31.9180
# Epoch 13/200
# 7193/7197 [============================>.] - ETA: 0s - loss: 31.9530
# Epoch 00013: val_loss did not improve from 31.91795
# 7197/7197 [==============================] - 35s 5ms/step - loss: 31.9555 - val_loss: 38.3702
# Epoch 14/200
# 7195/7197 [============================>.] - ETA: 0s - loss: 31.4128
# Epoch 00014: val_loss improved from 31.91795 to 30.80402, saving model to DS02/experiment_set_7\window_10\split_seed_3\mlp_model_trained.h5
# 7197/7197 [==============================] - 36s 5ms/step - loss: 31.4123 - val_loss: 30.8040
# Epoch 15/200
# 7184/7197 [============================>.] - ETA: 0s - loss: 30.4440
# Epoch 00015: val_loss did not improve from 30.80402
# 7197/7197 [==============================] - 36s 5ms/step - loss: 30.4641 - val_loss: 45.7807
# Epoch 16/200
# 7192/7197 [============================>.] - ETA: 0s - loss: 29.6774
# Epoch 00016: val_loss improved from 30.80402 to 29.53986, saving model to DS02/experiment_set_7\window_10\split_seed_3\mlp_model_trained.h5
# 7197/7197 [==============================] - 36s 5ms/step - loss: 29.6762 - val_loss: 29.5399
# Epoch 17/200
# 7190/7197 [============================>.] - ETA: 0s - loss: 29.2518
# Epoch 00017: val_loss did not improve from 29.53986
# 7197/7197 [==============================] - 35s 5ms/step - loss: 29.2533 - val_loss: 48.9051
# Epoch 18/200
# 7190/7197 [============================>.] - ETA: 0s - loss: 28.6911
# Epoch 00018: val_loss did not improve from 29.53986
# 7197/7197 [==============================] - 36s 5ms/step - loss: 28.6902 - val_loss: 32.4628
# Epoch 19/200
# 7189/7197 [============================>.] - ETA: 0s - loss: 28.1930
# Epoch 00019: val_loss improved from 29.53986 to 25.44147, saving model to DS02/experiment_set_7\window_10\split_seed_3\mlp_model_trained.h5
# 7197/7197 [==============================] - 36s 5ms/step - loss: 28.1965 - val_loss: 25.4415
# Epoch 20/200
# 7195/7197 [============================>.] - ETA: 0s - loss: 27.5759
# Epoch 00020: val_loss did not improve from 25.44147
# 7197/7197 [==============================] - 36s 5ms/step - loss: 27.5763 - val_loss: 45.8830
# Epoch 21/200
# 7197/7197 [==============================] - ETA: 0s - loss: 27.2061
# Epoch 00021: val_loss did not improve from 25.44147
# 7197/7197 [==============================] - 35s 5ms/step - loss: 27.2061 - val_loss: 32.5778
# Epoch 22/200
# 7188/7197 [============================>.] - ETA: 0s - loss: 26.7740
# Epoch 00022: val_loss did not improve from 25.44147
# 7197/7197 [==============================] - 35s 5ms/step - loss: 26.7719 - val_loss: 41.1987
# Epoch 23/200
# 7188/7197 [============================>.] - ETA: 0s - loss: 26.3712
# Epoch 00023: val_loss did not improve from 25.44147
# 7197/7197 [==============================] - 35s 5ms/step - loss: 26.3733 - val_loss: 32.5438
# Epoch 24/200
# 7194/7197 [============================>.] - ETA: 0s - loss: 26.1338
# Epoch 00024: val_loss improved from 25.44147 to 24.83752, saving model to DS02/experiment_set_7\window_10\split_seed_3\mlp_model_trained.h5
# 7197/7197 [==============================] - 35s 5ms/step - loss: 26.1328 - val_loss: 24.8375
# Epoch 25/200
# 7186/7197 [============================>.] - ETA: 0s - loss: 25.5773
# Epoch 00025: val_loss did not improve from 24.83752
# 7197/7197 [==============================] - 36s 5ms/step - loss: 25.5738 - val_loss: 27.7748
# Epoch 26/200
# 7194/7197 [============================>.] - ETA: 0s - loss: 25.2607
# Epoch 00026: val_loss did not improve from 24.83752
# 7197/7197 [==============================] - 37s 5ms/step - loss: 25.2609 - val_loss: 37.3424
# Epoch 27/200
# 7191/7197 [============================>.] - ETA: 0s - loss: 25.1991
# Epoch 00027: val_loss did not improve from 24.83752
# 7197/7197 [==============================] - 36s 5ms/step - loss: 25.1979 - val_loss: 39.5086
# Epoch 28/200
# 7190/7197 [============================>.] - ETA: 0s - loss: 24.7775
# Epoch 00028: val_loss did not improve from 24.83752
# 7197/7197 [==============================] - 36s 5ms/step - loss: 24.7798 - val_loss: 26.5689
# Epoch 29/200
# 7186/7197 [============================>.] - ETA: 0s - loss: 24.4736
# Epoch 00029: val_loss improved from 24.83752 to 21.71376, saving model to DS02/experiment_set_7\window_10\split_seed_3\mlp_model_trained.h5
# 7197/7197 [==============================] - 37s 5ms/step - loss: 24.4678 - val_loss: 21.7138
# Epoch 30/200
# 7196/7197 [============================>.] - ETA: 0s - loss: 24.3122
# Epoch 00030: val_loss did not improve from 21.71376
# 7197/7197 [==============================] - 36s 5ms/step - loss: 24.3122 - val_loss: 43.8968
# Epoch 31/200
# 7195/7197 [============================>.] - ETA: 0s - loss: 24.2436
# Epoch 00031: val_loss did not improve from 21.71376
# 7197/7197 [==============================] - 35s 5ms/step - loss: 24.2428 - val_loss: 27.7922
# Epoch 32/200
# 7195/7197 [============================>.] - ETA: 0s - loss: 24.0725
# Epoch 00032: val_loss did not improve from 21.71376
# 7197/7197 [==============================] - 36s 5ms/step - loss: 24.0721 - val_loss: 33.5960
# Epoch 33/200
# 7185/7197 [============================>.] - ETA: 0s - loss: 23.4925
# Epoch 00033: val_loss did not improve from 21.71376
# 7197/7197 [==============================] - 35s 5ms/step - loss: 23.4969 - val_loss: 31.2232
# Epoch 34/200
# 7197/7197 [==============================] - ETA: 0s - loss: 23.4020
# Epoch 00034: val_loss did not improve from 21.71376
# 7197/7197 [==============================] - 35s 5ms/step - loss: 23.4020 - val_loss: 29.7982
# Epoch 35/200
# 7186/7197 [============================>.] - ETA: 0s - loss: 23.1868
# Epoch 00035: val_loss did not improve from 21.71376
# 7197/7197 [==============================] - 35s 5ms/step - loss: 23.1821 - val_loss: 23.1084
# Epoch 36/200
# 7193/7197 [============================>.] - ETA: 0s - loss: 23.1515
# Epoch 00036: val_loss did not improve from 21.71376
# 7197/7197 [==============================] - 35s 5ms/step - loss: 23.1506 - val_loss: 26.2225
# Epoch 37/200
# 7189/7197 [============================>.] - ETA: 0s - loss: 22.8064
# Epoch 00037: val_loss did not improve from 21.71376
# 7197/7197 [==============================] - 35s 5ms/step - loss: 22.8107 - val_loss: 26.2178
# Epoch 38/200
# 7192/7197 [============================>.] - ETA: 0s - loss: 22.6918
# Epoch 00038: val_loss did not improve from 21.71376
# 7197/7197 [==============================] - 35s 5ms/step - loss: 22.6949 - val_loss: 26.9776
# Epoch 39/200
# 7185/7197 [============================>.] - ETA: 0s - loss: 22.5447
# Epoch 00039: val_loss did not improve from 21.71376
# 7197/7197 [==============================] - 35s 5ms/step - loss: 22.5401 - val_loss: 23.5072
# Epoch 00039: early stopping
# Saved training history to file: DS02/experiment_set_7\window_10\split_seed_3\history.pkl
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_15 (Dense)             (None, 256)               13056
# _________________________________________________________________
# dense_16 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dense_17 (Dense)             (None, 512)               131584
# _________________________________________________________________
# dense_18 (Dense)             (None, 64)                32832
# _________________________________________________________________
# dense_19 (Dense)             (None, 1)                 65
# =================================================================
# Total params: 243,329
# Trainable params: 243,329
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/200
# 7191/7197 [============================>.] - ETA: 0s - loss: 181.1359
# Epoch 00001: val_loss improved from inf to 79.35913, saving model to DS02/experiment_set_7\window_10\split_seed_4\mlp_model_trained.h5
# 7197/7197 [==============================] - 36s 5ms/step - loss: 181.0581 - val_loss: 79.3591
# Epoch 2/200
# 7196/7197 [============================>.] - ETA: 0s - loss: 64.9482
# Epoch 00002: val_loss improved from 79.35913 to 76.86446, saving model to DS02/experiment_set_7\window_10\split_seed_4\mlp_model_trained.h5
# 7197/7197 [==============================] - 36s 5ms/step - loss: 64.9482 - val_loss: 76.8645
# Epoch 3/200
# 7190/7197 [============================>.] - ETA: 0s - loss: 56.2527
# Epoch 00003: val_loss did not improve from 76.86446
# 7197/7197 [==============================] - 36s 5ms/step - loss: 56.2452 - val_loss: 78.1474
# Epoch 4/200
# 7187/7197 [============================>.] - ETA: 0s - loss: 50.6795
# Epoch 00004: val_loss improved from 76.86446 to 54.45944, saving model to DS02/experiment_set_7\window_10\split_seed_4\mlp_model_trained.h5
# 7197/7197 [==============================] - 35s 5ms/step - loss: 50.6732 - val_loss: 54.4594
# Epoch 5/200
# 7196/7197 [============================>.] - ETA: 0s - loss: 46.7436
# Epoch 00005: val_loss did not improve from 54.45944
# 7197/7197 [==============================] - 36s 5ms/step - loss: 46.7440 - val_loss: 109.0555
# Epoch 6/200
# 7187/7197 [============================>.] - ETA: 0s - loss: 43.8376
# Epoch 00006: val_loss did not improve from 54.45944
# 7197/7197 [==============================] - 35s 5ms/step - loss: 43.8294 - val_loss: 77.8717
# Epoch 7/200
# 7186/7197 [============================>.] - ETA: 0s - loss: 41.8568
# Epoch 00007: val_loss did not improve from 54.45944
# 7197/7197 [==============================] - 36s 5ms/step - loss: 41.8493 - val_loss: 55.9145
# Epoch 8/200
# 7197/7197 [==============================] - ETA: 0s - loss: 39.7384
# Epoch 00008: val_loss improved from 54.45944 to 52.26810, saving model to DS02/experiment_set_7\window_10\split_seed_4\mlp_model_trained.h5
# 7197/7197 [==============================] - 36s 5ms/step - loss: 39.7384 - val_loss: 52.2681
# Epoch 9/200
# 7190/7197 [============================>.] - ETA: 0s - loss: 38.0047
# Epoch 00009: val_loss improved from 52.26810 to 41.07824, saving model to DS02/experiment_set_7\window_10\split_seed_4\mlp_model_trained.h5
# 7197/7197 [==============================] - 36s 5ms/step - loss: 37.9992 - val_loss: 41.0782
# Epoch 10/200
# 7196/7197 [============================>.] - ETA: 0s - loss: 36.3798
# Epoch 00010: val_loss improved from 41.07824 to 35.95972, saving model to DS02/experiment_set_7\window_10\split_seed_4\mlp_model_trained.h5
# 7197/7197 [==============================] - 36s 5ms/step - loss: 36.3798 - val_loss: 35.9597
# Epoch 11/200
# 7195/7197 [============================>.] - ETA: 0s - loss: 35.1762
# Epoch 00011: val_loss did not improve from 35.95972
# 7197/7197 [==============================] - 36s 5ms/step - loss: 35.1766 - val_loss: 39.5372
# Epoch 12/200
# 7192/7197 [============================>.] - ETA: 0s - loss: 34.3679
# Epoch 00012: val_loss did not improve from 35.95972
# 7197/7197 [==============================] - 35s 5ms/step - loss: 34.3721 - val_loss: 52.2526
# Epoch 13/200
# 7196/7197 [============================>.] - ETA: 0s - loss: 33.0801
# Epoch 00013: val_loss improved from 35.95972 to 34.07974, saving model to DS02/experiment_set_7\window_10\split_seed_4\mlp_model_trained.h5
# 7197/7197 [==============================] - 37s 5ms/step - loss: 33.0802 - val_loss: 34.0797
# Epoch 14/200
# 7195/7197 [============================>.] - ETA: 0s - loss: 32.3421
# Epoch 00014: val_loss did not improve from 34.07974
# 7197/7197 [==============================] - 37s 5ms/step - loss: 32.3419 - val_loss: 45.6530
# Epoch 15/200
# 7197/7197 [==============================] - ETA: 0s - loss: 31.3465
# Epoch 00015: val_loss did not improve from 34.07974
# 7197/7197 [==============================] - 37s 5ms/step - loss: 31.3465 - val_loss: 47.6213
# Epoch 16/200
# 7195/7197 [============================>.] - ETA: 0s - loss: 30.7130
# Epoch 00016: val_loss improved from 34.07974 to 28.61875, saving model to DS02/experiment_set_7\window_10\split_seed_4\mlp_model_trained.h5
# 7197/7197 [==============================] - 36s 5ms/step - loss: 30.7116 - val_loss: 28.6187
# Epoch 17/200
# 7190/7197 [============================>.] - ETA: 0s - loss: 29.8284
# Epoch 00017: val_loss did not improve from 28.61875
# 7197/7197 [==============================] - 37s 5ms/step - loss: 29.8322 - val_loss: 43.9378
# Epoch 18/200
# 7190/7197 [============================>.] - ETA: 0s - loss: 29.5876
# Epoch 00018: val_loss improved from 28.61875 to 26.54677, saving model to DS02/experiment_set_7\window_10\split_seed_4\mlp_model_trained.h5
# 7197/7197 [==============================] - 36s 5ms/step - loss: 29.5865 - val_loss: 26.5468
# Epoch 19/200
# 7194/7197 [============================>.] - ETA: 0s - loss: 29.0122
# Epoch 00019: val_loss did not improve from 26.54677
# 7197/7197 [==============================] - 36s 5ms/step - loss: 29.0124 - val_loss: 33.6148
# Epoch 20/200
# 7190/7197 [============================>.] - ETA: 0s - loss: 28.5390
# Epoch 00020: val_loss improved from 26.54677 to 26.26831, saving model to DS02/experiment_set_7\window_10\split_seed_4\mlp_model_trained.h5
# 7197/7197 [==============================] - 36s 5ms/step - loss: 28.5334 - val_loss: 26.2683
# Epoch 21/200
# 7190/7197 [============================>.] - ETA: 0s - loss: 27.8144
# Epoch 00021: val_loss did not improve from 26.26831
# 7197/7197 [==============================] - 37s 5ms/step - loss: 27.8133 - val_loss: 45.3915
# Epoch 22/200
# 7189/7197 [============================>.] - ETA: 0s - loss: 27.5049
# Epoch 00022: val_loss did not improve from 26.26831
# 7197/7197 [==============================] - 37s 5ms/step - loss: 27.5046 - val_loss: 34.4487
# Epoch 23/200
# 7189/7197 [============================>.] - ETA: 0s - loss: 27.1974
# Epoch 00023: val_loss did not improve from 26.26831
# 7197/7197 [==============================] - 36s 5ms/step - loss: 27.1949 - val_loss: 29.4147
# Epoch 24/200
# 7190/7197 [============================>.] - ETA: 0s - loss: 26.5663
# Epoch 00024: val_loss did not improve from 26.26831
# 7197/7197 [==============================] - 36s 5ms/step - loss: 26.5641 - val_loss: 34.3872
# Epoch 25/200
# 7189/7197 [============================>.] - ETA: 0s - loss: 26.3778
# Epoch 00025: val_loss did not improve from 26.26831
# 7197/7197 [==============================] - 36s 5ms/step - loss: 26.3760 - val_loss: 31.9380
# Epoch 26/200
# 7186/7197 [============================>.] - ETA: 0s - loss: 25.9683
# Epoch 00026: val_loss did not improve from 26.26831
# 7197/7197 [==============================] - 36s 5ms/step - loss: 25.9675 - val_loss: 30.8402
# Epoch 27/200
# 7196/7197 [============================>.] - ETA: 0s - loss: 25.7283
# Epoch 00027: val_loss improved from 26.26831 to 24.98999, saving model to DS02/experiment_set_7\window_10\split_seed_4\mlp_model_trained.h5
# 7197/7197 [==============================] - 36s 5ms/step - loss: 25.7282 - val_loss: 24.9900
# Epoch 28/200
# 7192/7197 [============================>.] - ETA: 0s - loss: 25.3984
# Epoch 00028: val_loss did not improve from 24.98999
# 7197/7197 [==============================] - 36s 5ms/step - loss: 25.3968 - val_loss: 28.8998
# Epoch 29/200
# 7186/7197 [============================>.] - ETA: 0s - loss: 25.0811
# Epoch 00029: val_loss did not improve from 24.98999
# 7197/7197 [==============================] - 36s 5ms/step - loss: 25.0971 - val_loss: 39.2357
# Epoch 30/200
# 7195/7197 [============================>.] - ETA: 0s - loss: 24.9448
# Epoch 00030: val_loss did not improve from 24.98999
# 7197/7197 [==============================] - 36s 5ms/step - loss: 24.9449 - val_loss: 26.1390
# Epoch 31/200
# 7195/7197 [============================>.] - ETA: 0s - loss: 24.4276
# Epoch 00031: val_loss did not improve from 24.98999
# 7197/7197 [==============================] - 36s 5ms/step - loss: 24.4279 - val_loss: 29.1658
# Epoch 32/200
# 7196/7197 [============================>.] - ETA: 0s - loss: 24.5076
# Epoch 00032: val_loss did not improve from 24.98999
# 7197/7197 [==============================] - 37s 5ms/step - loss: 24.5076 - val_loss: 62.6625
# Epoch 33/200
# 7194/7197 [============================>.] - ETA: 0s - loss: 24.2292
# Epoch 00033: val_loss did not improve from 24.98999
# 7197/7197 [==============================] - 36s 5ms/step - loss: 24.2301 - val_loss: 25.4794
# Epoch 34/200
# 7193/7197 [============================>.] - ETA: 0s - loss: 23.9404
# Epoch 00034: val_loss did not improve from 24.98999
# 7197/7197 [==============================] - 36s 5ms/step - loss: 23.9388 - val_loss: 44.0113
# Epoch 35/200
# 7186/7197 [============================>.] - ETA: 0s - loss: 23.7175
# Epoch 00035: val_loss improved from 24.98999 to 23.73231, saving model to DS02/experiment_set_7\window_10\split_seed_4\mlp_model_trained.h5
# 7197/7197 [==============================] - 37s 5ms/step - loss: 23.7132 - val_loss: 23.7323
# Epoch 36/200
# 7194/7197 [============================>.] - ETA: 0s - loss: 23.4671
# Epoch 00036: val_loss improved from 23.73231 to 23.70476, saving model to DS02/experiment_set_7\window_10\split_seed_4\mlp_model_trained.h5
# 7197/7197 [==============================] - 37s 5ms/step - loss: 23.4671 - val_loss: 23.7048
# Epoch 37/200
# 7187/7197 [============================>.] - ETA: 0s - loss: 23.2221
# Epoch 00037: val_loss did not improve from 23.70476
# 7197/7197 [==============================] - 36s 5ms/step - loss: 23.2236 - val_loss: 27.3294
# Epoch 38/200
# 7194/7197 [============================>.] - ETA: 0s - loss: 23.0384
# Epoch 00038: val_loss did not improve from 23.70476
# 7197/7197 [==============================] - 35s 5ms/step - loss: 23.0383 - val_loss: 23.8972
# Epoch 39/200
# 7187/7197 [============================>.] - ETA: 0s - loss: 22.8051
# Epoch 00039: val_loss improved from 23.70476 to 19.40313, saving model to DS02/experiment_set_7\window_10\split_seed_4\mlp_model_trained.h5
# 7197/7197 [==============================] - 38s 5ms/step - loss: 22.8040 - val_loss: 19.4031
# Epoch 40/200
# 7188/7197 [============================>.] - ETA: 0s - loss: 22.6050
# Epoch 00040: val_loss did not improve from 19.40313
# 7197/7197 [==============================] - 36s 5ms/step - loss: 22.6066 - val_loss: 23.6974
# Epoch 41/200
# 7191/7197 [============================>.] - ETA: 0s - loss: 22.8685
# Epoch 00041: val_loss did not improve from 19.40313
# 7197/7197 [==============================] - 36s 5ms/step - loss: 22.8678 - val_loss: 35.5534
# Epoch 42/200
# 7188/7197 [============================>.] - ETA: 0s - loss: 22.4993
# Epoch 00042: val_loss did not improve from 19.40313
# 7197/7197 [==============================] - 35s 5ms/step - loss: 22.5029 - val_loss: 27.2535
# Epoch 43/200
# 7193/7197 [============================>.] - ETA: 0s - loss: 22.0934
# Epoch 00043: val_loss did not improve from 19.40313
# 7197/7197 [==============================] - 36s 5ms/step - loss: 22.0924 - val_loss: 27.8345
# Epoch 44/200
# 7192/7197 [============================>.] - ETA: 0s - loss: 22.2545
# Epoch 00044: val_loss did not improve from 19.40313
# 7197/7197 [==============================] - 37s 5ms/step - loss: 22.2536 - val_loss: 34.8980
# Epoch 45/200
# 7188/7197 [============================>.] - ETA: 0s - loss: 21.7952
# Epoch 00045: val_loss did not improve from 19.40313
# 7197/7197 [==============================] - 36s 5ms/step - loss: 21.7941 - val_loss: 22.5685
# Epoch 46/200
# 7187/7197 [============================>.] - ETA: 0s - loss: 22.2203
# Epoch 00046: val_loss did not improve from 19.40313
# 7197/7197 [==============================] - 37s 5ms/step - loss: 22.2181 - val_loss: 27.2894
# Epoch 47/200
# 7189/7197 [============================>.] - ETA: 0s - loss: 21.6766
# Epoch 00047: val_loss did not improve from 19.40313
# 7197/7197 [==============================] - 36s 5ms/step - loss: 21.6730 - val_loss: 29.4074
# Epoch 48/200
# 7192/7197 [============================>.] - ETA: 0s - loss: 21.7842
# Epoch 00048: val_loss improved from 19.40313 to 19.09345, saving model to DS02/experiment_set_7\window_10\split_seed_4\mlp_model_trained.h5
# 7197/7197 [==============================] - 36s 5ms/step - loss: 21.7826 - val_loss: 19.0934
# Epoch 49/200
# 7191/7197 [============================>.] - ETA: 0s - loss: 21.8725
# Epoch 00049: val_loss did not improve from 19.09345
# 7197/7197 [==============================] - 37s 5ms/step - loss: 21.8720 - val_loss: 27.7834
# Epoch 50/200
# 7194/7197 [============================>.] - ETA: 0s - loss: 21.3122
# Epoch 00050: val_loss did not improve from 19.09345
# 7197/7197 [==============================] - 37s 5ms/step - loss: 21.3108 - val_loss: 19.5811
# Epoch 51/200
# 7194/7197 [============================>.] - ETA: 0s - loss: 21.3922
# Epoch 00051: val_loss did not improve from 19.09345
# 7197/7197 [==============================] - 37s 5ms/step - loss: 21.3920 - val_loss: 26.5148
# Epoch 52/200
# 7192/7197 [============================>.] - ETA: 0s - loss: 21.2211
# Epoch 00052: val_loss did not improve from 19.09345
# 7197/7197 [==============================] - 37s 5ms/step - loss: 21.2223 - val_loss: 21.6264
# Epoch 53/200
# 7186/7197 [============================>.] - ETA: 0s - loss: 20.9212
# Epoch 00053: val_loss did not improve from 19.09345
# 7197/7197 [==============================] - 37s 5ms/step - loss: 20.9284 - val_loss: 36.9485
# Epoch 54/200
# 7189/7197 [============================>.] - ETA: 0s - loss: 20.9149
# Epoch 00054: val_loss did not improve from 19.09345
# 7197/7197 [==============================] - 37s 5ms/step - loss: 20.9148 - val_loss: 26.6220
# Epoch 55/200
# 7194/7197 [============================>.] - ETA: 0s - loss: 20.7674
# Epoch 00055: val_loss did not improve from 19.09345
# 7197/7197 [==============================] - 36s 5ms/step - loss: 20.7665 - val_loss: 20.8310
# Epoch 56/200
# 7185/7197 [============================>.] - ETA: 0s - loss: 20.6568
# Epoch 00056: val_loss did not improve from 19.09345
# 7197/7197 [==============================] - 36s 5ms/step - loss: 20.6541 - val_loss: 21.3109
# Epoch 57/200
# 7187/7197 [============================>.] - ETA: 0s - loss: 20.8036
# Epoch 00057: val_loss improved from 19.09345 to 18.33142, saving model to DS02/experiment_set_7\window_10\split_seed_4\mlp_model_trained.h5
# 7197/7197 [==============================] - 36s 5ms/step - loss: 20.8002 - val_loss: 18.3314
# Epoch 58/200
# 7187/7197 [============================>.] - ETA: 0s - loss: 20.7711
# Epoch 00058: val_loss did not improve from 18.33142
# 7197/7197 [==============================] - 36s 5ms/step - loss: 20.7668 - val_loss: 23.3147
# Epoch 59/200
# 7186/7197 [============================>.] - ETA: 0s - loss: 20.4483
# Epoch 00059: val_loss did not improve from 18.33142
# 7197/7197 [==============================] - 38s 5ms/step - loss: 20.4493 - val_loss: 42.5252
# Epoch 60/200
# 7191/7197 [============================>.] - ETA: 0s - loss: 20.3755
# Epoch 00060: val_loss did not improve from 18.33142
# 7197/7197 [==============================] - 37s 5ms/step - loss: 20.3740 - val_loss: 24.0223
# Epoch 61/200
# 7186/7197 [============================>.] - ETA: 0s - loss: 20.3731
# Epoch 00061: val_loss did not improve from 18.33142
# 7197/7197 [==============================] - 36s 5ms/step - loss: 20.3706 - val_loss: 20.5891
# Epoch 62/200
# 7196/7197 [============================>.] - ETA: 0s - loss: 20.2213
# Epoch 00062: val_loss did not improve from 18.33142
# 7197/7197 [==============================] - 36s 5ms/step - loss: 20.2213 - val_loss: 29.1426
# Epoch 63/200
# 7186/7197 [============================>.] - ETA: 0s - loss: 20.1473
# Epoch 00063: val_loss did not improve from 18.33142
# 7197/7197 [==============================] - 36s 5ms/step - loss: 20.1495 - val_loss: 22.4950
# Epoch 64/200
# 7195/7197 [============================>.] - ETA: 0s - loss: 20.3118
# Epoch 00064: val_loss did not improve from 18.33142
# 7197/7197 [==============================] - 35s 5ms/step - loss: 20.3117 - val_loss: 20.2114
# Epoch 65/200
# 7192/7197 [============================>.] - ETA: 0s - loss: 19.9562
# Epoch 00065: val_loss did not improve from 18.33142
# 7197/7197 [==============================] - 35s 5ms/step - loss: 19.9552 - val_loss: 23.8759
# Epoch 66/200
# 7194/7197 [============================>.] - ETA: 0s - loss: 19.7729
# Epoch 00066: val_loss did not improve from 18.33142
# 7197/7197 [==============================] - 35s 5ms/step - loss: 19.7719 - val_loss: 51.1291
# Epoch 67/200
# 7185/7197 [============================>.] - ETA: 0s - loss: 19.9864
# Epoch 00067: val_loss did not improve from 18.33142
# 7197/7197 [==============================] - 35s 5ms/step - loss: 19.9835 - val_loss: 19.5193
# Epoch 00067: early stopping
# Saved training history to file: DS02/experiment_set_7\window_10\split_seed_4\history.pkl

# %%
mse_vals = []
rmse_vals = []
cmapss_score_vals = []

for i in range(1, 5):
    model_path = os.path.join(output_path, "window_{}".format(W), "split_seed_{}".format(i))
    model = load_model(os.path.join(model_path, "mlp_model_trained.h5"))
    scaler = results[i - 1][2]
    x_test_scaled = scaler.transform(x_test_tw)
    predictions_test = model.predict(x_test_scaled).flatten()
    mse, rmse, cmapss_score = compute_evaluation_metrics(predictions_test, y_test_tw)
    mse_vals.append(mse)
    rmse_vals.append(rmse)
    cmapss_score_vals.append(cmapss_score)
    
print(mse_vals)
print(rmse_vals)
print(cmapss_score_vals)
# Out:
# Test set:
# MSE: 62.69
# RMSE: 7.92
# CMAPSS score: 1.80
#
# Test set:
# MSE: 64.41
# RMSE: 8.03
# CMAPSS score: 1.81
#
# Test set:
# MSE: 67.55
# RMSE: 8.22
# CMAPSS score: 1.84
#
# Test set:
# MSE: 66.79
# RMSE: 8.17
# CMAPSS score: 1.85
#
# [62.69164, 64.40734, 67.55202, 66.78518]
# [7.917805, 8.025418, 8.219004, 8.17222]
# [1.7950371136684864, 1.8138475938729346, 1.8381098669874198, 1.8468223664689611]

# %%
def print_summary_statistics(arr):
    print("Mean: {:.2f}".format(np.mean(arr)))
    print("Stddev: {:.2f}".format(np.std(arr)))

# %%
# For random seed 0
mse_vals += [64.41]
rmse_vals += [8.03]
cmapss_score_vals += [1.83]

# %%
print("MSE: ")
print_summary_statistics(mse_vals)

print("\nRMSE: ")
print_summary_statistics(rmse_vals)

print("\nCMAPSS score: ")
print_summary_statistics(cmapss_score_vals)
# Out:
# MSE:
# Mean: 65.17
# Stddev: 1.77
#
# RMSE:
# Mean: 8.07
# Stddev: 0.11
#
# CMAPSS score:
# Mean: 1.82
# Stddev: 0.02
